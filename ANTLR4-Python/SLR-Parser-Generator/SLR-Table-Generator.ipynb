# %%
from IPython.core.display import HTML
with open('../../style.css', 'r') as file:
    css = file.read()
HTML(css)
# Out:
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Philosopher:400,700,400italic,700italic' rel='stylesheet' type='text/css'>
#
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
# .container { width: 100% }
#
# /* Formatting for header cells */
# .text_cell_render h1 {
#     font-family: 'Philosopher', sans-serif;
#     font-weight: 400;
#     font-size: 2.2em;
#     line-height: 100%;
#     color: rgb(0, 80, 120);
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
# .text_cell_render h2 {
#     font-family: 'Philosopher', serif;
#     font-weight: 400;
#     font-size: 1.9em;
#     line-height: 100%;
#     color: rgb(200,100,0);
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h3 {
#     font-family: 'Philosopher', serif;
#     margin-top:12px;
#     margin-bottom: 3px;
#     font-style: italic;
#     color: rgb(94,127,192);
# }
#
# .text_cell_render h4 {
#     font-family: 'Philosopher', serif;
# }
#
# .text_cell_render h5 {
#     font-family: 'Alegreya Sans', sans-serif;
#     font-weight: 300;
#     font-size: 16pt;
#     color: grey;
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h6 {
#     font-family: 'PT Mono', sans-serif;
#     font-weight: 300;
#     font-size: 10pt;
#     color: grey;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# .text_cell_render em {
#     font-family: 'Philosopher', sans-serif;
#     color:        blue;
#     background-color: rgb(255,220,180);
#     font-size:    110%;
#     margin-left:   2px;
#     margin-right:  2px;
#     font-weight:   100;
# }
#
# .text_cell_render b {
#     color:            rgb(255,195,195);
#     background-color: rgb(0,0,0);
#     font-size:    110%;
#     margin-left:   2px;
#     margin-right:  2px;
#     font-weight:   650;
# }
#
# .text_cell_render tt {
#     font-size:    120%;
#     margin-left:   2px;
#     margin-right:  2px;
#     font-weight:   150;
# }
#
# .Codemirror {
#     font-family: "PT Mono";
#     font-size: 100%;
# }
#
# </style>

# %% [markdown]
# # Implementing an SLR-Table-Generator

# %% [markdown]
# ## A Grammar for Grammars

# %% [markdown]
# As the goal is to generate an *SLR-table-generator* we first need to implement a parser for context free grammars.
# The file `simple.g` contains an example grammar that describes arithmetic expressions.

# %%
# !cat Examples/c-grammar.g
# Out:
# // Below is the grammar for the programming language C.
#
# primary_expression
# 	: IDENTIFIER
# 	| CONSTANT
# 	| STRING_LITERAL
# 	| '(' expression ')'
# 	;
#
# postfix_expression
# 	: primary_expression
# 	| postfix_expression '[' expression ']'
# 	| postfix_expression '(' ')'
# 	| postfix_expression '(' argument_expression_list ')'
# 	| postfix_expression '.' IDENTIFIER
# 	| postfix_expression '->' IDENTIFIER
# 	| postfix_expression '++'
# 	| postfix_expression '--'
# 	;
#
# argument_expression_list
# 	: assignment_expression
# 	| argument_expression_list ',' assignment_expression
# 	;
#
# unary_expression
# 	: postfix_expression
# 	| '++' unary_expression
# 	| '--' unary_expression
# 	| unary_operator unary_expression
# 	| 'sizeof' unary_expression
# 	| 'sizeof' '(' type_name ')'
# 	;
#
# unary_operator
# 	: '&'
# 	| '*'
# 	| '+'
# 	| '-'
# 	| '~'
# 	| '!'
# 	;
#
# multiplicative_expression
# 	: unary_expression
# 	| multiplicative_expression '*' unary_expression
# 	| multiplicative_expression '/' unary_expression
# 	| multiplicative_expression '%' unary_expression
# 	;
#
# additive_expression
# 	: multiplicative_expression
# 	| additive_expression '+' multiplicative_expression
# 	| additive_expression '-' multiplicative_expression
# 	;
#
# shift_expression
# 	: additive_expression
# 	| shift_expression '<<' additive_expression
# 	| shift_expression '>>' additive_expression
# 	;
#
# relational_expression
# 	: shift_expression
# 	| relational_expression '<' shift_expression
# 	| relational_expression '>' shift_expression
# 	| relational_expression '<=' shift_expression
# 	| relational_expression '>=' shift_expression
# 	;
#
# equality_expression
# 	: relational_expression
# 	| equality_expression '==' relational_expression
# 	| equality_expression '!=' relational_expression
# 	;
#
# and_expression
# 	: equality_expression
# 	| and_expression '&' equality_expression
# 	;
#
# exclusive_or_expression
# 	: and_expression
# 	| exclusive_or_expression '^' and_expression
# 	;
#
# inclusive_or_expression
# 	: exclusive_or_expression
# 	| inclusive_or_expression '|' exclusive_or_expression
# 	;
#
# logical_and_expression
# 	: inclusive_or_expression
# 	| logical_and_expression '&&' inclusive_or_expression
# 	;
#
# logical_or_expression
# 	: logical_and_expression
# 	| logical_or_expression '||' logical_and_expression
# 	;
#
# conditional_expression
# 	: logical_or_expression
# 	| logical_or_expression '?' expression ':' conditional_expression
# 	;
#
# assignment_expression
# 	: conditional_expression
# 	| unary_expression assignment_operator assignment_expression
# 	;
#
# assignment_operator
# 	: '='
# 	| '*='
# 	| '/='
# 	| '%='
# 	| '+='
# 	| '-='
# 	| '<<='
# 	| '>>='
# 	| '&='
# 	| '^='
# 	| '|='
# 	;
#
# expression
# 	: assignment_expression
# 	| expression ',' assignment_expression
# 	;
#
# constant_expression
# 	: conditional_expression
# 	;
#
# declaration
# 	: declaration_specifiers ';'
# 	| declaration_specifiers init_declarator_list ';'
# 	;
#
# declaration_specifiers
# 	: storage_class_specifier
# 	| storage_class_specifier declaration_specifiers
# 	| type_specifier
# 	| type_specifier declaration_specifiers
# 	| type_qualifier
# 	| type_qualifier declaration_specifiers
# 	;
#
# init_declarator_list
# 	: init_declarator
# 	| init_declarator_list ',' init_declarator
# 	;
#
# init_declarator
# 	: declarator
# 	| declarator '=' initializer
# 	;
#
# storage_class_specifier
# 	: 'typedef'
# 	| 'extern'
# 	| 'static'
# 	| 'auto'
# 	| 'register'
# 	;
#
# type_specifier
# 	: 'void'
# 	| 'char'
# 	| 'short'
# 	| 'int'
# 	| 'long'
# 	| 'float'
# 	| 'double'
# 	| 'signed'
# 	| 'unsigned'
# 	| struct_or_union_specifier
# 	| enum_specifier
# 	| TYPE_NAME
# 	;
#
# struct_or_union_specifier
# 	: struct_or_union IDENTIFIER '{' struct_declaration_list '}'
# 	| struct_or_union '{' struct_declaration_list '}'
# 	| struct_or_union IDENTIFIER
# 	;
#
# struct_or_union
# 	: 'struct'
# 	| 'union'
# 	;
#
# struct_declaration_list
# 	: struct_declaration
# 	| struct_declaration_list struct_declaration
# 	;
#
# struct_declaration
# 	: specifier_qualifier_list struct_declarator_list ';'
# 	;
#
# specifier_qualifier_list
# 	: type_specifier specifier_qualifier_list
# 	| type_specifier
# 	| type_qualifier specifier_qualifier_list
# 	| type_qualifier
# 	;
#
# struct_declarator_list
# 	: struct_declarator
# 	| struct_declarator_list ',' struct_declarator
# 	;
#
# struct_declarator
# 	: declarator
# 	| ':' constant_expression
# 	| declarator ':' constant_expression
# 	;
#
# enum_specifier
# 	: 'enum' '{' enumerator_list '}'
# 	| 'enum' IDENTIFIER '{' enumerator_list '}'
# 	| 'enum' IDENTIFIER
# 	;
#
# enumerator_list
# 	: enumerator
# 	| enumerator_list ',' enumerator
# 	;
#
# enumerator
# 	: IDENTIFIER
# 	| IDENTIFIER '=' constant_expression
# 	;
#
# type_qualifier
# 	: 'const'
# 	| 'volatile'
# 	;
#
# declarator
# 	: pointer direct_declarator
# 	| direct_declarator
# 	;
#
# direct_declarator
# 	: IDENTIFIER
# 	| '(' declarator ')'
# 	| direct_declarator '[' constant_expression ']'
# 	| direct_declarator '[' ']'
# 	| direct_declarator '(' parameter_type_list ')'
# 	| direct_declarator '(' identifier_list ')'
# 	| direct_declarator '(' ')'
# 	;
#
# pointer
# 	: '*'
# 	| '*' type_qualifier_list
# 	| '*' pointer
# 	| '*' type_qualifier_list pointer
# 	;
#
# type_qualifier_list
# 	: type_qualifier
# 	| type_qualifier_list type_qualifier
# 	;
#
#
# parameter_type_list
# 	: parameter_list
# 	| parameter_list ',' '...'
# 	;
#
# parameter_list
# 	: parameter_declaration
# 	| parameter_list ',' parameter_declaration
# 	;
#
# parameter_declaration
# 	: declaration_specifiers declarator
# 	| declaration_specifiers abstract_declarator
# 	| declaration_specifiers
# 	;
#
# identifier_list
# 	: IDENTIFIER
# 	| identifier_list ',' IDENTIFIER
# 	;
#
# type_name
# 	: specifier_qualifier_list
# 	| specifier_qualifier_list abstract_declarator
# 	;
#
# abstract_declarator
# 	: pointer
# 	| direct_abstract_declarator
# 	| pointer direct_abstract_declarator
# 	;
#
# direct_abstract_declarator
# 	: '(' abstract_declarator ')'
# 	| '[' ']'
# 	| '[' constant_expression ']'
# 	| direct_abstract_declarator '[' ']'
# 	| direct_abstract_declarator '[' constant_expression ']'
# 	| '(' ')'
# 	| '(' parameter_type_list ')'
# 	| direct_abstract_declarator '(' ')'
# 	| direct_abstract_declarator '(' parameter_type_list ')'
# 	;
#
# initializer
# 	: assignment_expression
# 	| '{' initializer_list '}'
# 	| '{' initializer_list ',' '}'
# 	;
#
# initializer_list
# 	: initializer
# 	| initializer_list ',' initializer
# 	;
#
# statement
# 	: labeled_statement
# 	| compound_statement
# 	| expression_statement
# 	| selection_statement
# 	| iteration_statement
# 	| jump_statement
# 	;
#
# labeled_statement
# 	: IDENTIFIER ':' statement
# 	| 'case' constant_expression ':' statement
# 	| 'default' ':' statement
# 	;
#
# compound_statement
# 	: '{' '}'
# 	| '{' statement_list '}'
# 	| '{' declaration_list '}'
# 	| '{' declaration_list statement_list '}'
# 	;
#
# declaration_list
# 	: declaration
# 	| declaration_list declaration
# 	;
#
# statement_list
# 	: statement
# 	| statement_list statement
# 	;
#
# expression_statement
# 	: ';'
# 	| expression ';'
# 	;
#
# selection_statement
# 	: 'if' '(' expression ')' statement
# 	| 'if' '(' expression ')' statement 'else' statement
# 	| 'switch' '(' expression ')' statement
# 	;
#
# iteration_statement
# 	: 'while' '(' expression ')' statement
# 	| 'do' statement 'while' '(' expression ')' ';'
# 	| 'for' '(' expression_statement expression_statement ')' statement
# 	| 'for' '(' expression_statement expression_statement expression ')' statement
# 	;
#
# jump_statement
# 	: 'goto' IDENTIFIER ';'
# 	| 'continue' ';'
# 	| 'break' ';'
# 	| 'return' ';'
# 	| 'return' expression ';'
# 	;
#
# translation_unit
# 	: external_declaration
# 	| translation_unit external_declaration
# 	;
#
# external_declaration
# 	: function_definition
# 	| declaration
# 	;
#
# function_definition
# 	: declaration_specifiers declarator declaration_list compound_statement
# 	| declaration_specifiers declarator compound_statement
# 	| declarator declaration_list compound_statement
# 	| declarator compound_statement
# 	;

# %% [markdown]
# We use <span style="font-variant:small-caps;">Antlr</span> to develop a parser for context free grammars.  The pure grammar used to parse context free grammars is stored in the file `Pure.g4`.  It is similar to the grammar that we have already used to implement *Earley's algorithm*, but allows additionally the use of the operator `|`, so that all grammar rules that define a variable can be combined in one rule.

# %%
# !cat Pure.g4
# Out:
# grammar Grammar;
#
# start: grmrl+;
#
# grmrl: VARIABLE ':' body ('|' body)* ';';
#
# body: item* ;
#
# item : VARIABLE
#      | TOKEN
#      | LITERAL
#      ;
#
# VARIABLE: [a-z][a-z_]*;
# TOKEN   : [A-Z][A_Z_]*;
# LITERAL : '\'' ~('\'')+ '\'';
#
# WS      : [ \t\n\r]     -> skip ;
# COMMENT : '//' ~('\n')* -> skip ;

# %% [markdown]
# The annotated grammar is stored in the file `Grammar.g4`.
# The parser will return a list of grammar rules, where each rule of the form
# $$ a \rightarrow \beta $$
# is stored as the tuple `(a,) + 𝛽`.

# %%
# !cat -n Grammar.g4
# Out:
#      1	grammar Grammar;
#      2
#      3	start returns [g]
#      4	    : {Rules = []}
#      5	      (grmrl {Rules += $grmrl.rl})+
#      6	      {$g = Rules}
#      7	    ;
#      8
#      9	grmrl returns [rl]
#     10	    : {RuleList = []}
#     11	      v=VARIABLE ':' b1=body {RuleList.append(($v.text,) + $b1.il)}
#     12	      ('|' b2=body {RuleList.append(($v.text,) + $b2.il)})* ';'
#     13	      {$rl = RuleList}
#     14	    ;
#     15
#     16	body returns [il]
#     17	    : {Body = []} (i=item {Body.append($i.atom)})*
#     18	      {$il = tuple(Body)}
#     19	    ;
#     20
#     21	item returns [atom]
#     22	    : v=VARIABLE {$atom = $v.text}
#     23	    | t=TOKEN    {$atom = $t.text}
#     24	    | l=LITERAL  {$atom = $l.text}
#     25	    ;
#     26
#     27	VARIABLE: [a-z][a-z_]*;
#     28	TOKEN   : [A-Z][A-Z_]*;
#     29	LITERAL : '\'' ~('\'')+ '\'';
#     30
#     31	WS      : [ \t\n\r]     -> skip ;
#     32	COMMENT : '//' ~('\n')* -> skip ;

# %% [markdown]
# We start by generating both scanner and parser.

# %%
# !antlr4 -Dlanguage=Python3 Grammar.g4

# %%
from GrammarLexer  import GrammarLexer
from GrammarParser import GrammarParser
import antlr4

# %% [markdown]
# ## The Class `GrammarRule`

# %% [markdown]
# The class `GrammarRule` is used to store a single grammar rule.  As we have to use objects of type `GrammarRule` as keys in a dictionary later, we have to provide the methods `__eq__`, `__ne__`, and `__hash__`.

# %%
class GrammarRule:
    def __init__(self, variable, body):
        self.mVariable = variable
        self.mBody     = body
        
    def __eq__(self, other):
        return isinstance(other, GrammarRule)    and \
               self.mVariable == other.mVariable and \
               self.mBody     == other.mBody
    
    def __ne__(self, other):
        return not self.__eq__(other)
    
    def __hash__(self):
        return hash(self.__repr__())
    
    def __repr__(self):
        return f'{self.mVariable} → {" ".join(self.mBody)}'

# %% [markdown]
# The function `parse_grammar` takes a string `filename` as its argument and returns the grammar that is stored in the specified file.  The grammar is represented as list of rules.  Each rule is represented as a tuple.  The example below will clarify this structure.

# %%
def parse_grammar(filename):
    input_stream  = antlr4.FileStream(filename, encoding="utf-8")
    lexer         = GrammarLexer(input_stream)
    token_stream  = antlr4.CommonTokenStream(lexer)
    parser        = GrammarParser(token_stream)
    grammar       = parser.start()
    return [GrammarRule(head, tuple(body)) for head, *body in grammar.g]

# %%
grammar = parse_grammar('Examples/c-grammar.g')
grammar
# Out:
# [primary_expression → IDENTIFIER,
#  primary_expression → CONSTANT,
#  primary_expression → STRING_LITERAL,
#  primary_expression → '(' expression ')',
#  postfix_expression → primary_expression,
#  postfix_expression → postfix_expression '[' expression ']',
#  postfix_expression → postfix_expression '(' ')',
#  postfix_expression → postfix_expression '(' argument_expression_list ')',
#  postfix_expression → postfix_expression '.' IDENTIFIER,
#  postfix_expression → postfix_expression '->' IDENTIFIER,
#  postfix_expression → postfix_expression '++',
#  postfix_expression → postfix_expression '--',
#  argument_expression_list → assignment_expression,
#  argument_expression_list → argument_expression_list ',' assignment_expression,
#  unary_expression → postfix_expression,
#  unary_expression → '++' unary_expression,
#  unary_expression → '--' unary_expression,
#  unary_expression → unary_operator unary_expression,
#  unary_expression → 'sizeof' unary_expression,
#  unary_expression → 'sizeof' '(' type_name ')',
#  unary_operator → '&',
#  unary_operator → '*',
#  unary_operator → '+',
#  unary_operator → '-',
#  unary_operator → '~',
#  unary_operator → '!',
#  multiplicative_expression → unary_expression,
#  multiplicative_expression → multiplicative_expression '*' unary_expression,
#  multiplicative_expression → multiplicative_expression '/' unary_expression,
#  multiplicative_expression → multiplicative_expression '%' unary_expression,
#  additive_expression → multiplicative_expression,
#  additive_expression → additive_expression '+' multiplicative_expression,
#  additive_expression → additive_expression '-' multiplicative_expression,
#  shift_expression → additive_expression,
#  shift_expression → shift_expression '<<' additive_expression,
#  shift_expression → shift_expression '>>' additive_expression,
#  relational_expression → shift_expression,
#  relational_expression → relational_expression '<' shift_expression,
#  relational_expression → relational_expression '>' shift_expression,
#  relational_expression → relational_expression '<=' shift_expression,
#  relational_expression → relational_expression '>=' shift_expression,
#  equality_expression → relational_expression,
#  equality_expression → equality_expression '==' relational_expression,
#  equality_expression → equality_expression '!=' relational_expression,
#  and_expression → equality_expression,
#  and_expression → and_expression '&' equality_expression,
#  exclusive_or_expression → and_expression,
#  exclusive_or_expression → exclusive_or_expression '^' and_expression,
#  inclusive_or_expression → exclusive_or_expression,
#  inclusive_or_expression → inclusive_or_expression '|' exclusive_or_expression,
#  logical_and_expression → inclusive_or_expression,
#  logical_and_expression → logical_and_expression '&&' inclusive_or_expression,
#  logical_or_expression → logical_and_expression,
#  logical_or_expression → logical_or_expression '||' logical_and_expression,
#  conditional_expression → logical_or_expression,
#  conditional_expression → logical_or_expression '?' expression ':' conditional_expression,
#  assignment_expression → conditional_expression,
#  assignment_expression → unary_expression assignment_operator assignment_expression,
#  assignment_operator → '=',
#  assignment_operator → '*=',
#  assignment_operator → '/=',
#  assignment_operator → '%=',
#  assignment_operator → '+=',
#  assignment_operator → '-=',
#  assignment_operator → '<<=',
#  assignment_operator → '>>=',
#  assignment_operator → '&=',
#  assignment_operator → '^=',
#  assignment_operator → '|=',
#  expression → assignment_expression,
#  expression → expression ',' assignment_expression,
#  constant_expression → conditional_expression,
#  declaration → declaration_specifiers ';',
#  declaration → declaration_specifiers init_declarator_list ';',
#  declaration_specifiers → storage_class_specifier,
#  declaration_specifiers → storage_class_specifier declaration_specifiers,
#  declaration_specifiers → type_specifier,
#  declaration_specifiers → type_specifier declaration_specifiers,
#  declaration_specifiers → type_qualifier,
#  declaration_specifiers → type_qualifier declaration_specifiers,
#  init_declarator_list → init_declarator,
#  init_declarator_list → init_declarator_list ',' init_declarator,
#  init_declarator → declarator,
#  init_declarator → declarator '=' initializer,
#  storage_class_specifier → 'typedef',
#  storage_class_specifier → 'extern',
#  storage_class_specifier → 'static',
#  storage_class_specifier → 'auto',
#  storage_class_specifier → 'register',
#  type_specifier → 'void',
#  type_specifier → 'char',
#  type_specifier → 'short',
#  type_specifier → 'int',
#  type_specifier → 'long',
#  type_specifier → 'float',
#  type_specifier → 'double',
#  type_specifier → 'signed',
#  type_specifier → 'unsigned',
#  type_specifier → struct_or_union_specifier,
#  type_specifier → enum_specifier,
#  type_specifier → TYPE_NAME,
#  struct_or_union_specifier → struct_or_union IDENTIFIER '{' struct_declaration_list '}',
#  struct_or_union_specifier → struct_or_union '{' struct_declaration_list '}',
#  struct_or_union_specifier → struct_or_union IDENTIFIER,
#  struct_or_union → 'struct',
#  struct_or_union → 'union',
#  struct_declaration_list → struct_declaration,
#  struct_declaration_list → struct_declaration_list struct_declaration,
#  struct_declaration → specifier_qualifier_list struct_declarator_list ';',
#  specifier_qualifier_list → type_specifier specifier_qualifier_list,
#  specifier_qualifier_list → type_specifier,
#  specifier_qualifier_list → type_qualifier specifier_qualifier_list,
#  specifier_qualifier_list → type_qualifier,
#  struct_declarator_list → struct_declarator,
#  struct_declarator_list → struct_declarator_list ',' struct_declarator,
#  struct_declarator → declarator,
#  struct_declarator → ':' constant_expression,
#  struct_declarator → declarator ':' constant_expression,
#  enum_specifier → 'enum' '{' enumerator_list '}',
#  enum_specifier → 'enum' IDENTIFIER '{' enumerator_list '}',
#  enum_specifier → 'enum' IDENTIFIER,
#  enumerator_list → enumerator,
#  enumerator_list → enumerator_list ',' enumerator,
#  enumerator → IDENTIFIER,
#  enumerator → IDENTIFIER '=' constant_expression,
#  type_qualifier → 'const',
#  type_qualifier → 'volatile',
#  declarator → pointer direct_declarator,
#  declarator → direct_declarator,
#  direct_declarator → IDENTIFIER,
#  direct_declarator → '(' declarator ')',
#  direct_declarator → direct_declarator '[' constant_expression ']',
#  direct_declarator → direct_declarator '[' ']',
#  direct_declarator → direct_declarator '(' parameter_type_list ')',
#  direct_declarator → direct_declarator '(' identifier_list ')',
#  direct_declarator → direct_declarator '(' ')',
#  pointer → '*',
#  pointer → '*' type_qualifier_list,
#  pointer → '*' pointer,
#  pointer → '*' type_qualifier_list pointer,
#  type_qualifier_list → type_qualifier,
#  type_qualifier_list → type_qualifier_list type_qualifier,
#  parameter_type_list → parameter_list,
#  parameter_type_list → parameter_list ',' '...',
#  parameter_list → parameter_declaration,
#  parameter_list → parameter_list ',' parameter_declaration,
#  parameter_declaration → declaration_specifiers declarator,
#  parameter_declaration → declaration_specifiers abstract_declarator,
#  parameter_declaration → declaration_specifiers,
#  identifier_list → IDENTIFIER,
#  identifier_list → identifier_list ',' IDENTIFIER,
#  type_name → specifier_qualifier_list,
#  type_name → specifier_qualifier_list abstract_declarator,
#  abstract_declarator → pointer,
#  abstract_declarator → direct_abstract_declarator,
#  abstract_declarator → pointer direct_abstract_declarator,
#  direct_abstract_declarator → '(' abstract_declarator ')',
#  direct_abstract_declarator → '[' ']',
#  direct_abstract_declarator → '[' constant_expression ']',
#  direct_abstract_declarator → direct_abstract_declarator '[' ']',
#  direct_abstract_declarator → direct_abstract_declarator '[' constant_expression ']',
#  direct_abstract_declarator → '(' ')',
#  direct_abstract_declarator → '(' parameter_type_list ')',
#  direct_abstract_declarator → direct_abstract_declarator '(' ')',
#  direct_abstract_declarator → direct_abstract_declarator '(' parameter_type_list ')',
#  initializer → assignment_expression,
#  initializer → '{' initializer_list '}',
#  initializer → '{' initializer_list ',' '}',
#  initializer_list → initializer,
#  initializer_list → initializer_list ',' initializer,
#  statement → labeled_statement,
#  statement → compound_statement,
#  statement → expression_statement,
#  statement → selection_statement,
#  statement → iteration_statement,
#  statement → jump_statement,
#  labeled_statement → IDENTIFIER ':' statement,
#  labeled_statement → 'case' constant_expression ':' statement,
#  labeled_statement → 'default' ':' statement,
#  compound_statement → '{' '}',
#  compound_statement → '{' statement_list '}',
#  compound_statement → '{' declaration_list '}',
#  compound_statement → '{' declaration_list statement_list '}',
#  declaration_list → declaration,
#  declaration_list → declaration_list declaration,
#  statement_list → statement,
#  statement_list → statement_list statement,
#  expression_statement → ';',
#  expression_statement → expression ';',
#  selection_statement → 'if' '(' expression ')' statement,
#  selection_statement → 'if' '(' expression ')' statement 'else' statement,
#  selection_statement → 'switch' '(' expression ')' statement,
#  iteration_statement → 'while' '(' expression ')' statement,
#  iteration_statement → 'do' statement 'while' '(' expression ')' ';',
#  iteration_statement → 'for' '(' expression_statement expression_statement ')' statement,
#  iteration_statement → 'for' '(' expression_statement expression_statement expression ')' statement,
#  jump_statement → 'goto' IDENTIFIER ';',
#  jump_statement → 'continue' ';',
#  jump_statement → 'break' ';',
#  jump_statement → 'return' ';',
#  jump_statement → 'return' expression ';',
#  translation_unit → external_declaration,
#  translation_unit → translation_unit external_declaration,
#  external_declaration → function_definition,
#  external_declaration → declaration,
#  function_definition → declaration_specifiers declarator declaration_list compound_statement,
#  function_definition → declaration_specifiers declarator compound_statement,
#  function_definition → declarator declaration_list compound_statement,
#  function_definition → declarator compound_statement]

# %% [markdown]
# Given a string `name`, which is either a *variable*, a *token*, or a *literal*, the function `is_var` checks whether `name` is a variable.  The function can distinguish variable names from tokens and literals because variable names consist only of lower case letters, while tokens are all uppercase and literals start with the character "`'`".

# %%
def is_var(name):
    return name[0] != "'" and name.islower()

# %% [markdown]
# **Fun Fact:** The invocation of `"'return'".islower()` returns `True`.  This is the reason that we have to test that
# `name` does not start with a `"'"` character because otherwise keywords like `'return'` or `'while'` appearing in a grammar would be mistaken for variables.

# %%
"'return'".islower()
# Out:
# True

# %% [markdown]
# Given a list `Rules` of `GrammarRules`, the function `collect_variables(Rules)` returns the set of all *variables* occuring in `Rules`.

# %%
def collect_variables(Rules):
    Variables = set()
    for rule in Rules:
        Variables.add(rule.mVariable)
        for item in rule.mBody:
            if is_var(item):
                Variables.add(item)
    return Variables

# %% [markdown]
# Given a set `Rules` of `GrammarRules`, the function `collect_tokens(Rules)` returns the set of all *tokens* and *literals* occuring in `Rules`.

# %%
def collect_tokens(Rules):
    Tokens = set()
    for rule in Rules:
        for item in rule.mBody:
            if not is_var(item):
                Tokens.add(item)
    return Tokens

# %% [markdown]
# ## Marked Rules

# %% [markdown]
# The class `MarkedRule` stores a single *marked rule* of the form
# $$ v \rightarrow \alpha \bullet \beta $$
# where the *variable* $v$ is stored in the member variable `mVariable`, while $\alpha$ and $\beta$ are stored in the variables `mAlpha`and `mBeta` respectively.  These variables are assumed to contain tuples of *grammar symbols*.  A *grammar symbol* is either
# - a *variable*,
# - a *token*, or
# - a *literal*, i.e. a string enclosed in single quotes.
#
#
# Later, we need to maintain sets of *marked rules* to represent *states*.  Therefore, we have to define the methods `__eq__`, `__ne__`, and `__hash__`.

# %%
class MarkedRule():
    def __init__(self, variable, alpha, beta):
        self.mVariable = variable
        self.mAlpha    = alpha
        self.mBeta     = beta
        
    def __eq__(self, other):
        return isinstance(other, MarkedRule)     and \
               self.mVariable == other.mVariable and \
               self.mAlpha    == other.mAlpha    and \
               self.mBeta     == other.mBeta
    
    def __ne__(self, other):
        return not self.__eq__(other)
    
    def __hash__(self):
        return hash(self.__repr__())
    
    def __repr__(self):
        alphaStr = ' '.join(self.mAlpha)
        betaStr  = ' '.join(self.mBeta)
        return f'{self.mVariable} → {alphaStr} • {betaStr}'

# %% [markdown]
# Given a *marked rule* `self`, the function `is_complete` checks, whether the *marked rule* `self` has the form
# $$ c \rightarrow \alpha\; \bullet,$$
# i.e. it checks, whether the $\bullet$ is at the end of the grammar rule.

# %%
def is_complete(self):
    return len(self.mBeta) == 0

MarkedRule.is_complete = is_complete
del is_complete

# %% [markdown]
# Given a *marked rule* `self` of the form
# $$ c \rightarrow \alpha \bullet X\, \delta, $$
# the function `symbol_after_dot` returns the *symbol* $X$. If there is no symbol after the $\bullet$, the method returns `None`.

# %%
def symbol_after_dot(self):
    if len(self.mBeta) > 0:
        return self.mBeta[0]
    return None

MarkedRule.symbol_after_dot = symbol_after_dot
del symbol_after_dot

# %% [markdown]
# Given a marked rule, this function returns the variable following the dot.  If there is no variable following the dot, the function returns `None`.

# %%
def next_var(self):
    if len(self.mBeta) > 0:
        var = self.mBeta[0]
        if is_var(var):
            return var
    return None

MarkedRule.next_var = next_var
del next_var

# %% [markdown]
# The function `move_dot(self)` transforms a *marked rule*  of the form
# $$ c \rightarrow \alpha \bullet X\, \beta $$
# into a *marked rule* of the form
# $$ c \rightarrow \alpha\, X \bullet \beta, $$
# i.e. the $\bullet$ is moved over the next symbol.  Invocation of this method assumes that there is a symbol
# following the $\bullet$.

# %%
def move_dot(self):
    return MarkedRule(self.mVariable, 
                      self.mAlpha + (self.mBeta[0],), 
                      self.mBeta[1:])

MarkedRule.move_dot = move_dot
del move_dot

# %% [markdown]
# The function `to_rule(self)` turns the *marked rule* `self` into  a `GrammarRule`, i.e. the *marked rule*
# $$ c \rightarrow \alpha \bullet \beta $$
# is turned into the grammar rule
# $$ c \rightarrow \alpha\, \beta. $$

# %%
def to_rule(self):
    return GrammarRule(self.mVariable, self.mAlpha + self.mBeta)

MarkedRule.to_rule = to_rule
del to_rule

# %% [markdown]
# ## SLR-Table-Generation

# %% [markdown]
# The class `Grammar` represents a context free grammar.  It stores a list of the `GrammarRules` of the given grammar.
# Each grammar rule is of the form
# $$ a \rightarrow \beta $$
# where $\beta$ is a tuple of variables, tokens, and literals.
# The start symbol is assumed to be the variable on the left hand side of the first rule. The grammar is *augmented* with the rule
# $$ \widehat{s} \rightarrow s\, \$. $$
# Here $s$ is the start variable of the given grammar and $\widehat{s}$ is a new variable that is the start variable of the *augmented grammar*. The symbol `$` denotes the end of input.  The non-obvious member variables of the class `Grammar` have the following interpretation
# - `mStates` is the set of all states of the *SLR-parser*.  These states are sets of *marked rules*.
# - `mStateNames`is a dictionary assigning names of the form `s0`, `s1`, $\cdots$, `sn` to the states stored in
#   `mStates`.  The functions `action` and `goto` will be defined for *state names*, not for *states*, because
#   otherwise the table representing these functions would become both huge and unreadable.
# - `mConflicts` is a Boolean variable that will be set to true if the table generation discovers
#   *shift/reduce conflicts* or *reduce/reduce conflicts*.

# %%
class Grammar():
    def __init__(self, Rules):
        self.mRules      = Rules
        self.mStart      = Rules[0].mVariable
        self.mVariables  = collect_variables(Rules)
        self.mTokens     = collect_tokens(Rules)
        self.mStates     = set()
        self.mStateNames = {}
        self.mConflicts  = False
        self.mVariables.add('ŝ')
        self.mTokens.add('$')
        self.mRules.append(GrammarRule('ŝ', (self.mStart, '$'))) # augmenting
        self.compute_tables()

# %% [markdown]
# Given a set of `Variables`, the function `initialize_dictionary` returns a dictionary that assigns the empty set to all variables.

# %%
def initialize_dictionary(Variables):
    return { a: set() for a in Variables }

# %% [markdown]
# Given a `Grammar`, the function `compute_tables` computes
# - the sets `First(v)` and `Follow(v)` for every variable `v`,
# - the set of all *states* of the *SLR-Parser*,
# - the *action table*, and
# - the *goto table*.
#
# Given a grammar `g`,
# - the set `g.mFirst` is a dictionary such that `g.mFirst[a] = First[a]` and
# - the set `g.mFollow` is a dictionary such that `g.mFollow[a] = Follow[a]` for all variables `a`.

# %%
def compute_tables(self):
    self.mFirst  = initialize_dictionary(self.mVariables)
    self.mFollow = initialize_dictionary(self.mVariables)
    self.compute_first()
    self.compute_follow()
    self.compute_rule_names()
    self.all_states()
    self.compute_action_table()
    self.compute_goto_table()
    
Grammar.compute_tables = compute_tables
del compute_tables

# %% [markdown]
# The function `compute_rule_names` assigns a unique name to each *rule* of the grammar.  These names are used later
# to represent *reduce actions* in the *action table*.

# %%
def compute_rule_names(self):
    self.mRuleNames = {}
    counter = 0
    for rule in self.mRules:
        self.mRuleNames[rule] = 'r' + str(counter)
        counter += 1
        
Grammar.compute_rule_names = compute_rule_names
del compute_rule_names

# %% [markdown]
# The function `compute_first(self)` computes the sets $\texttt{First}(c)$ for all variables $c$ and stores them in the dictionary `mFirst`.  Abstractly, given a variable $c$ the function $\texttt{First}(c)$ is the set of all tokens that can start a string that is derived from $c$:
# $$\texttt{First}(\texttt{c}) :=
#   \Bigl\{ t \in T \Bigm| \exists \gamma \in (V \cup T)^*: \texttt{c} \Rightarrow^* t\,\gamma \Bigr\}.
# $$
# The definition of the function $\texttt{First}()$ is extended to strings from $(V \cup T)^*$ as follows:
# - $\texttt{FirstList}(\varepsilon) = \{\}$.
# - $\texttt{FirstList}(t \beta) = \{ t \}$  if $t \in T$.
# - $\texttt{FirstList}(\texttt{a} \beta) = \left\{
#        \begin{array}[c]{ll}
#          \texttt{First}(\texttt{a}) \cup \texttt{FirstList}(\beta) & \mbox{if $\texttt{a} \Rightarrow^* \varepsilon$;} \\
#          \texttt{First}(\texttt{a})                                & \mbox{otherwise.}
#        \end{array}
#        \right.
#       $
#
# If $\texttt{a}$ is a variable of $G$ and the rules defining $\texttt{a}$ are given as
# $$\texttt{a} \rightarrow \alpha_1 \mid \cdots \mid \alpha_n, $$
# then we have
# $$\texttt{First}(\texttt{a}) = \bigcup\limits_{i=1}^n \texttt{FirstList}(\alpha_i). $$
# The dictionary `mFirst` that stores this function is computed via a *fixed point iteration*.

# %%
def compute_first(self):
    change = True
    while change:
        change = False
        for rule in self.mRules:
            a, body = rule.mVariable, rule.mBody
            first_body = self.first_list(body)
            if not (first_body <= self.mFirst[a]):
                change = True
                self.mFirst[a] |= first_body           
    print('First sets:')
    for v in self.mVariables:
        print(f'First({v}) = {self.mFirst[v]}')
        
Grammar.compute_first = compute_first
del compute_first

# %% [markdown]
# Given a tuple of variables and tokens `alpha`, the function `first_list(alpha)` computes the function $\texttt{FirstList}(\alpha)$ that has been defined above.  If `alpha` is *nullable*, then the result will contain the empty string $\varepsilon = \texttt{''}$.

# %%
def first_list(self, alpha):
    if len(alpha) == 0:
        return { '' }
    elif is_var(alpha[0]): 
        v, *r = alpha
        return eps_union(self.mFirst[v], self.first_list(r))
    else:
        t = alpha[0]
        return { t }
    
Grammar.first_list = first_list
del first_list

# %% [markdown]
# The arguments `S` and `T` of `eps_union` are sets that contain tokens and, additionally, they might contain the empty string.

# %%
def eps_union(S, T):
    if '' in S: 
        if '' in T: 
            return S | T
        return (S - { '' }) | T
    return S

# %% [markdown]
# Given an augmented grammar $G = \langle V,T,R\cup\{\widehat{s} \rightarrow s\,\$\}, \widehat{s}\rangle$
# and a variable $a$, the set of tokens that might follow $a$ is defined as:
# $$\texttt{Follow}(a) :=
#  \bigl\{ t \in \widehat{T} \,\bigm|\, \exists \beta,\gamma \in (V \cup \widehat{T})^*:
#                            \widehat{s} \Rightarrow^* \beta \,a\, t\, \gamma
#   \bigr\}.
# $$
# The function `compute_follow` computes the sets $\texttt{Follow}(a)$ for all variables $a$ via a *fixed-point iteration*.

# %%
def compute_follow(self):
    self.mFollow[self.mStart] = { '$' }
    change = True
    while change:
        change = False
        for rule in self.mRules:
            a, body = rule.mVariable, rule.mBody
            for i in range(len(body)):
                if is_var(body[i]):
                    yi        = body[i]
                    Tail      = self.first_list(body[i+1:])
                    firstTail = eps_union(Tail, self.mFollow[a])
                    if not (firstTail <= self.mFollow[yi]): 
                        change = True
                        self.mFollow[yi] |= firstTail  
    print('Follow sets (note that "$" denotes the end of file):');
    for v in self.mVariables:
        print(f'Follow({v}) = {self.mFollow[v]}')
        
Grammar.compute_follow = compute_follow
del compute_follow

# %% [markdown]
# If $\mathcal{M}$ is a set of *marked rules*, then the *closure* of $\mathcal{M}$ is the smallest set $\mathcal{K}$ such that
# we have the following:
# - $\mathcal{M} \subseteq \mathcal{K}$,
# - If $a \rightarrow \beta \bullet c\, \delta$ is a *marked rule* from
#   $\mathcal{K}$, and $c$ is a variable and if, furthermore,
#   $c \rightarrow \gamma$ is a grammar rule,
#   then the marked rule $c \rightarrow \bullet \gamma$
#   is an element of $\mathcal{K}$:
#   $$(a \rightarrow \beta \bullet c\, \delta) \in \mathcal{K}
#          \;\wedge\;
#          (c \rightarrow \gamma) \in R
#          \;\Rightarrow\; (c \rightarrow \bullet \gamma) \in \mathcal{K}
#   $$
#
# We define $\texttt{closure}(\mathcal{M}) := \mathcal{K}$.  The function `cmp_closure` computes this closure for a given set of *marked rules* via a *fixed-point iteration*.

# %%
def cmp_closure(self, Marked_Rules):
    All_Rules = Marked_Rules
    New_Rules = Marked_Rules
    while True:
        More_Rules = set()
        for rule in New_Rules:
            c = rule.next_var()
            if c == None:
                continue
            for rule in self.mRules:
                head, alpha = rule.mVariable, rule.mBody
                if c == head:
                    More_Rules |= { MarkedRule(head, (), alpha) }
        if More_Rules <= All_Rules:
            return frozenset(All_Rules)
        New_Rules  = More_Rules - All_Rules
        All_Rules |= New_Rules

Grammar.cmp_closure = cmp_closure
del cmp_closure

# %% [markdown]
# Given a set of *marked rules* $\mathcal{M}$ and a *grammar symbol* $X$, the function $\texttt{goto}(\mathcal{M}, X)$
# is defined as follows:
# $$\texttt{goto}(\mathcal{M}, X) := \texttt{closure}\Bigl( \bigl\{
#    a \rightarrow \beta\, X \bullet \delta \bigm| (a \rightarrow \beta \bullet X\, \delta) \in \mathcal{M}
#    \bigr\} \Bigr).
# $$

# %%
def goto(self, Marked_Rules, x):
    Result = set()
    for mr in Marked_Rules:
        if mr.symbol_after_dot() == x:
            Result.add(mr.move_dot())
    return self.cmp_closure(Result)

Grammar.goto = goto
del goto

# %% [markdown]
# The function `all_states` computes the set of all states of an *SLR-parser*.  The function starts with the state
# $$ \texttt{closure}\bigl(\{ \widehat{s} \rightarrow \bullet s \, $\}\bigr) $$
# and then tries to compute new states by using the function `goto`.  This computation proceeds via a
# *fixed-point iteration*.  Once all states have been computed, the function assigns names to these states.
# This association is stored in the dictionary *mStateNames*.

# %%
def all_states(self): 
    start_state  = self.cmp_closure({ MarkedRule('ŝ', (), (self.mStart, '$')) })
    self.mStates = { start_state }
    New_States   = self.mStates
    while True:
        More_States = set()
        for Rule_Set in New_States:
            for mr in Rule_Set: 
                if not mr.is_complete():
                    x = mr.symbol_after_dot()
                    More_States |= { self.goto(Rule_Set, x) }
        if More_States <= self.mStates:
            break
        New_States = More_States - self.mStates;
        self.mStates |= New_States
    print("All SLR-states:")
    counter = 1
    self.mStateNames[start_state] = 's0'
    print(f's0 = {set(start_state)}')
    for state in self.mStates - { start_state }:
        self.mStateNames[state] = f's{counter}'
        print(f's{counter} = {set(state)}')
        counter += 1

Grammar.all_states = all_states
del all_states

# %% [markdown]
# The following function computes the *action table* and is defined as follows:
# - If $\mathcal{M}$ contains a *marked rule* of the form $a \rightarrow \beta \bullet t\, \delta$
#   then we have
#   $$\texttt{action}(\mathcal{M},t) := \langle \texttt{shift}, \texttt{goto}(\mathcal{M},t) \rangle.$$
# - If $\mathcal{M}$ contains a marked rule of the form $a \rightarrow \beta\, \bullet$ and we have
#   $t \in \texttt{Follow}(a)$, then we define
#   $$\texttt{action}(\mathcal{M},t) := \langle \texttt{reduce}, a \rightarrow \beta \rangle$$
# - If $\mathcal{M}$ contains the marked rule $\widehat{s} \rightarrow s \bullet \$ $, then we define
#   $$\texttt{action}(\mathcal{M},\$) := \texttt{accept}. $$
# - Otherwise, we have
#   $$\texttt{action}(\mathcal{M},t) := \texttt{error}. $$

# %%
def compute_action_table(self):
    self.mActionTable = {}
    print('\nAction Table:')
    for state in self.mStates:
        stateName = self.mStateNames[state]
        actionTable = {}
        # compute shift actions
        for token in self.mTokens:   
            newState  = self.goto(state, token)
            if newState != set():
                newName = self.mStateNames[newState]
                actionTable[token] = ('shift', newName)
                self.mActionTable[stateName, token] = ('shift', newName)
                print(f'action("{stateName}", {token}) = ("shift", {newName})')
        # compute reduce actions
        for mr in state:
            if mr.is_complete():
                for token in self.mFollow[mr.mVariable]:
                    action1 = actionTable.get(token)
                    action2 = ('reduce', mr.to_rule())
                    if action1 == None:
                        actionTable[token] = action2  
                        r = self.mRuleNames[mr.to_rule()]
                        self.mActionTable[stateName, token] = ('reduce', r)
                        print(f'action("{stateName}", {token}) = {action2}')
                    elif action1 != action2: 
                        self.mConflicts = True
                        print('')
                        print(f'conflict in state {stateName}:')
                        print(f'{stateName} = {state}')
                        print(f'action("{stateName}", {token}) = {action1}')     
                        print(f'action("{stateName}", {token}) = {action2}')
                        print('')
        for mr in state:
            if mr == MarkedRule('ŝ', (self.mStart,), ('$',)):
                actionTable['$'] = 'accept'
                self.mActionTable[stateName, '$'] = 'accept'
                print(f'action("{stateName}", $) = accept')

Grammar.compute_action_table = compute_action_table
del compute_action_table

# %% [markdown]
# The function `compute_goto_table` computes the *goto table*.

# %%
def compute_goto_table(self):
    self.mGotoTable = {}
    print('\nGoto Table:')
    for state in self.mStates:
        for var in self.mVariables:
            newState = self.goto(state, var)
            if newState != set():
                stateName = self.mStateNames[state]
                newName   = self.mStateNames[newState]
                self.mGotoTable[stateName, var] = newName
                print(f'goto({stateName}, {var}) = {newName}')

Grammar.compute_goto_table = compute_goto_table
del compute_goto_table

# %%
# %%time
g = Grammar(grammar)
# Out:
# First sets:
# First(declaration) = {"'static'", "'short'", "'float'", "'void'", "'union'", "'long'", "'auto'", "'enum'", "'volatile'", "'double'", "'typedef'", 'TYPE_NAME', "'const'", "'unsigned'", "'int'", "'extern'", "'struct'", "'char'", "'signed'", "'register'"}
# First(type_specifier) = {"'unsigned'", "'enum'", "'int'", "'float'", "'struct'", "'char'", "'signed'", "'double'", "'short'", "'union'", "'long'", 'TYPE_NAME', "'void'"}
# First(enumerator) = {'IDENTIFIER'}
# First(primary_expression) = {"'('", 'STRING_LITERAL', 'CONSTANT', 'IDENTIFIER'}
# First(relational_expression) = {"'sizeof'", "'('", "'!'", "'++'", 'STRING_LITERAL', "'--'", "'&'", "'-'", 'CONSTANT', "'*'", "'+'", "'~'", 'IDENTIFIER'}
# First(initializer_list) = {"'sizeof'", "'{'", "'('", "'!'", "'++'", 'STRING_LITERAL', "'--'", "'-'", 'CONSTANT', "'+'", "'*'", "'&'", "'~'", 'IDENTIFIER'}
# First(selection_statement) = {"'if'", "'switch'"}
# First(additive_expression) = {"'sizeof'", "'('", "'!'", "'++'", 'STRING_LITERAL', "'--'", "'-'", 'CONSTANT', "'+'", "'*'", "'&'", "'~'", 'IDENTIFIER'}
# First(constant_expression) = {"'sizeof'", "'('", "'!'", "'++'", 'STRING_LITERAL', "'--'", "'~'", "'-'", 'CONSTANT', "'*'", "'+'", "'&'", 'IDENTIFIER'}
# First(argument_expression_list) = {"'sizeof'", "'('", "'!'", "'++'", 'STRING_LITERAL', "'--'", "'&'", "'-'", 'CONSTANT', "'*'", "'+'", "'~'", 'IDENTIFIER'}
# First(function_definition) = {"'('", "'static'", "'short'", "'float'", "'void'", "'union'", "'long'", "'auto'", 'IDENTIFIER', "'enum'", "'volatile'", "'double'", "'typedef'", 'TYPE_NAME', "'const'", "'unsigned'", "'int'", "'extern'", "'struct'", "'char'", "'signed'", "'*'", "'register'"}
# First(exclusive_or_expression) = {"'sizeof'", "'('", "'!'", "'++'", 'STRING_LITERAL', "'--'", "'&'", "'-'", 'CONSTANT', "'*'", "'+'", "'~'", 'IDENTIFIER'}
# First(conditional_expression) = {"'sizeof'", "'('", "'!'", "'++'", 'STRING_LITERAL', "'--'", "'-'", 'CONSTANT', "'+'", "'*'", "'&'", "'~'", 'IDENTIFIER'}
# First(struct_or_union_specifier) = {"'struct'", "'union'"}
# First(iteration_statement) = {"'for'", "'while'", "'do'"}
# First(struct_declaration) = {"'enum'", "'volatile'", "'double'", "'short'", "'float'", 'TYPE_NAME', "'void'", "'unsigned'", "'const'", "'union'", "'int'", "'struct'", "'char'", "'signed'", "'long'"}
# First(compound_statement) = {"'{'"}
# First(inclusive_or_expression) = {"'sizeof'", "'('", "'!'", "'++'", 'STRING_LITERAL', "'--'", "'-'", 'CONSTANT', "'+'", "'*'", "'&'", "'~'", 'IDENTIFIER'}
# First(shift_expression) = {"'sizeof'", "'('", "'!'", "'++'", 'STRING_LITERAL', "'--'", "'~'", "'-'", 'CONSTANT', "'*'", "'+'", "'&'", 'IDENTIFIER'}
# First(type_qualifier_list) = {"'volatile'", "'const'"}
# First(struct_declarator_list) = {"'*'", "'('", "':'", 'IDENTIFIER'}
# First(expression_statement) = {"'sizeof'", "';'", "'('", "'!'", "'++'", 'STRING_LITERAL', "'--'", "'-'", 'CONSTANT', "'+'", "'*'", "'&'", "'~'", 'IDENTIFIER'}
# First(unary_expression) = {"'sizeof'", "'~'", "'-'", 'CONSTANT', "'('", "'!'", "'++'", 'STRING_LITERAL', "'--'", "'*'", "'+'", "'&'", 'IDENTIFIER'}
# First(direct_declarator) = {"'('", 'IDENTIFIER'}
# First(parameter_type_list) = {"'static'", "'short'", "'float'", "'void'", "'union'", "'long'", "'auto'", "'enum'", "'volatile'", "'double'", "'typedef'", 'TYPE_NAME', "'const'", "'unsigned'", "'int'", "'extern'", "'struct'", "'char'", "'signed'", "'register'"}
# First(declarator) = {"'('", "'*'", 'IDENTIFIER'}
# First(direct_abstract_declarator) = {"'('", "'['"}
# First(type_qualifier) = {"'volatile'", "'const'"}
# First(jump_statement) = {"'continue'", "'return'", "'goto'", "'break'"}
# First(unary_operator) = {"'-'", "'+'", "'*'", "'&'", "'~'", "'!'"}
# First(declaration_list) = {"'static'", "'short'", "'float'", "'void'", "'union'", "'long'", "'auto'", "'enum'", "'volatile'", "'double'", "'typedef'", 'TYPE_NAME', "'const'", "'unsigned'", "'int'", "'extern'", "'struct'", "'char'", "'signed'", "'register'"}
# First(specifier_qualifier_list) = {"'enum'", "'volatile'", "'double'", "'short'", "'float'", 'TYPE_NAME', "'void'", "'unsigned'", "'const'", "'union'", "'int'", "'struct'", "'char'", "'signed'", "'long'"}
# First(expression) = {"'sizeof'", "'('", "'!'", "'++'", 'STRING_LITERAL', "'--'", "'&'", "'-'", 'CONSTANT', "'*'", "'+'", "'~'", 'IDENTIFIER'}
# First(assignment_operator) = {"'*='", "'>>='", "'+='", "'|='", "'&='", "'^='", "'/='", "'='", "'<<='", "'-='", "'%='"}
# First(parameter_declaration) = {"'static'", "'short'", "'float'", "'void'", "'union'", "'long'", "'auto'", "'enum'", "'volatile'", "'double'", "'typedef'", 'TYPE_NAME', "'const'", "'unsigned'", "'int'", "'extern'", "'struct'", "'char'", "'signed'", "'register'"}
# First(enumerator_list) = {'IDENTIFIER'}
# First(postfix_expression) = {"'('", 'STRING_LITERAL', 'CONSTANT', 'IDENTIFIER'}
# First(pointer) = {"'*'"}
# First(declaration_specifiers) = {"'enum'", "'register'", "'static'", "'volatile'", "'double'", "'short'", "'typedef'", "'float'", 'TYPE_NAME', "'const'", "'unsigned'", "'void'", "'union'", "'int'", "'extern'", "'struct'", "'char'", "'signed'", "'long'", "'auto'"}
# First(struct_declaration_list) = {"'enum'", "'volatile'", "'double'", "'short'", "'float'", 'TYPE_NAME', "'void'", "'unsigned'", "'const'", "'union'", "'int'", "'struct'", "'char'", "'signed'", "'long'"}
# First(enum_specifier) = {"'enum'"}
# First(init_declarator_list) = {"'('", "'*'", 'IDENTIFIER'}
# First(parameter_list) = {"'static'", "'short'", "'float'", "'void'", "'union'", "'long'", "'auto'", "'enum'", "'volatile'", "'double'", "'typedef'", 'TYPE_NAME', "'const'", "'unsigned'", "'int'", "'extern'", "'struct'", "'char'", "'signed'", "'register'"}
# First(struct_declarator) = {"'('", "':'", "'*'", 'IDENTIFIER'}
# First(statement_list) = {"'sizeof'", "'('", "'++'", "'switch'", "'for'", "'while'", "'--'", "'do'", "'continue'", 'CONSTANT', "'-'", "'*'", "'&'", "'+'", "'~'", 'IDENTIFIER', "'break'", "';'", "'{'", "'!'", 'STRING_LITERAL', "'case'", "'goto'", "'if'", "'default'", "'return'"}
# First(struct_or_union) = {"'struct'", "'union'"}
# First(translation_unit) = {"'('", "'static'", "'short'", "'float'", "'void'", "'union'", "'long'", "'auto'", 'IDENTIFIER', "'enum'", "'volatile'", "'double'", "'typedef'", 'TYPE_NAME', "'const'", "'unsigned'", "'int'", "'extern'", "'struct'", "'char'", "'signed'", "'*'", "'register'"}
# First(abstract_declarator) = {"'('", "'*'", "'['"}
# First(storage_class_specifier) = {"'typedef'", "'register'", "'static'", "'auto'", "'extern'"}
# First(logical_or_expression) = {"'sizeof'", "'('", "'!'", "'++'", 'STRING_LITERAL', "'--'", "'&'", "'-'", 'CONSTANT', "'*'", "'+'", "'~'", 'IDENTIFIER'}
# First(initializer) = {"'sizeof'", "'{'", "'('", "'!'", "'++'", 'STRING_LITERAL', "'--'", "'&'", "'-'", 'CONSTANT', "'*'", "'+'", "'~'", 'IDENTIFIER'}
# First(logical_and_expression) = {"'sizeof'", "'('", "'!'", "'++'", 'STRING_LITERAL', "'--'", "'~'", "'-'", 'CONSTANT', "'*'", "'+'", "'&'", 'IDENTIFIER'}
# First(equality_expression) = {"'sizeof'", "'('", "'!'", "'++'", 'STRING_LITERAL', "'--'", "'-'", 'CONSTANT', "'+'", "'*'", "'&'", "'~'", 'IDENTIFIER'}
# First(init_declarator) = {"'('", "'*'", 'IDENTIFIER'}
# First(multiplicative_expression) = {"'sizeof'", "'('", "'!'", "'++'", 'STRING_LITERAL', "'--'", "'&'", "'-'", 'CONSTANT', "'*'", "'+'", "'~'", 'IDENTIFIER'}
# First(statement) = {"'sizeof'", "';'", "'{'", "'('", "'!'", "'++'", "'switch'", 'STRING_LITERAL', "'for'", "'while'", "'--'", "'case'", "'&'", "'do'", "'~'", "'continue'", 'CONSTANT', "'goto'", "'-'", "'if'", "'*'", "'default'", "'+'", "'return'", 'IDENTIFIER', "'break'"}
# First(identifier_list) = {'IDENTIFIER'}
# First(and_expression) = {"'sizeof'", "'('", "'!'", "'++'", 'STRING_LITERAL', "'--'", "'~'", "'-'", 'CONSTANT', "'*'", "'+'", "'&'", 'IDENTIFIER'}
# First(ŝ) = {"'('", 'STRING_LITERAL', 'CONSTANT', 'IDENTIFIER'}
# First(assignment_expression) = {"'sizeof'", "'('", "'!'", "'++'", 'STRING_LITERAL', "'--'", "'~'", "'-'", 'CONSTANT', "'*'", "'+'", "'&'", 'IDENTIFIER'}
# First(type_name) = {"'enum'", "'volatile'", "'double'", "'short'", "'float'", 'TYPE_NAME', "'void'", "'unsigned'", "'const'", "'union'", "'int'", "'struct'", "'char'", "'signed'", "'long'"}
# First(labeled_statement) = {"'default'", "'case'", 'IDENTIFIER'}
# First(external_declaration) = {"'('", "'static'", "'short'", "'float'", "'void'", "'union'", "'long'", "'auto'", 'IDENTIFIER', "'enum'", "'volatile'", "'double'", "'typedef'", 'TYPE_NAME', "'const'", "'unsigned'", "'int'", "'extern'", "'struct'", "'char'", "'signed'", "'*'", "'register'"}
# Follow sets (note that "$" denotes the end of file):
# Follow(declaration) = {"'sizeof'", "'('", "'}'", "'static'", "'for'", "'while'", "'short'", "'--'", "'float'", "'void'", "'union'", "'-'", "'+'", "'&'", 'IDENTIFIER', "';'", "'{'", "'!'", "'volatile'", "'double'", 'STRING_LITERAL', "'typedef'", "'case'", "'const'", "'unsigned'", "'int'", "'if'", "'char'", "'default'", "'*'", "'register'", "'++'", "'switch'", "'do'", "'continue'", 'CONSTANT', "'long'", "'~'", "'auto'", "'break'", "'enum'", 'TYPE_NAME', "'goto'", "'extern'", "'struct'", "'signed'", "'return'"}
# Follow(type_specifier) = {"'enum'", "';'", "'('", "'static'", "'volatile'", "'double'", "'short'", "')'", "'typedef'", "'float'", 'TYPE_NAME', "'const'", "'unsigned'", "'void'", "'union'", "'int'", "'extern'", "':'", "'struct'", "'char'", "'signed'", "'long'", "','", "'*'", "'register'", "'auto'", 'IDENTIFIER', "'['"}
# Follow(enumerator) = {"'}'", "','"}
# Follow(primary_expression) = {"'/'", "'('", "'}'", "'&&'", "'--'", "'>='", "'-'", "':'", "','", "'!='", "'+'", "'&'", "'^'", "'>>'", "';'", "'>>='", "'|'", "'<<='", "'*='", "']'", "'^='", "'*'", "'%='", '$', "'+='", "'++'", "'>'", "'||'", "'<='", "'|='", "'-='", "'%'", "'['", "'?'", "')'", "'='", "'<'", "'&='", "'<<'", "'/='", "'=='", "'->'", "'.'"}
# Follow(relational_expression) = {"'?'", "';'", "'}'", "'|'", "')'", "'&&'", "'>='", "'>'", "'||'", "'<'", "':'", "']'", "'<='", "'=='", "','", "'!='", "'&'", "'^'"}
# Follow(initializer_list) = {"'}'", "','"}
# Follow(selection_statement) = {"'sizeof'", "';'", "'{'", "'('", "'else'", "'}'", "'!'", "'++'", "'switch'", 'STRING_LITERAL', "'for'", "'while'", "'--'", "'case'", "'&'", "'do'", "'~'", "'continue'", 'CONSTANT', "'goto'", "'-'", "'if'", "'*'", "'default'", "'+'", "'return'", 'IDENTIFIER', "'break'"}
# Follow(additive_expression) = {"'}'", "'&&'", "'>='", "'>'", "'||'", "'-'", "':'", "'<='", "','", "'!='", "'+'", "'&'", "'^'", "'>>'", "'?'", "';'", "'|'", "')'", "'<'", "']'", "'<<'", "'=='"}
# Follow(constant_expression) = {"';'", "','", "':'", "'}'", "']'"}
# Follow(argument_expression_list) = {"')'", "','"}
# Follow(function_definition) = {"'enum'", "'register'", "'('", "'static'", "'volatile'", "'double'", "'short'", "'typedef'", "'float'", 'TYPE_NAME', "'void'", "'union'", "'const'", "'unsigned'", "'int'", "'extern'", "'struct'", "'char'", "'signed'", "'*'", "'long'", "'auto'", 'IDENTIFIER'}
# Follow(exclusive_or_expression) = {"'?'", "';'", "':'", "'}'", "']'", "'|'", "')'", "'&&'", "','", "'^'", "'||'"}
# Follow(conditional_expression) = {"';'", "':'", "'}'", "']'", "')'", "','"}
# Follow(struct_or_union_specifier) = {"'('", "'static'", "'short'", "'float'", "'void'", "'union'", "':'", "','", "'long'", "'auto'", 'IDENTIFIER', "'['", "'enum'", "';'", "'volatile'", "'double'", "')'", "'typedef'", 'TYPE_NAME', "'const'", "'unsigned'", "'int'", "'extern'", "'struct'", "'char'", "'signed'", "'*'", "'register'"}
# Follow(iteration_statement) = {"'sizeof'", "';'", "'{'", "'('", "'else'", "'}'", "'!'", "'++'", "'switch'", 'STRING_LITERAL', "'for'", "'while'", "'--'", "'case'", "'&'", "'do'", "'~'", "'continue'", 'CONSTANT', "'goto'", "'-'", "'if'", "'*'", "'default'", "'+'", "'return'", 'IDENTIFIER', "'break'"}
# Follow(struct_declaration) = {"'enum'", "'}'", "'volatile'", "'double'", "'short'", "'float'", 'TYPE_NAME', "'void'", "'unsigned'", "'const'", "'union'", "'int'", "'struct'", "'char'", "'signed'", "'long'"}
# Follow(compound_statement) = {"'sizeof'", "'('", "'}'", "'static'", "'++'", "'switch'", "'for'", "'short'", "'while'", "'--'", "'default'", "'float'", "'do'", "'void'", "'union'", "'continue'", 'CONSTANT', "'-'", "'long'", "'&'", "'auto'", 'IDENTIFIER', "'~'", "'+'", "'break'", "'enum'", "';'", "'{'", "'else'", "'!'", "'volatile'", "'double'", 'STRING_LITERAL', "'typedef'", "'case'", 'TYPE_NAME', "'const'", "'unsigned'", "'int'", "'goto'", "'extern'", "'if'", "'struct'", "'char'", "'signed'", "'*'", "'register'", "'return'"}
# Follow(inclusive_or_expression) = {"'?'", "';'", "':'", "'}'", "']'", "'|'", "')'", "'&&'", "','", "'||'"}
# Follow(shift_expression) = {"'?'", "';'", "'}'", "'|'", "')'", "'&&'", "'>='", "'>'", "'||'", "'<'", "':'", "']'", "'<<'", "'<='", "'=='", "','", "'!='", "'&'", "'^'", "'>>'"}
# Follow(type_qualifier_list) = {"'('", "'['", "'volatile'", "')'", "','", "'*'", 'IDENTIFIER', "'const'"}
# Follow(struct_declarator_list) = {"';'", "','"}
# Follow(expression_statement) = {"'sizeof'", "'('", "'}'", "'++'", "'switch'", "'for'", "'while'", "'--'", "'default'", "'do'", "'-'", 'CONSTANT', "'continue'", "'+'", "'&'", "'~'", 'IDENTIFIER', "'break'", "';'", "'{'", "'else'", "'!'", 'STRING_LITERAL', "')'", "'case'", "'goto'", "'if'", "'*'", "'return'"}
# Follow(unary_expression) = {"'/'", "'+='", "'}'", "'&&'", "'>'", "'>='", "'||'", "'-'", "':'", "'<='", "','", "'!='", "'-='", "'+'", "'|='", "'%'", "'&'", "'^'", "'>>'", "'?'", "';'", "'>>='", "'|'", "')'", "'='", "'<<='", "'*='", "'<'", "']'", "'&='", "'^='", "'<<'", "'/='", "'=='", "'*'", "'%='"}
# Follow(direct_declarator) = {"'('", "'static'", "'short'", "'float'", "'void'", "'union'", "':'", "','", "'long'", "'auto'", "'['", "'enum'", "';'", "'{'", "'volatile'", "'double'", "')'", "'='", "'typedef'", 'TYPE_NAME', "'const'", "'unsigned'", "'int'", "'extern'", "'struct'", "'char'", "'signed'", "'register'"}
# Follow(parameter_type_list) = {"')'"}
# Follow(declarator) = {"'enum'", "';'", "'register'", "'{'", "'static'", "'volatile'", "'double'", "')'", "'short'", "'='", "'typedef'", "'float'", 'TYPE_NAME', "'void'", "'union'", "'const'", "'unsigned'", "'int'", "':'", "'extern'", "'struct'", "'char'", "'signed'", "','", "'long'", "'auto'"}
# Follow(direct_abstract_declarator) = {"'('", "')'", "','", "'['"}
# Follow(type_qualifier) = {"'enum'", "';'", "'('", "'static'", "'volatile'", "'double'", "'short'", "')'", "'typedef'", "'float'", 'TYPE_NAME', "'const'", "'unsigned'", "'void'", "'union'", "'int'", "'extern'", "':'", "'struct'", "'char'", "'signed'", "'long'", "','", "'*'", "'register'", "'auto'", 'IDENTIFIER', "'['"}
# Follow(jump_statement) = {"'sizeof'", "';'", "'{'", "'('", "'else'", "'}'", "'!'", "'++'", "'switch'", 'STRING_LITERAL', "'for'", "'while'", "'--'", "'case'", "'&'", "'do'", "'~'", "'continue'", 'CONSTANT', "'goto'", "'-'", "'if'", "'*'", "'default'", "'+'", "'return'", 'IDENTIFIER', "'break'"}
# Follow(unary_operator) = {"'sizeof'", "'~'", "'-'", 'CONSTANT', "'('", "'!'", "'++'", 'STRING_LITERAL', "'--'", "'*'", "'+'", "'&'", 'IDENTIFIER'}
# Follow(declaration_list) = {"'sizeof'", "'('", "'}'", "'static'", "'++'", "'switch'", "'for'", "'while'", "'short'", "'--'", "'float'", "'do'", "'void'", "'union'", "'continue'", 'CONSTANT', "'-'", "'*'", "'+'", "'&'", "'~'", 'IDENTIFIER', "'long'", "'break'", "'auto'", "'enum'", "';'", "'{'", "'!'", "'volatile'", "'double'", 'STRING_LITERAL', "'typedef'", "'case'", 'TYPE_NAME', "'const'", "'unsigned'", "'goto'", "'int'", "'extern'", "'if'", "'struct'", "'char'", "'signed'", "'default'", "'register'", "'return'"}
# Follow(specifier_qualifier_list) = {"')'", "':'", "'('", "'*'", 'IDENTIFIER', "'['"}
# Follow(expression) = {"')'", "';'", "','", "':'", "']'"}
# Follow(assignment_operator) = {"'sizeof'", "'-'", 'CONSTANT', "'('", "'!'", "'++'", 'STRING_LITERAL', 'IDENTIFIER', "'--'", "'*'", "'+'", "'~'", "'&'"}
# Follow(parameter_declaration) = {"')'", "','"}
# Follow(enumerator_list) = {"'}'", "','"}
# Follow(postfix_expression) = {"'/'", "'('", "'+='", "'}'", "'++'", "'&&'", "'--'", "'>'", "'>='", "'||'", "'-'", "':'", "'<='", "','", "'!='", "'-='", "'+'", "'|='", "'%'", "'&'", "'^'", "'['", "'>>'", "'?'", "';'", "'>>='", "'|'", "')'", "'='", "'<<='", "'*='", "'<'", "']'", "'&='", "'^='", "'<<'", "'/='", "'=='", "'->'", "'.'", "'*'", "'%='"}
# Follow(pointer) = {"')'", "','", "'('", 'IDENTIFIER', "'['"}
# Follow(declaration_specifiers) = {"';'", "')'", "','", "'('", "'*'", 'IDENTIFIER', "'['"}
# Follow(struct_declaration_list) = {"'enum'", "'}'", "'volatile'", "'double'", "'short'", "'float'", 'TYPE_NAME', "'void'", "'unsigned'", "'const'", "'union'", "'int'", "'struct'", "'char'", "'signed'", "'long'"}
# Follow(enum_specifier) = {"'('", "'static'", "'short'", "'float'", "'void'", "'union'", "':'", "','", "'long'", "'auto'", 'IDENTIFIER', "'['", "'enum'", "';'", "'volatile'", "'double'", "')'", "'typedef'", 'TYPE_NAME', "'const'", "'unsigned'", "'int'", "'extern'", "'struct'", "'char'", "'signed'", "'*'", "'register'"}
# Follow(init_declarator_list) = {"';'", "','"}
# Follow(parameter_list) = {"')'", "','"}
# Follow(struct_declarator) = {"';'", "','"}
# Follow(statement_list) = {"'sizeof'", "';'", "'{'", "'('", "'}'", "'!'", "'++'", "'switch'", 'STRING_LITERAL', "'for'", "'while'", "'--'", "'default'", "'case'", "'return'", "'do'", "'continue'", 'CONSTANT', "'goto'", "'-'", "'if'", "'+'", "'*'", "'&'", "'~'", 'IDENTIFIER', "'break'"}
# Follow(struct_or_union) = {'IDENTIFIER', "'{'"}
# Follow(translation_unit) = {"'enum'", "'register'", "'('", "'static'", "'volatile'", "'double'", "'short'", "'typedef'", "'float'", 'TYPE_NAME', "'void'", "'union'", "'const'", "'unsigned'", "'int'", "'extern'", "'struct'", "'char'", "'signed'", "'*'", "'long'", "'auto'", 'IDENTIFIER'}
# Follow(abstract_declarator) = {"')'", "','"}
# Follow(storage_class_specifier) = {"'enum'", "';'", "'('", "'static'", "'volatile'", "'double'", "'short'", "')'", "'typedef'", "'float'", 'TYPE_NAME', "'const'", "'unsigned'", "'void'", "'union'", "'int'", "'extern'", "'struct'", "'char'", "'signed'", "'long'", "','", "'*'", "'register'", "'auto'", 'IDENTIFIER', "'['"}
# Follow(logical_or_expression) = {"'?'", "';'", "':'", "'}'", "']'", "')'", "','", "'||'"}
# Follow(initializer) = {"'}'", "';'", "','"}
# Follow(logical_and_expression) = {"'?'", "';'", "':'", "'}'", "']'", "')'", "'&&'", "','", "'||'"}
# Follow(equality_expression) = {"'?'", "';'", "'}'", "'|'", "')'", "'&&'", "'||'", "':'", "']'", "'=='", "','", "'!='", "'&'", "'^'"}
# Follow(init_declarator) = {"';'", "','"}
# Follow(multiplicative_expression) = {"'/'", "'}'", "'&&'", "'>'", "'>='", "'||'", "'-'", "':'", "'<='", "','", "'!='", "'&'", "'+'", "'%'", "'^'", "'>>'", "'?'", "';'", "'|'", "')'", "'<'", "']'", "'<<'", "'=='", "'*'"}
# Follow(statement) = {"'sizeof'", "';'", "'{'", "'('", "'else'", "'}'", "'!'", "'++'", "'switch'", 'STRING_LITERAL', "'for'", "'while'", "'--'", "'case'", "'&'", "'do'", "'~'", "'continue'", 'CONSTANT', "'goto'", "'-'", "'if'", "'*'", "'default'", "'+'", "'return'", 'IDENTIFIER', "'break'"}
# Follow(identifier_list) = {"')'", "','"}
# Follow(and_expression) = {"'?'", "';'", "'}'", "'|'", "')'", "'&&'", "'||'", "':'", "']'", "','", "'&'", "'^'"}
# Follow(ŝ) = set()
# Follow(assignment_expression) = {"')'", "';'", "','", "':'", "'}'", "']'"}
# Follow(type_name) = {"')'"}
# Follow(labeled_statement) = {"'sizeof'", "';'", "'{'", "'('", "'else'", "'}'", "'!'", "'++'", "'switch'", 'STRING_LITERAL', "'for'", "'while'", "'--'", "'case'", "'&'", "'do'", "'~'", "'continue'", 'CONSTANT', "'goto'", "'-'", "'if'", "'*'", "'default'", "'+'", "'return'", 'IDENTIFIER', "'break'"}
# Follow(external_declaration) = {"'enum'", "'register'", "'('", "'static'", "'volatile'", "'double'", "'short'", "'typedef'", "'float'", 'TYPE_NAME', "'void'", "'union'", "'const'", "'unsigned'", "'int'", "'extern'", "'struct'", "'char'", "'signed'", "'*'", "'long'", "'auto'", 'IDENTIFIER'}
# All SLR-states:
# s0 = {ŝ →  • primary_expression $, primary_expression →  • STRING_LITERAL, primary_expression →  • '(' expression ')', primary_expression →  • IDENTIFIER, primary_expression →  • CONSTANT}
# s1 = {declaration_specifiers → type_specifier declaration_specifiers • }
# s2 = {relational_expression → shift_expression • , shift_expression → shift_expression • '>>' additive_expression, shift_expression → shift_expression • '<<' additive_expression}
# s3 = {enum_specifier → 'enum' IDENTIFIER '{' enumerator_list • '}', enumerator_list → enumerator_list • ',' enumerator}
# s4 = {ŝ → primary_expression $ • }
# s5 = {primary_expression → CONSTANT • }
# s6 = {pointer →  • '*' type_qualifier_list, pointer →  • '*', pointer → '*' type_qualifier_list • , pointer →  • '*' pointer, type_qualifier →  • 'const', pointer →  • '*' type_qualifier_list pointer, pointer → '*' type_qualifier_list • pointer, type_qualifier →  • 'volatile', type_qualifier_list → type_qualifier_list • type_qualifier}
# s7 = {pointer →  • '*' type_qualifier_list, type_qualifier_list →  • type_qualifier_list type_qualifier, pointer → '*' • type_qualifier_list pointer, pointer →  • '*', pointer →  • '*' pointer, pointer → '*' • type_qualifier_list, pointer → '*' • pointer, type_qualifier →  • 'const', pointer →  • '*' type_qualifier_list pointer, type_qualifier_list →  • type_qualifier, pointer → '*' • , type_qualifier →  • 'volatile'}
# s8 = {specifier_qualifier_list → type_qualifier specifier_qualifier_list • }
# s9 = {struct_or_union_specifier → struct_or_union '{' struct_declaration_list '}' • }
# s10 = {postfix_expression →  • postfix_expression '(' argument_expression_list ')', conditional_expression →  • logical_or_expression, postfix_expression →  • postfix_expression '--', postfix_expression →  • primary_expression, postfix_expression →  • postfix_expression '(' ')', postfix_expression →  • postfix_expression '.' IDENTIFIER, unary_operator →  • '~', exclusive_or_expression →  • exclusive_or_expression '^' and_expression, multiplicative_expression →  • multiplicative_expression '%' unary_expression, additive_expression →  • additive_expression '-' multiplicative_expression, multiplicative_expression →  • multiplicative_expression '*' unary_expression, logical_and_expression →  • logical_and_expression '&&' inclusive_or_expression, primary_expression →  • IDENTIFIER, additive_expression →  • additive_expression '+' multiplicative_expression, equality_expression →  • equality_expression '!=' relational_expression, conditional_expression →  • logical_or_expression '?' expression ':' conditional_expression, primary_expression →  • STRING_LITERAL, and_expression →  • and_expression '&' equality_expression, and_expression →  • equality_expression, unary_operator →  • '!', logical_and_expression →  • inclusive_or_expression, unary_expression →  • unary_operator unary_expression, relational_expression →  • relational_expression '<' shift_expression, postfix_expression → postfix_expression '(' • ')', unary_expression →  • '++' unary_expression, assignment_expression →  • conditional_expression, unary_expression →  • '--' unary_expression, relational_expression →  • shift_expression, primary_expression →  • CONSTANT, logical_or_expression →  • logical_and_expression, argument_expression_list →  • assignment_expression, shift_expression →  • shift_expression '>>' additive_expression, relational_expression →  • relational_expression '>=' shift_expression, logical_or_expression →  • logical_or_expression '||' logical_and_expression, argument_expression_list →  • argument_expression_list ',' assignment_expression, exclusive_or_expression →  • and_expression, unary_operator →  • '&', shift_expression →  • shift_expression '<<' additive_expression, relational_expression →  • relational_expression '>' shift_expression, shift_expression →  • additive_expression, multiplicative_expression →  • multiplicative_expression '/' unary_expression, multiplicative_expression →  • unary_expression, unary_expression →  • postfix_expression, unary_operator →  • '*', unary_expression →  • 'sizeof' unary_expression, primary_expression →  • '(' expression ')', postfix_expression →  • postfix_expression '[' expression ']', postfix_expression →  • postfix_expression '++', assignment_expression →  • unary_expression assignment_operator assignment_expression, additive_expression →  • multiplicative_expression, inclusive_or_expression →  • exclusive_or_expression, postfix_expression →  • postfix_expression '->' IDENTIFIER, inclusive_or_expression →  • inclusive_or_expression '|' exclusive_or_expression, equality_expression →  • equality_expression '==' relational_expression, postfix_expression → postfix_expression '(' • argument_expression_list ')', unary_operator →  • '+', equality_expression →  • relational_expression, unary_expression →  • 'sizeof' '(' type_name ')', unary_operator →  • '-', relational_expression →  • relational_expression '<=' shift_expression}
# s11 = {enum_specifier → 'enum' IDENTIFIER '{' enumerator_list '}' • }
# s12 = {assignment_operator → '-=' • }
# s13 = {unary_expression → 'sizeof' unary_expression • }
# s14 = {postfix_expression →  • postfix_expression '(' argument_expression_list ')', postfix_expression →  • postfix_expression '--', postfix_expression →  • primary_expression, postfix_expression →  • postfix_expression '(' ')', postfix_expression →  • postfix_expression '.' IDENTIFIER, exclusive_or_expression →  • exclusive_or_expression '^' and_expression, multiplicative_expression →  • multiplicative_expression '%' unary_expression, unary_operator →  • '~', additive_expression →  • additive_expression '-' multiplicative_expression, multiplicative_expression →  • multiplicative_expression '*' unary_expression, logical_and_expression →  • logical_and_expression '&&' inclusive_or_expression, additive_expression →  • additive_expression '+' multiplicative_expression, primary_expression →  • IDENTIFIER, equality_expression →  • equality_expression '!=' relational_expression, and_expression →  • and_expression '&' equality_expression, primary_expression →  • STRING_LITERAL, and_expression →  • equality_expression, unary_operator →  • '!', logical_and_expression →  • inclusive_or_expression, unary_expression →  • unary_operator unary_expression, relational_expression →  • relational_expression '<' shift_expression, unary_expression →  • '++' unary_expression, unary_expression →  • '--' unary_expression, relational_expression →  • shift_expression, primary_expression →  • CONSTANT, shift_expression →  • shift_expression '>>' additive_expression, relational_expression →  • relational_expression '>=' shift_expression, exclusive_or_expression →  • and_expression, unary_operator →  • '&', shift_expression →  • shift_expression '<<' additive_expression, relational_expression →  • relational_expression '>' shift_expression, shift_expression →  • additive_expression, multiplicative_expression →  • multiplicative_expression '/' unary_expression, multiplicative_expression →  • unary_expression, unary_expression →  • postfix_expression, unary_operator →  • '*', unary_expression →  • 'sizeof' unary_expression, primary_expression →  • '(' expression ')', logical_or_expression → logical_or_expression '||' • logical_and_expression, postfix_expression →  • postfix_expression '[' expression ']', postfix_expression →  • postfix_expression '++', additive_expression →  • multiplicative_expression, inclusive_or_expression →  • exclusive_or_expression, inclusive_or_expression →  • inclusive_or_expression '|' exclusive_or_expression, equality_expression →  • equality_expression '==' relational_expression, postfix_expression →  • postfix_expression '->' IDENTIFIER, unary_operator →  • '+', equality_expression →  • relational_expression, unary_expression →  • 'sizeof' '(' type_name ')', unary_operator →  • '-', relational_expression →  • relational_expression '<=' shift_expression}
# s15 = {declaration_specifiers →  • type_qualifier, type_specifier →  • 'int', struct_or_union_specifier →  • struct_or_union IDENTIFIER, enum_specifier →  • 'enum' IDENTIFIER '{' enumerator_list '}', storage_class_specifier →  • 'typedef', struct_or_union_specifier →  • struct_or_union IDENTIFIER '{' struct_declaration_list '}', struct_or_union →  • 'struct', type_qualifier →  • 'volatile', type_specifier →  • 'short', storage_class_specifier →  • 'auto', enum_specifier →  • 'enum' '{' enumerator_list '}', type_specifier →  • 'signed', type_qualifier →  • 'const', type_specifier →  • 'long', declaration_specifiers →  • type_specifier declaration_specifiers, type_specifier →  • 'float', storage_class_specifier →  • 'register', enum_specifier →  • 'enum' IDENTIFIER, type_specifier →  • 'double', type_specifier →  • 'char', declaration_specifiers →  • storage_class_specifier declaration_specifiers, declaration_specifiers →  • type_specifier, struct_or_union_specifier →  • struct_or_union '{' struct_declaration_list '}', declaration_specifiers → storage_class_specifier • , declaration_specifiers → storage_class_specifier • declaration_specifiers, type_specifier →  • enum_specifier, declaration_specifiers →  • storage_class_specifier, type_specifier →  • 'void', storage_class_specifier →  • 'extern', type_specifier →  • 'unsigned', type_specifier →  • struct_or_union_specifier, declaration_specifiers →  • type_qualifier declaration_specifiers, storage_class_specifier →  • 'static', struct_or_union →  • 'union', type_specifier →  • TYPE_NAME}
# s16 = {postfix_expression → postfix_expression '->' IDENTIFIER • }
# s17 = {unary_expression → 'sizeof' '(' type_name ')' • }
# s18 = {postfix_expression → postfix_expression '--' • }
# s19 = {struct_declaration → specifier_qualifier_list struct_declarator_list • ';', struct_declarator_list → struct_declarator_list • ',' struct_declarator}
# s20 = {conditional_expression → logical_or_expression '?' expression ':' conditional_expression • }
# s21 = {postfix_expression → postfix_expression '.' IDENTIFIER • }
# s22 = {pointer →  • '*' pointer, struct_declarator_list →  • struct_declarator_list ',' struct_declarator, struct_declaration → specifier_qualifier_list • struct_declarator_list ';', declarator →  • direct_declarator, direct_declarator →  • '(' declarator ')', pointer →  • '*' type_qualifier_list pointer, struct_declarator →  • ':' constant_expression, declarator →  • pointer direct_declarator, direct_declarator →  • direct_declarator '(' parameter_type_list ')', struct_declarator →  • declarator ':' constant_expression, direct_declarator →  • direct_declarator '(' ')', direct_declarator →  • direct_declarator '[' ']', pointer →  • '*' type_qualifier_list, direct_declarator →  • direct_declarator '(' identifier_list ')', pointer →  • '*', struct_declarator_list →  • struct_declarator, direct_declarator →  • direct_declarator '[' constant_expression ']', struct_declarator →  • declarator, direct_declarator →  • IDENTIFIER}
# s23 = {postfix_expression →  • postfix_expression '(' argument_expression_list ')', postfix_expression →  • postfix_expression '--', postfix_expression →  • primary_expression, postfix_expression →  • postfix_expression '(' ')', postfix_expression →  • postfix_expression '.' IDENTIFIER, and_expression → and_expression '&' • equality_expression, multiplicative_expression →  • multiplicative_expression '%' unary_expression, unary_operator →  • '~', additive_expression →  • additive_expression '-' multiplicative_expression, multiplicative_expression →  • multiplicative_expression '*' unary_expression, additive_expression →  • additive_expression '+' multiplicative_expression, primary_expression →  • IDENTIFIER, equality_expression →  • equality_expression '!=' relational_expression, primary_expression →  • STRING_LITERAL, unary_operator →  • '!', unary_expression →  • unary_operator unary_expression, relational_expression →  • relational_expression '<' shift_expression, unary_expression →  • '++' unary_expression, unary_expression →  • '--' unary_expression, relational_expression →  • shift_expression, primary_expression →  • CONSTANT, shift_expression →  • shift_expression '>>' additive_expression, relational_expression →  • relational_expression '>=' shift_expression, unary_operator →  • '&', shift_expression →  • shift_expression '<<' additive_expression, relational_expression →  • relational_expression '>' shift_expression, shift_expression →  • additive_expression, multiplicative_expression →  • multiplicative_expression '/' unary_expression, multiplicative_expression →  • unary_expression, unary_expression →  • postfix_expression, unary_operator →  • '*', unary_expression →  • 'sizeof' unary_expression, primary_expression →  • '(' expression ')', postfix_expression →  • postfix_expression '[' expression ']', postfix_expression →  • postfix_expression '++', additive_expression →  • multiplicative_expression, postfix_expression →  • postfix_expression '->' IDENTIFIER, equality_expression →  • equality_expression '==' relational_expression, unary_operator →  • '+', equality_expression →  • relational_expression, unary_expression →  • 'sizeof' '(' type_name ')', unary_operator →  • '-', relational_expression →  • relational_expression '<=' shift_expression}
# s24 = {storage_class_specifier → 'register' • }
# s25 = {postfix_expression →  • postfix_expression '(' argument_expression_list ')', conditional_expression →  • logical_or_expression, postfix_expression →  • postfix_expression '--', postfix_expression →  • primary_expression, postfix_expression →  • postfix_expression '(' ')', postfix_expression →  • postfix_expression '.' IDENTIFIER, exclusive_or_expression →  • exclusive_or_expression '^' and_expression, multiplicative_expression →  • multiplicative_expression '%' unary_expression, unary_operator →  • '~', additive_expression →  • additive_expression '-' multiplicative_expression, multiplicative_expression →  • multiplicative_expression '*' unary_expression, logical_and_expression →  • logical_and_expression '&&' inclusive_or_expression, additive_expression →  • additive_expression '+' multiplicative_expression, primary_expression →  • IDENTIFIER, equality_expression →  • equality_expression '!=' relational_expression, conditional_expression →  • logical_or_expression '?' expression ':' conditional_expression, and_expression →  • and_expression '&' equality_expression, primary_expression →  • STRING_LITERAL, and_expression →  • equality_expression, unary_operator →  • '!', logical_and_expression →  • inclusive_or_expression, unary_expression →  • unary_operator unary_expression, relational_expression →  • relational_expression '<' shift_expression, unary_expression →  • '++' unary_expression, unary_expression →  • '--' unary_expression, relational_expression →  • shift_expression, primary_expression →  • CONSTANT, logical_or_expression →  • logical_and_expression, shift_expression →  • shift_expression '>>' additive_expression, relational_expression →  • relational_expression '>=' shift_expression, logical_or_expression →  • logical_or_expression '||' logical_and_expression, exclusive_or_expression →  • and_expression, unary_operator →  • '&', shift_expression →  • shift_expression '<<' additive_expression, relational_expression →  • relational_expression '>' shift_expression, shift_expression →  • additive_expression, multiplicative_expression →  • multiplicative_expression '/' unary_expression, conditional_expression → logical_or_expression '?' expression ':' • conditional_expression, multiplicative_expression →  • unary_expression, unary_expression →  • postfix_expression, unary_operator →  • '*', unary_expression →  • 'sizeof' unary_expression, primary_expression →  • '(' expression ')', postfix_expression →  • postfix_expression '[' expression ']', postfix_expression →  • postfix_expression '++', additive_expression →  • multiplicative_expression, inclusive_or_expression →  • exclusive_or_expression, inclusive_or_expression →  • inclusive_or_expression '|' exclusive_or_expression, equality_expression →  • equality_expression '==' relational_expression, postfix_expression →  • postfix_expression '->' IDENTIFIER, unary_operator →  • '+', equality_expression →  • relational_expression, unary_expression →  • 'sizeof' '(' type_name ')', unary_operator →  • '-', relational_expression →  • relational_expression '<=' shift_expression}
# s26 = {specifier_qualifier_list →  • type_specifier, specifier_qualifier_list →  • type_qualifier specifier_qualifier_list, type_specifier →  • 'char', type_specifier →  • 'int', struct_or_union_specifier →  • struct_or_union IDENTIFIER, struct_declaration →  • specifier_qualifier_list struct_declarator_list ';', struct_or_union_specifier →  • struct_or_union '{' struct_declaration_list '}', enum_specifier →  • 'enum' IDENTIFIER '{' enumerator_list '}', struct_or_union_specifier →  • struct_or_union IDENTIFIER '{' struct_declaration_list '}', struct_declaration_list → struct_declaration_list • struct_declaration, enum_specifier →  • 'enum' IDENTIFIER, struct_or_union →  • 'struct', type_specifier →  • 'short', type_qualifier →  • 'volatile', specifier_qualifier_list →  • type_qualifier, struct_or_union_specifier → struct_or_union '{' struct_declaration_list • '}', type_specifier →  • enum_specifier, specifier_qualifier_list →  • type_specifier specifier_qualifier_list, enum_specifier →  • 'enum' '{' enumerator_list '}', type_specifier →  • 'signed', type_specifier →  • 'void', type_specifier →  • 'unsigned', type_specifier →  • struct_or_union_specifier, type_specifier →  • 'long', type_specifier →  • 'float', type_qualifier →  • 'const', type_specifier →  • 'double', struct_or_union →  • 'union', type_specifier →  • TYPE_NAME}
# s27 = {postfix_expression → postfix_expression '(' ')' • }
# s28 = {relational_expression → relational_expression '>' shift_expression • , shift_expression → shift_expression • '>>' additive_expression, shift_expression → shift_expression • '<<' additive_expression}
# s29 = {postfix_expression →  • postfix_expression '(' argument_expression_list ')', conditional_expression →  • logical_or_expression, postfix_expression →  • postfix_expression '--', postfix_expression →  • primary_expression, postfix_expression →  • postfix_expression '(' ')', postfix_expression →  • postfix_expression '.' IDENTIFIER, expression →  • assignment_expression, unary_operator →  • '~', exclusive_or_expression →  • exclusive_or_expression '^' and_expression, multiplicative_expression →  • multiplicative_expression '%' unary_expression, additive_expression →  • additive_expression '-' multiplicative_expression, multiplicative_expression →  • multiplicative_expression '*' unary_expression, logical_and_expression →  • logical_and_expression '&&' inclusive_or_expression, primary_expression →  • IDENTIFIER, additive_expression →  • additive_expression '+' multiplicative_expression, equality_expression →  • equality_expression '!=' relational_expression, conditional_expression →  • logical_or_expression '?' expression ':' conditional_expression, primary_expression →  • STRING_LITERAL, and_expression →  • and_expression '&' equality_expression, and_expression →  • equality_expression, unary_operator →  • '!', logical_and_expression →  • inclusive_or_expression, unary_expression →  • unary_operator unary_expression, relational_expression →  • relational_expression '<' shift_expression, unary_expression →  • '++' unary_expression, assignment_expression →  • conditional_expression, unary_expression →  • '--' unary_expression, relational_expression →  • shift_expression, primary_expression →  • CONSTANT, logical_or_expression →  • logical_and_expression, shift_expression →  • shift_expression '>>' additive_expression, relational_expression →  • relational_expression '>=' shift_expression, logical_or_expression →  • logical_or_expression '||' logical_and_expression, exclusive_or_expression →  • and_expression, unary_operator →  • '&', shift_expression →  • shift_expression '<<' additive_expression, relational_expression →  • relational_expression '>' shift_expression, shift_expression →  • additive_expression, multiplicative_expression →  • multiplicative_expression '/' unary_expression, multiplicative_expression →  • unary_expression, unary_expression →  • postfix_expression, unary_operator →  • '*', unary_expression →  • 'sizeof' unary_expression, primary_expression →  • '(' expression ')', postfix_expression →  • postfix_expression '[' expression ']', postfix_expression →  • postfix_expression '++', assignment_expression →  • unary_expression assignment_operator assignment_expression, additive_expression →  • multiplicative_expression, inclusive_or_expression →  • exclusive_or_expression, postfix_expression →  • postfix_expression '->' IDENTIFIER, inclusive_or_expression →  • inclusive_or_expression '|' exclusive_or_expression, postfix_expression → postfix_expression '[' • expression ']', equality_expression →  • equality_expression '==' relational_expression, expression →  • expression ',' assignment_expression, unary_operator →  • '+', equality_expression →  • relational_expression, unary_expression →  • 'sizeof' '(' type_name ')', unary_operator →  • '-', relational_expression →  • relational_expression '<=' shift_expression}
# s30 = {type_qualifier → 'volatile' • }
# s31 = {abstract_declarator → pointer • direct_abstract_declarator, direct_abstract_declarator →  • '[' ']', direct_abstract_declarator →  • '[' constant_expression ']', direct_abstract_declarator →  • '(' ')', abstract_declarator → pointer • , direct_abstract_declarator →  • '(' abstract_declarator ')', direct_abstract_declarator →  • direct_abstract_declarator '(' ')', direct_abstract_declarator →  • '(' parameter_type_list ')', direct_abstract_declarator →  • direct_abstract_declarator '[' constant_expression ']', direct_abstract_declarator →  • direct_abstract_declarator '(' parameter_type_list ')', direct_abstract_declarator →  • direct_abstract_declarator '[' ']'}
# s32 = {direct_abstract_declarator → direct_abstract_declarator '[' constant_expression ']' • }
# s33 = {postfix_expression →  • postfix_expression '(' argument_expression_list ')', postfix_expression →  • postfix_expression '--', postfix_expression →  • primary_expression, postfix_expression →  • postfix_expression '(' ')', postfix_expression →  • postfix_expression '.' IDENTIFIER, multiplicative_expression →  • multiplicative_expression '%' unary_expression, unary_operator →  • '~', additive_expression →  • additive_expression '-' multiplicative_expression, multiplicative_expression →  • multiplicative_expression '*' unary_expression, additive_expression →  • additive_expression '+' multiplicative_expression, primary_expression →  • IDENTIFIER, primary_expression →  • STRING_LITERAL, unary_operator →  • '!', unary_expression →  • unary_operator unary_expression, unary_expression →  • '++' unary_expression, unary_expression →  • '--' unary_expression, primary_expression →  • CONSTANT, unary_operator →  • '&', multiplicative_expression →  • multiplicative_expression '/' unary_expression, multiplicative_expression →  • unary_expression, shift_expression → shift_expression '>>' • additive_expression, unary_expression →  • postfix_expression, unary_operator →  • '*', unary_expression →  • 'sizeof' unary_expression, primary_expression →  • '(' expression ')', postfix_expression →  • postfix_expression '[' expression ']', postfix_expression →  • postfix_expression '++', additive_expression →  • multiplicative_expression, postfix_expression →  • postfix_expression '->' IDENTIFIER, unary_operator →  • '+', unary_expression →  • 'sizeof' '(' type_name ')', unary_operator →  • '-'}
# s34 = {type_specifier → TYPE_NAME • }
# s35 = {postfix_expression →  • postfix_expression '(' argument_expression_list ')', postfix_expression →  • postfix_expression '--', postfix_expression →  • primary_expression, postfix_expression →  • postfix_expression '(' ')', postfix_expression →  • postfix_expression '.' IDENTIFIER, multiplicative_expression →  • multiplicative_expression '%' unary_expression, unary_operator →  • '~', additive_expression →  • additive_expression '-' multiplicative_expression, multiplicative_expression →  • multiplicative_expression '*' unary_expression, additive_expression →  • additive_expression '+' multiplicative_expression, primary_expression →  • IDENTIFIER, primary_expression →  • STRING_LITERAL, unary_operator →  • '!', unary_expression →  • unary_operator unary_expression, unary_expression →  • '++' unary_expression, unary_expression →  • '--' unary_expression, primary_expression →  • CONSTANT, relational_expression → relational_expression '<=' • shift_expression, shift_expression →  • shift_expression '>>' additive_expression, unary_operator →  • '&', shift_expression →  • shift_expression '<<' additive_expression, shift_expression →  • additive_expression, multiplicative_expression →  • multiplicative_expression '/' unary_expression, multiplicative_expression →  • unary_expression, unary_expression →  • postfix_expression, unary_operator →  • '*', unary_expression →  • 'sizeof' unary_expression, primary_expression →  • '(' expression ')', postfix_expression →  • postfix_expression '[' expression ']', postfix_expression →  • postfix_expression '++', additive_expression →  • multiplicative_expression, postfix_expression →  • postfix_expression '->' IDENTIFIER, unary_operator →  • '+', unary_expression →  • 'sizeof' '(' type_name ')', unary_operator →  • '-'}
# s36 = {inclusive_or_expression → inclusive_or_expression • '|' exclusive_or_expression, logical_and_expression → inclusive_or_expression • }
# s37 = {assignment_expression → conditional_expression • }
# s38 = {relational_expression → relational_expression '<' shift_expression • , shift_expression → shift_expression • '>>' additive_expression, shift_expression → shift_expression • '<<' additive_expression}
# s39 = {postfix_expression →  • postfix_expression '(' argument_expression_list ')', postfix_expression →  • postfix_expression '--', postfix_expression →  • primary_expression, postfix_expression →  • postfix_expression '(' ')', postfix_expression →  • postfix_expression '.' IDENTIFIER, multiplicative_expression →  • multiplicative_expression '%' unary_expression, unary_operator →  • '~', additive_expression →  • additive_expression '-' multiplicative_expression, multiplicative_expression →  • multiplicative_expression '*' unary_expression, additive_expression →  • additive_expression '+' multiplicative_expression, primary_expression →  • IDENTIFIER, primary_expression →  • STRING_LITERAL, unary_operator →  • '!', unary_expression →  • unary_operator unary_expression, unary_expression →  • '++' unary_expression, shift_expression → shift_expression '<<' • additive_expression, unary_expression →  • '--' unary_expression, primary_expression →  • CONSTANT, unary_operator →  • '&', multiplicative_expression →  • multiplicative_expression '/' unary_expression, multiplicative_expression →  • unary_expression, unary_expression →  • postfix_expression, unary_operator →  • '*', unary_expression →  • 'sizeof' unary_expression, primary_expression →  • '(' expression ')', postfix_expression →  • postfix_expression '[' expression ']', postfix_expression →  • postfix_expression '++', additive_expression →  • multiplicative_expression, postfix_expression →  • postfix_expression '->' IDENTIFIER, unary_operator →  • '+', unary_expression →  • 'sizeof' '(' type_name ')', unary_operator →  • '-'}
# ...
# goto(s43, struct_declaration) = s83
# goto(s43, type_qualifier) = s61
# goto(s43, specifier_qualifier_list) = s22
# goto(s43, enum_specifier) = s238
# goto(s43, struct_or_union) = s93
# goto(s51, primary_expression) = s66
# goto(s51, relational_expression) = s178
# goto(s51, additive_expression) = s154
# goto(s51, constant_expression) = s214
# goto(s51, exclusive_or_expression) = s185
# goto(s51, conditional_expression) = s98
# goto(s51, inclusive_or_expression) = s36
# goto(s51, shift_expression) = s2
# goto(s51, unary_expression) = s119
# goto(s51, unary_operator) = s85
# goto(s51, postfix_expression) = s206
# goto(s51, logical_or_expression) = s60
# goto(s51, logical_and_expression) = s108
# goto(s51, equality_expression) = s100
# goto(s51, multiplicative_expression) = s107
# goto(s51, and_expression) = s121
# goto(s52, primary_expression) = s66
# goto(s52, relational_expression) = s196
# goto(s52, additive_expression) = s154
# goto(s52, shift_expression) = s2
# goto(s52, unary_expression) = s119
# goto(s52, unary_operator) = s85
# goto(s52, postfix_expression) = s206
# goto(s52, multiplicative_expression) = s107
# goto(s55, type_specifier) = s91
# goto(s55, struct_or_union_specifier) = s126
# goto(s55, struct_declaration) = s92
# goto(s55, type_qualifier) = s61
# goto(s55, specifier_qualifier_list) = s22
# goto(s55, struct_declaration_list) = s26
# goto(s55, enum_specifier) = s238
# goto(s55, struct_or_union) = s93
# goto(s57, primary_expression) = s66
# goto(s57, relational_expression) = s178
# goto(s57, additive_expression) = s154
# goto(s57, exclusive_or_expression) = s185
# goto(s57, inclusive_or_expression) = s134
# goto(s57, shift_expression) = s2
# goto(s57, unary_expression) = s119
# goto(s57, unary_operator) = s85
# goto(s57, postfix_expression) = s206
# goto(s57, equality_expression) = s100
# goto(s57, multiplicative_expression) = s107
# goto(s57, and_expression) = s121
# goto(s61, type_specifier) = s91
# goto(s61, struct_or_union_specifier) = s126
# goto(s61, type_qualifier) = s61
# goto(s61, specifier_qualifier_list) = s8
# goto(s61, enum_specifier) = s238
# goto(s61, struct_or_union) = s93
# goto(s75, direct_declarator) = s153
# goto(s78, assignment_operator) = s179
# goto(s85, primary_expression) = s66
# goto(s85, unary_expression) = s71
# goto(s85, unary_operator) = s85
# goto(s85, postfix_expression) = s206
# goto(s91, type_specifier) = s91
# goto(s91, struct_or_union_specifier) = s126
# goto(s91, type_qualifier) = s61
# goto(s91, specifier_qualifier_list) = s198
# goto(s91, enum_specifier) = s238
# goto(s91, struct_or_union) = s93
# goto(s94, primary_expression) = s66
# goto(s94, unary_expression) = s13
# goto(s94, unary_operator) = s85
# goto(s94, postfix_expression) = s206
# goto(s95, direct_abstract_declarator) = s53
# goto(s95, pointer) = s31
# goto(s95, abstract_declarator) = s195
# goto(s99, direct_declarator) = s153
# goto(s99, direct_abstract_declarator) = s226
# goto(s101, type_specifier) = s203
# goto(s101, struct_or_union_specifier) = s126
# goto(s101, type_qualifier) = s101
# goto(s101, declaration_specifiers) = s110
# goto(s101, enum_specifier) = s238
# goto(s101, struct_or_union) = s93
# goto(s101, storage_class_specifier) = s15
# goto(s102, primary_expression) = s66
# goto(s102, unary_expression) = s166
# goto(s102, unary_operator) = s85
# goto(s102, postfix_expression) = s206
# goto(s103, primary_expression) = s66
# goto(s103, additive_expression) = s154
# goto(s103, shift_expression) = s38
# goto(s103, unary_expression) = s119
# goto(s103, unary_operator) = s85
# goto(s103, postfix_expression) = s206
# goto(s103, multiplicative_expression) = s107
# goto(s104, primary_expression) = s66
# goto(s104, relational_expression) = s73
# goto(s104, additive_expression) = s154
# goto(s104, shift_expression) = s2
# goto(s104, unary_expression) = s119
# goto(s104, unary_operator) = s85
# goto(s104, postfix_expression) = s206
# goto(s104, multiplicative_expression) = s107
# goto(s118, primary_expression) = s66
# goto(s118, relational_expression) = s178
# goto(s118, additive_expression) = s154
# goto(s118, constant_expression) = s207
# goto(s118, exclusive_or_expression) = s185
# goto(s118, conditional_expression) = s98
# goto(s118, inclusive_or_expression) = s36
# goto(s118, shift_expression) = s2
# goto(s118, unary_expression) = s119
# goto(s118, unary_operator) = s85
# goto(s118, postfix_expression) = s206
# goto(s118, logical_or_expression) = s60
# goto(s118, logical_and_expression) = s108
# goto(s118, equality_expression) = s100
# goto(s118, multiplicative_expression) = s107
# goto(s118, and_expression) = s121
# goto(s120, primary_expression) = s66
# goto(s120, relational_expression) = s178
# goto(s120, additive_expression) = s154
# goto(s120, exclusive_or_expression) = s185
# goto(s120, conditional_expression) = s37
# goto(s120, inclusive_or_expression) = s36
# goto(s120, shift_expression) = s2
# goto(s120, unary_expression) = s78
# goto(s120, unary_operator) = s85
# goto(s120, postfix_expression) = s206
# goto(s120, logical_or_expression) = s60
# goto(s120, logical_and_expression) = s108
# goto(s120, equality_expression) = s100
# goto(s120, multiplicative_expression) = s107
# goto(s120, and_expression) = s121
# goto(s120, assignment_expression) = s67
# goto(s122, primary_expression) = s66
# goto(s122, unary_expression) = s113
# goto(s122, unary_operator) = s85
# goto(s122, postfix_expression) = s206
# goto(s124, primary_expression) = s66
# goto(s124, unary_expression) = s189
# goto(s124, unary_operator) = s85
# goto(s124, postfix_expression) = s206
# goto(s127, primary_expression) = s66
# goto(s127, unary_expression) = s167
# goto(s127, unary_operator) = s85
# goto(s127, postfix_expression) = s206
# goto(s128, type_specifier) = s203
# goto(s128, struct_or_union_specifier) = s126
# goto(s128, parameter_type_list) = s114
# goto(s128, direct_abstract_declarator) = s53
# goto(s128, type_qualifier) = s101
# goto(s128, parameter_declaration) = s44
# goto(s128, pointer) = s31
# goto(s128, declaration_specifiers) = s171
# goto(s128, enum_specifier) = s238
# goto(s128, parameter_list) = s88
# goto(s128, struct_or_union) = s93
# goto(s128, abstract_declarator) = s149
# goto(s128, storage_class_specifier) = s15
# goto(s0, primary_expression) = s76
# goto(s135, primary_expression) = s66
# goto(s135, relational_expression) = s178
# goto(s135, additive_expression) = s154
# goto(s135, exclusive_or_expression) = s185
# goto(s135, conditional_expression) = s37
# goto(s135, inclusive_or_expression) = s36
# goto(s135, shift_expression) = s2
# goto(s135, unary_expression) = s78
# goto(s135, unary_operator) = s85
# goto(s135, expression) = s46
# goto(s135, postfix_expression) = s206
# goto(s135, logical_or_expression) = s60
# goto(s135, logical_and_expression) = s108
# goto(s135, equality_expression) = s100
# goto(s135, multiplicative_expression) = s107
# goto(s135, and_expression) = s121
# goto(s135, assignment_expression) = s105
# goto(s142, type_specifier) = s203
# goto(s142, struct_or_union_specifier) = s126
# goto(s142, parameter_type_list) = s235
# goto(s142, type_qualifier) = s101
# goto(s142, parameter_declaration) = s44
# goto(s142, declaration_specifiers) = s171
# goto(s142, enum_specifier) = s238
# goto(s142, parameter_list) = s88
# goto(s142, struct_or_union) = s93
# goto(s142, storage_class_specifier) = s15
# goto(s142, identifier_list) = s138
# goto(s146, primary_expression) = s66
# goto(s146, relational_expression) = s178
# goto(s146, additive_expression) = s154
# goto(s146, constant_expression) = s117
# goto(s146, exclusive_or_expression) = s185
# goto(s146, conditional_expression) = s98
# goto(s146, inclusive_or_expression) = s36
# goto(s146, shift_expression) = s2
# goto(s146, unary_expression) = s119
# goto(s146, unary_operator) = s85
# goto(s146, postfix_expression) = s206
# goto(s146, logical_or_expression) = s60
# goto(s146, logical_and_expression) = s108
# goto(s146, equality_expression) = s100
# goto(s146, multiplicative_expression) = s107
# goto(s146, and_expression) = s121
# goto(s159, direct_declarator) = s115
# goto(s159, declarator) = s116
# goto(s159, pointer) = s75
# goto(s160, direct_declarator) = s115
# goto(s160, declarator) = s111
# goto(s160, pointer) = s75
# goto(s160, struct_declarator) = s42
# goto(s171, direct_declarator) = s115
# goto(s171, declarator) = s208
# goto(s171, direct_abstract_declarator) = s53
# goto(s171, pointer) = s99
# goto(s171, abstract_declarator) = s77
# goto(s176, type_specifier) = s203
# goto(s176, struct_or_union_specifier) = s126
# goto(s176, type_qualifier) = s101
# goto(s176, parameter_declaration) = s229
# goto(s176, declaration_specifiers) = s171
# goto(s176, enum_specifier) = s238
# goto(s176, struct_or_union) = s93
# goto(s176, storage_class_specifier) = s15
# goto(s179, primary_expression) = s66
# goto(s179, relational_expression) = s178
# goto(s179, additive_expression) = s154
# goto(s179, exclusive_or_expression) = s185
# goto(s179, conditional_expression) = s37
# goto(s179, inclusive_or_expression) = s36
# goto(s179, shift_expression) = s2
# goto(s179, unary_expression) = s78
# goto(s179, unary_operator) = s85
# goto(s179, postfix_expression) = s206
# goto(s179, logical_or_expression) = s60
# goto(s179, logical_and_expression) = s108
# goto(s179, equality_expression) = s100
# goto(s179, multiplicative_expression) = s107
# goto(s179, and_expression) = s121
# goto(s179, assignment_expression) = s84
# goto(s180, primary_expression) = s66
# goto(s180, unary_expression) = s119
# goto(s180, unary_operator) = s85
# goto(s180, postfix_expression) = s206
# goto(s180, multiplicative_expression) = s155
# goto(s181, type_specifier) = s203
# goto(s181, struct_or_union_specifier) = s126
# goto(s181, parameter_type_list) = s163
# goto(s181, type_qualifier) = s101
# goto(s181, parameter_declaration) = s44
# goto(s181, declaration_specifiers) = s171
# goto(s181, enum_specifier) = s238
# goto(s181, parameter_list) = s88
# goto(s181, struct_or_union) = s93
# goto(s181, storage_class_specifier) = s15
# goto(s183, primary_expression) = s66
# goto(s183, relational_expression) = s178
# goto(s183, additive_expression) = s154
# goto(s183, exclusive_or_expression) = s185
# goto(s183, conditional_expression) = s37
# goto(s183, inclusive_or_expression) = s36
# goto(s183, shift_expression) = s2
# goto(s183, unary_expression) = s78
# goto(s183, unary_operator) = s85
# goto(s183, expression) = s191
# goto(s183, postfix_expression) = s206
# goto(s183, logical_or_expression) = s60
# goto(s183, logical_and_expression) = s108
# goto(s183, equality_expression) = s100
# goto(s183, multiplicative_expression) = s107
# goto(s183, and_expression) = s121
# goto(s183, assignment_expression) = s105
# goto(s187, primary_expression) = s66
# goto(s187, unary_expression) = s119
# goto(s187, unary_operator) = s85
# goto(s187, postfix_expression) = s206
# goto(s187, multiplicative_expression) = s62
# goto(s190, primary_expression) = s66
# goto(s190, relational_expression) = s178
# goto(s190, additive_expression) = s154
# goto(s190, exclusive_or_expression) = s234
# goto(s190, shift_expression) = s2
# goto(s190, unary_expression) = s119
# goto(s190, unary_operator) = s85
# goto(s190, postfix_expression) = s206
# goto(s190, equality_expression) = s100
# goto(s190, multiplicative_expression) = s107
# goto(s190, and_expression) = s121
# goto(s192, primary_expression) = s66
# goto(s192, relational_expression) = s178
# goto(s192, additive_expression) = s154
# goto(s192, constant_expression) = s64
# goto(s192, exclusive_or_expression) = s185
# goto(s192, conditional_expression) = s98
# goto(s192, inclusive_or_expression) = s36
# goto(s192, shift_expression) = s2
# goto(s192, unary_expression) = s119
# goto(s192, unary_operator) = s85
# goto(s192, postfix_expression) = s206
# goto(s192, logical_or_expression) = s60
# goto(s192, logical_and_expression) = s108
# goto(s192, equality_expression) = s100
# goto(s192, multiplicative_expression) = s107
# goto(s192, and_expression) = s121
# goto(s197, primary_expression) = s66
# goto(s197, additive_expression) = s154
# goto(s197, shift_expression) = s28
# goto(s197, unary_expression) = s119
# goto(s197, unary_operator) = s85
# goto(s197, postfix_expression) = s206
# goto(s197, multiplicative_expression) = s107
# goto(s203, type_specifier) = s203
# goto(s203, struct_or_union_specifier) = s126
# goto(s203, type_qualifier) = s101
# goto(s203, declaration_specifiers) = s1
# goto(s203, enum_specifier) = s238
# goto(s203, struct_or_union) = s93
# goto(s203, storage_class_specifier) = s15
# goto(s204, primary_expression) = s66
# goto(s204, relational_expression) = s178
# goto(s204, additive_expression) = s154
# goto(s204, constant_expression) = s96
# goto(s204, exclusive_or_expression) = s185
# goto(s204, conditional_expression) = s98
# goto(s204, inclusive_or_expression) = s36
# goto(s204, shift_expression) = s2
# goto(s204, unary_expression) = s119
# goto(s204, unary_operator) = s85
# goto(s204, postfix_expression) = s206
# goto(s204, logical_or_expression) = s60
# goto(s204, logical_and_expression) = s108
# goto(s204, equality_expression) = s100
# goto(s204, multiplicative_expression) = s107
# goto(s204, and_expression) = s121
# goto(s205, primary_expression) = s66
# goto(s205, relational_expression) = s178
# goto(s205, additive_expression) = s154
# goto(s205, exclusive_or_expression) = s185
# goto(s205, conditional_expression) = s37
# goto(s205, inclusive_or_expression) = s36
# goto(s205, shift_expression) = s2
# goto(s205, unary_expression) = s78
# goto(s205, unary_operator) = s85
# goto(s205, postfix_expression) = s206
# goto(s205, logical_or_expression) = s60
# goto(s205, logical_and_expression) = s108
# goto(s205, equality_expression) = s100
# goto(s205, multiplicative_expression) = s107
# goto(s205, and_expression) = s121
# goto(s205, assignment_expression) = s218
# goto(s209, primary_expression) = s66
# goto(s209, additive_expression) = s154
# goto(s209, shift_expression) = s199
# goto(s209, unary_expression) = s119
# goto(s209, unary_operator) = s85
# goto(s209, postfix_expression) = s206
# goto(s209, multiplicative_expression) = s107
# goto(s212, primary_expression) = s66
# goto(s212, unary_expression) = s79
# goto(s212, unary_operator) = s85
# goto(s212, postfix_expression) = s206
# goto(s217, enumerator) = s210
# goto(s217, enumerator_list) = s3
# goto(s219, primary_expression) = s66
# goto(s219, relational_expression) = s178
# goto(s219, additive_expression) = s154
# goto(s219, shift_expression) = s2
# goto(s219, unary_expression) = s119
# goto(s219, unary_operator) = s85
# goto(s219, postfix_expression) = s206
# goto(s219, equality_expression) = s100
# goto(s219, multiplicative_expression) = s107
# goto(s219, and_expression) = s152
# goto(s223, type_specifier) = s91
# goto(s223, primary_expression) = s66
# goto(s223, relational_expression) = s178
# goto(s223, additive_expression) = s154
# goto(s223, exclusive_or_expression) = s185
# goto(s223, conditional_expression) = s37
# goto(s223, struct_or_union_specifier) = s126
# goto(s223, inclusive_or_expression) = s36
# goto(s223, shift_expression) = s2
# goto(s223, unary_expression) = s78
# goto(s223, type_qualifier) = s61
# goto(s223, unary_operator) = s85
# goto(s223, specifier_qualifier_list) = s95
# goto(s223, expression) = s46
# goto(s223, postfix_expression) = s206
# goto(s223, enum_specifier) = s238
# goto(s223, struct_or_union) = s93
# goto(s223, logical_or_expression) = s60
# goto(s223, logical_and_expression) = s108
# goto(s223, equality_expression) = s100
# goto(s223, multiplicative_expression) = s107
# goto(s223, and_expression) = s121
# goto(s223, assignment_expression) = s105
# goto(s223, type_name) = s89
# goto(s224, type_specifier) = s91
# goto(s224, struct_or_union_specifier) = s126
# goto(s224, struct_declaration) = s92
# goto(s224, type_qualifier) = s61
# goto(s224, specifier_qualifier_list) = s22
# goto(s224, struct_declaration_list) = s43
# goto(s224, enum_specifier) = s238
# goto(s224, struct_or_union) = s93
# goto(s228, enumerator) = s210
# goto(s228, enumerator_list) = s82
# goto(s230, enumerator) = s174
# goto(s236, type_specifier) = s203
# goto(s236, struct_or_union_specifier) = s126
# goto(s236, direct_declarator) = s115
# goto(s236, parameter_type_list) = s114
# goto(s236, declarator) = s116
# goto(s236, direct_abstract_declarator) = s53
# goto(s236, type_qualifier) = s101
# goto(s236, parameter_declaration) = s44
# goto(s236, pointer) = s99
# goto(s236, declaration_specifiers) = s171
# goto(s236, enum_specifier) = s238
# goto(s236, parameter_list) = s88
# goto(s236, struct_or_union) = s93
# goto(s236, abstract_declarator) = s149
# goto(s236, storage_class_specifier) = s15
# CPU times: user 906 ms, sys: 119 ms, total: 1.03 s
# Wall time: 1.24 s

# %%
def strip_quotes(t):
    if t[0] == "'" and t[-1] == "'":
        return t[1:-1]
    return t

# %%
def dump_parse_table(self, file):
    with open(file, 'w') as handle:
        handle.write('# Grammar rules:\n')
        for rule in self.mRules:
            rule_name = self.mRuleNames[rule] 
            handle.write(f'{rule_name} = ("{rule.mVariable}", {rule.mBody})\n')
        handle.write('\n# Action table:\n')
        handle.write('actionTable = {}\n')
        for s, t in self.mActionTable:
            action = self.mActionTable[s, t]
            t = strip_quotes(t)
            if action[0] == 'reduce':
                rule_name = action[1]
                handle.write(f"actionTable['{s}', '{t}'] = ('reduce', {rule_name})\n")
            elif action == 'accept':
                handle.write(f"actionTable['{s}', '{t}'] = 'accept'\n")
            else:
                handle.write(f"actionTable['{s}', '{t}'] = {action}\n")
        handle.write('\n# Goto table:\n')
        handle.write('gotoTable = {}\n')
        for s, v in self.mGotoTable:
            state = self.mGotoTable[s, v]
            handle.write(f"gotoTable['{s}', '{v}'] = '{state}'\n")
        
Grammar.dump_parse_table = dump_parse_table
del dump_parse_table

# %%
g.dump_parse_table('parse-table.py')

# %%
cat parse-table.py
# Out:
# # Grammar rules:
# r0 = ("primary_expression", ('IDENTIFIER',))
# r1 = ("primary_expression", ('CONSTANT',))
# r2 = ("primary_expression", ('STRING_LITERAL',))
# r3 = ("primary_expression", ("'('", 'expression', "')'"))
# r4 = ("postfix_expression", ('primary_expression',))
# r5 = ("postfix_expression", ('postfix_expression', "'['", 'expression', "']'"))
# r6 = ("postfix_expression", ('postfix_expression', "'('", "')'"))
# r7 = ("postfix_expression", ('postfix_expression', "'('", 'argument_expression_list', "')'"))
# r8 = ("postfix_expression", ('postfix_expression', "'.'", 'IDENTIFIER'))
# r9 = ("postfix_expression", ('postfix_expression', "'->'", 'IDENTIFIER'))
# r10 = ("postfix_expression", ('postfix_expression', "'++'"))
# r11 = ("postfix_expression", ('postfix_expression', "'--'"))
# r12 = ("argument_expression_list", ('assignment_expression',))
# r13 = ("argument_expression_list", ('argument_expression_list', "','", 'assignment_expression'))
# r14 = ("unary_expression", ('postfix_expression',))
# r15 = ("unary_expression", ("'++'", 'unary_expression'))
# r16 = ("unary_expression", ("'--'", 'unary_expression'))
# r17 = ("unary_expression", ('unary_operator', 'unary_expression'))
# r18 = ("unary_expression", ("'sizeof'", 'unary_expression'))
# r19 = ("unary_expression", ("'sizeof'", "'('", 'type_name', "')'"))
# r20 = ("unary_operator", ("'&'",))
# r21 = ("unary_operator", ("'*'",))
# r22 = ("unary_operator", ("'+'",))
# r23 = ("unary_operator", ("'-'",))
# r24 = ("unary_operator", ("'~'",))
# r25 = ("unary_operator", ("'!'",))
# r26 = ("multiplicative_expression", ('unary_expression',))
# r27 = ("multiplicative_expression", ('multiplicative_expression', "'*'", 'unary_expression'))
# r28 = ("multiplicative_expression", ('multiplicative_expression', "'/'", 'unary_expression'))
# r29 = ("multiplicative_expression", ('multiplicative_expression', "'%'", 'unary_expression'))
# r30 = ("additive_expression", ('multiplicative_expression',))
# r31 = ("additive_expression", ('additive_expression', "'+'", 'multiplicative_expression'))
# r32 = ("additive_expression", ('additive_expression', "'-'", 'multiplicative_expression'))
# r33 = ("shift_expression", ('additive_expression',))
# r34 = ("shift_expression", ('shift_expression', "'<<'", 'additive_expression'))
# r35 = ("shift_expression", ('shift_expression', "'>>'", 'additive_expression'))
# r36 = ("relational_expression", ('shift_expression',))
# r37 = ("relational_expression", ('relational_expression', "'<'", 'shift_expression'))
# r38 = ("relational_expression", ('relational_expression', "'>'", 'shift_expression'))
# r39 = ("relational_expression", ('relational_expression', "'<='", 'shift_expression'))
# r40 = ("relational_expression", ('relational_expression', "'>='", 'shift_expression'))
# r41 = ("equality_expression", ('relational_expression',))
# r42 = ("equality_expression", ('equality_expression', "'=='", 'relational_expression'))
# r43 = ("equality_expression", ('equality_expression', "'!='", 'relational_expression'))
# r44 = ("and_expression", ('equality_expression',))
# r45 = ("and_expression", ('and_expression', "'&'", 'equality_expression'))
# r46 = ("exclusive_or_expression", ('and_expression',))
# r47 = ("exclusive_or_expression", ('exclusive_or_expression', "'^'", 'and_expression'))
# r48 = ("inclusive_or_expression", ('exclusive_or_expression',))
# r49 = ("inclusive_or_expression", ('inclusive_or_expression', "'|'", 'exclusive_or_expression'))
# r50 = ("logical_and_expression", ('inclusive_or_expression',))
# r51 = ("logical_and_expression", ('logical_and_expression', "'&&'", 'inclusive_or_expression'))
# r52 = ("logical_or_expression", ('logical_and_expression',))
# r53 = ("logical_or_expression", ('logical_or_expression', "'||'", 'logical_and_expression'))
# r54 = ("conditional_expression", ('logical_or_expression',))
# r55 = ("conditional_expression", ('logical_or_expression', "'?'", 'expression', "':'", 'conditional_expression'))
# r56 = ("assignment_expression", ('conditional_expression',))
# r57 = ("assignment_expression", ('unary_expression', 'assignment_operator', 'assignment_expression'))
# r58 = ("assignment_operator", ("'='",))
# r59 = ("assignment_operator", ("'*='",))
# r60 = ("assignment_operator", ("'/='",))
# r61 = ("assignment_operator", ("'%='",))
# r62 = ("assignment_operator", ("'+='",))
# r63 = ("assignment_operator", ("'-='",))
# r64 = ("assignment_operator", ("'<<='",))
# r65 = ("assignment_operator", ("'>>='",))
# r66 = ("assignment_operator", ("'&='",))
# r67 = ("assignment_operator", ("'^='",))
# r68 = ("assignment_operator", ("'|='",))
# r69 = ("expression", ('assignment_expression',))
# r70 = ("expression", ('expression', "','", 'assignment_expression'))
# r71 = ("constant_expression", ('conditional_expression',))
# r72 = ("declaration", ('declaration_specifiers', "';'"))
# r73 = ("declaration", ('declaration_specifiers', 'init_declarator_list', "';'"))
# r74 = ("declaration_specifiers", ('storage_class_specifier',))
# r75 = ("declaration_specifiers", ('storage_class_specifier', 'declaration_specifiers'))
# r76 = ("declaration_specifiers", ('type_specifier',))
# r77 = ("declaration_specifiers", ('type_specifier', 'declaration_specifiers'))
# r78 = ("declaration_specifiers", ('type_qualifier',))
# r79 = ("declaration_specifiers", ('type_qualifier', 'declaration_specifiers'))
# r80 = ("init_declarator_list", ('init_declarator',))
# r81 = ("init_declarator_list", ('init_declarator_list', "','", 'init_declarator'))
# r82 = ("init_declarator", ('declarator',))
# r83 = ("init_declarator", ('declarator', "'='", 'initializer'))
# r84 = ("storage_class_specifier", ("'typedef'",))
# r85 = ("storage_class_specifier", ("'extern'",))
# r86 = ("storage_class_specifier", ("'static'",))
# r87 = ("storage_class_specifier", ("'auto'",))
# r88 = ("storage_class_specifier", ("'register'",))
# r89 = ("type_specifier", ("'void'",))
# r90 = ("type_specifier", ("'char'",))
# r91 = ("type_specifier", ("'short'",))
# r92 = ("type_specifier", ("'int'",))
# r93 = ("type_specifier", ("'long'",))
# r94 = ("type_specifier", ("'float'",))
# r95 = ("type_specifier", ("'double'",))
# r96 = ("type_specifier", ("'signed'",))
# r97 = ("type_specifier", ("'unsigned'",))
# r98 = ("type_specifier", ('struct_or_union_specifier',))
# r99 = ("type_specifier", ('enum_specifier',))
# r100 = ("type_specifier", ('TYPE_NAME',))
# r101 = ("struct_or_union_specifier", ('struct_or_union', 'IDENTIFIER', "'{'", 'struct_declaration_list', "'}'"))
# r102 = ("struct_or_union_specifier", ('struct_or_union', "'{'", 'struct_declaration_list', "'}'"))
# r103 = ("struct_or_union_specifier", ('struct_or_union', 'IDENTIFIER'))
# r104 = ("struct_or_union", ("'struct'",))
# r105 = ("struct_or_union", ("'union'",))
# r106 = ("struct_declaration_list", ('struct_declaration',))
# r107 = ("struct_declaration_list", ('struct_declaration_list', 'struct_declaration'))
# r108 = ("struct_declaration", ('specifier_qualifier_list', 'struct_declarator_list', "';'"))
# r109 = ("specifier_qualifier_list", ('type_specifier', 'specifier_qualifier_list'))
# r110 = ("specifier_qualifier_list", ('type_specifier',))
# r111 = ("specifier_qualifier_list", ('type_qualifier', 'specifier_qualifier_list'))
# r112 = ("specifier_qualifier_list", ('type_qualifier',))
# r113 = ("struct_declarator_list", ('struct_declarator',))
# r114 = ("struct_declarator_list", ('struct_declarator_list', "','", 'struct_declarator'))
# r115 = ("struct_declarator", ('declarator',))
# r116 = ("struct_declarator", ("':'", 'constant_expression'))
# r117 = ("struct_declarator", ('declarator', "':'", 'constant_expression'))
# r118 = ("enum_specifier", ("'enum'", "'{'", 'enumerator_list', "'}'"))
# r119 = ("enum_specifier", ("'enum'", 'IDENTIFIER', "'{'", 'enumerator_list', "'}'"))
# r120 = ("enum_specifier", ("'enum'", 'IDENTIFIER'))
# r121 = ("enumerator_list", ('enumerator',))
# r122 = ("enumerator_list", ('enumerator_list', "','", 'enumerator'))
# r123 = ("enumerator", ('IDENTIFIER',))
# r124 = ("enumerator", ('IDENTIFIER', "'='", 'constant_expression'))
# r125 = ("type_qualifier", ("'const'",))
# r126 = ("type_qualifier", ("'volatile'",))
# r127 = ("declarator", ('pointer', 'direct_declarator'))
# r128 = ("declarator", ('direct_declarator',))
# r129 = ("direct_declarator", ('IDENTIFIER',))
# r130 = ("direct_declarator", ("'('", 'declarator', "')'"))
# r131 = ("direct_declarator", ('direct_declarator', "'['", 'constant_expression', "']'"))
# r132 = ("direct_declarator", ('direct_declarator', "'['", "']'"))
# r133 = ("direct_declarator", ('direct_declarator', "'('", 'parameter_type_list', "')'"))
# r134 = ("direct_declarator", ('direct_declarator', "'('", 'identifier_list', "')'"))
# r135 = ("direct_declarator", ('direct_declarator', "'('", "')'"))
# r136 = ("pointer", ("'*'",))
# r137 = ("pointer", ("'*'", 'type_qualifier_list'))
# r138 = ("pointer", ("'*'", 'pointer'))
# r139 = ("pointer", ("'*'", 'type_qualifier_list', 'pointer'))
# r140 = ("type_qualifier_list", ('type_qualifier',))
# r141 = ("type_qualifier_list", ('type_qualifier_list', 'type_qualifier'))
# r142 = ("parameter_type_list", ('parameter_list',))
# r143 = ("parameter_type_list", ('parameter_list', "','", "'...'"))
# r144 = ("parameter_list", ('parameter_declaration',))
# r145 = ("parameter_list", ('parameter_list', "','", 'parameter_declaration'))
# r146 = ("parameter_declaration", ('declaration_specifiers', 'declarator'))
# r147 = ("parameter_declaration", ('declaration_specifiers', 'abstract_declarator'))
# r148 = ("parameter_declaration", ('declaration_specifiers',))
# r149 = ("identifier_list", ('IDENTIFIER',))
# r150 = ("identifier_list", ('identifier_list', "','", 'IDENTIFIER'))
# r151 = ("type_name", ('specifier_qualifier_list',))
# r152 = ("type_name", ('specifier_qualifier_list', 'abstract_declarator'))
# r153 = ("abstract_declarator", ('pointer',))
# r154 = ("abstract_declarator", ('direct_abstract_declarator',))
# r155 = ("abstract_declarator", ('pointer', 'direct_abstract_declarator'))
# r156 = ("direct_abstract_declarator", ("'('", 'abstract_declarator', "')'"))
# r157 = ("direct_abstract_declarator", ("'['", "']'"))
# r158 = ("direct_abstract_declarator", ("'['", 'constant_expression', "']'"))
# r159 = ("direct_abstract_declarator", ('direct_abstract_declarator', "'['", "']'"))
# r160 = ("direct_abstract_declarator", ('direct_abstract_declarator', "'['", 'constant_expression', "']'"))
# r161 = ("direct_abstract_declarator", ("'('", "')'"))
# r162 = ("direct_abstract_declarator", ("'('", 'parameter_type_list', "')'"))
# r163 = ("direct_abstract_declarator", ('direct_abstract_declarator', "'('", "')'"))
# r164 = ("direct_abstract_declarator", ('direct_abstract_declarator', "'('", 'parameter_type_list', "')'"))
# r165 = ("initializer", ('assignment_expression',))
# r166 = ("initializer", ("'{'", 'initializer_list', "'}'"))
# r167 = ("initializer", ("'{'", 'initializer_list', "','", "'}'"))
# r168 = ("initializer_list", ('initializer',))
# r169 = ("initializer_list", ('initializer_list', "','", 'initializer'))
# r170 = ("statement", ('labeled_statement',))
# r171 = ("statement", ('compound_statement',))
# r172 = ("statement", ('expression_statement',))
# r173 = ("statement", ('selection_statement',))
# r174 = ("statement", ('iteration_statement',))
# r175 = ("statement", ('jump_statement',))
# r176 = ("labeled_statement", ('IDENTIFIER', "':'", 'statement'))
# r177 = ("labeled_statement", ("'case'", 'constant_expression', "':'", 'statement'))
# r178 = ("labeled_statement", ("'default'", "':'", 'statement'))
# r179 = ("compound_statement", ("'{'", "'}'"))
# r180 = ("compound_statement", ("'{'", 'statement_list', "'}'"))
# r181 = ("compound_statement", ("'{'", 'declaration_list', "'}'"))
# r182 = ("compound_statement", ("'{'", 'declaration_list', 'statement_list', "'}'"))
# r183 = ("declaration_list", ('declaration',))
# r184 = ("declaration_list", ('declaration_list', 'declaration'))
# r185 = ("statement_list", ('statement',))
# r186 = ("statement_list", ('statement_list', 'statement'))
# r187 = ("expression_statement", ("';'",))
# r188 = ("expression_statement", ('expression', "';'"))
# r189 = ("selection_statement", ("'if'", "'('", 'expression', "')'", 'statement'))
# r190 = ("selection_statement", ("'if'", "'('", 'expression', "')'", 'statement', "'else'", 'statement'))
# r191 = ("selection_statement", ("'switch'", "'('", 'expression', "')'", 'statement'))
# r192 = ("iteration_statement", ("'while'", "'('", 'expression', "')'", 'statement'))
# r193 = ("iteration_statement", ("'do'", 'statement', "'while'", "'('", 'expression', "')'", "';'"))
# r194 = ("iteration_statement", ("'for'", "'('", 'expression_statement', 'expression_statement', "')'", 'statement'))
# r195 = ("iteration_statement", ("'for'", "'('", 'expression_statement', 'expression_statement', 'expression', "')'", 'statement'))
# r196 = ("jump_statement", ("'goto'", 'IDENTIFIER', "';'"))
# r197 = ("jump_statement", ("'continue'", "';'"))
# r198 = ("jump_statement", ("'break'", "';'"))
# r199 = ("jump_statement", ("'return'", "';'"))
# r200 = ("jump_statement", ("'return'", 'expression', "';'"))
# r201 = ("translation_unit", ('external_declaration',))
# r202 = ("translation_unit", ('translation_unit', 'external_declaration'))
# r203 = ("external_declaration", ('function_definition',))
# r204 = ("external_declaration", ('declaration',))
# r205 = ("function_definition", ('declaration_specifiers', 'declarator', 'declaration_list', 'compound_statement'))
# r206 = ("function_definition", ('declaration_specifiers', 'declarator', 'compound_statement'))
# r207 = ("function_definition", ('declarator', 'declaration_list', 'compound_statement'))
# r208 = ("function_definition", ('declarator', 'compound_statement'))
# r209 = ("ŝ", ('primary_expression', '$'))
#
# # Action table:
# actionTable = {}
# actionTable['s1', ';'] = ('reduce', r77)
# actionTable['s1', ')'] = ('reduce', r77)
# actionTable['s1', ','] = ('reduce', r77)
# actionTable['s1', '('] = ('reduce', r77)
# actionTable['s1', '*'] = ('reduce', r77)
# actionTable['s1', 'IDENTIFIER'] = ('reduce', r77)
# actionTable['s1', '['] = ('reduce', r77)
# actionTable['s2', '>>'] = ('shift', 's33')
# actionTable['s2', '<<'] = ('shift', 's39')
# actionTable['s2', '?'] = ('reduce', r36)
# actionTable['s2', ';'] = ('reduce', r36)
# actionTable['s2', '}'] = ('reduce', r36)
# actionTable['s2', '|'] = ('reduce', r36)
# actionTable['s2', ')'] = ('reduce', r36)
# actionTable['s2', '&&'] = ('reduce', r36)
# actionTable['s2', '>='] = ('reduce', r36)
# actionTable['s2', '>'] = ('reduce', r36)
# actionTable['s2', '||'] = ('reduce', r36)
# actionTable['s2', '<'] = ('reduce', r36)
# actionTable['s2', ':'] = ('reduce', r36)
# actionTable['s2', ']'] = ('reduce', r36)
# actionTable['s2', '<='] = ('reduce', r36)
# actionTable['s2', '=='] = ('reduce', r36)
# actionTable['s2', ','] = ('reduce', r36)
# actionTable['s2', '!='] = ('reduce', r36)
# actionTable['s2', '&'] = ('reduce', r36)
# actionTable['s2', '^'] = ('reduce', r36)
# actionTable['s3', ','] = ('shift', 's230')
# actionTable['s3', '}'] = ('shift', 's11')
# actionTable['s5', '/'] = ('reduce', r1)
# actionTable['s5', '('] = ('reduce', r1)
# actionTable['s5', '}'] = ('reduce', r1)
# actionTable['s5', '&&'] = ('reduce', r1)
# actionTable['s5', '--'] = ('reduce', r1)
# actionTable['s5', '>='] = ('reduce', r1)
# actionTable['s5', '-'] = ('reduce', r1)
# actionTable['s5', ':'] = ('reduce', r1)
# actionTable['s5', ','] = ('reduce', r1)
# actionTable['s5', '!='] = ('reduce', r1)
# actionTable['s5', '+'] = ('reduce', r1)
# actionTable['s5', '&'] = ('reduce', r1)
# actionTable['s5', '^'] = ('reduce', r1)
# actionTable['s5', '>>'] = ('reduce', r1)
# actionTable['s5', ';'] = ('reduce', r1)
# actionTable['s5', '>>='] = ('reduce', r1)
# actionTable['s5', '|'] = ('reduce', r1)
# actionTable['s5', '<<='] = ('reduce', r1)
# actionTable['s5', '*='] = ('reduce', r1)
# actionTable['s5', ']'] = ('reduce', r1)
# actionTable['s5', '^='] = ('reduce', r1)
# actionTable['s5', '*'] = ('reduce', r1)
# actionTable['s5', '%='] = ('reduce', r1)
# actionTable['s5', '$'] = ('reduce', r1)
# actionTable['s5', '+='] = ('reduce', r1)
# actionTable['s5', '++'] = ('reduce', r1)
# actionTable['s5', '>'] = ('reduce', r1)
# actionTable['s5', '||'] = ('reduce', r1)
# actionTable['s5', '<='] = ('reduce', r1)
# actionTable['s5', '|='] = ('reduce', r1)
# actionTable['s5', '-='] = ('reduce', r1)
# actionTable['s5', '%'] = ('reduce', r1)
# actionTable['s5', '['] = ('reduce', r1)
# actionTable['s5', '?'] = ('reduce', r1)
# actionTable['s5', ')'] = ('reduce', r1)
# actionTable['s5', '='] = ('reduce', r1)
# actionTable['s5', '<'] = ('reduce', r1)
# actionTable['s5', '&='] = ('reduce', r1)
# actionTable['s5', '<<'] = ('reduce', r1)
# actionTable['s5', '/='] = ('reduce', r1)
# actionTable['s5', '=='] = ('reduce', r1)
# actionTable['s5', '->'] = ('reduce', r1)
# actionTable['s5', '.'] = ('reduce', r1)
# actionTable['s6', 'volatile'] = ('shift', 's30')
# actionTable['s6', '*'] = ('shift', 's7')
# actionTable['s6', 'const'] = ('shift', 's112')
# actionTable['s6', ')'] = ('reduce', r137)
# actionTable['s6', ','] = ('reduce', r137)
# actionTable['s6', '('] = ('reduce', r137)
# actionTable['s6', 'IDENTIFIER'] = ('reduce', r137)
# actionTable['s6', '['] = ('reduce', r137)
# actionTable['s7', 'volatile'] = ('shift', 's30')
# actionTable['s7', '*'] = ('shift', 's7')
# actionTable['s7', 'const'] = ('shift', 's112')
# actionTable['s7', ')'] = ('reduce', r136)
# actionTable['s7', ','] = ('reduce', r136)
# actionTable['s7', '('] = ('reduce', r136)
# actionTable['s7', 'IDENTIFIER'] = ('reduce', r136)
# actionTable['s7', '['] = ('reduce', r136)
# actionTable['s8', ')'] = ('reduce', r111)
# actionTable['s8', ':'] = ('reduce', r111)
# actionTable['s8', '('] = ('reduce', r111)
# actionTable['s8', '*'] = ('reduce', r111)
# actionTable['s8', 'IDENTIFIER'] = ('reduce', r111)
# actionTable['s8', '['] = ('reduce', r111)
# actionTable['s9', '('] = ('reduce', r102)
# actionTable['s9', 'static'] = ('reduce', r102)
# actionTable['s9', 'short'] = ('reduce', r102)
# actionTable['s9', 'float'] = ('reduce', r102)
# actionTable['s9', 'void'] = ('reduce', r102)
# actionTable['s9', 'union'] = ('reduce', r102)
# actionTable['s9', ':'] = ('reduce', r102)
# actionTable['s9', ','] = ('reduce', r102)
# actionTable['s9', 'long'] = ('reduce', r102)
# actionTable['s9', 'auto'] = ('reduce', r102)
# actionTable['s9', 'IDENTIFIER'] = ('reduce', r102)
# actionTable['s9', '['] = ('reduce', r102)
# actionTable['s9', 'enum'] = ('reduce', r102)
# actionTable['s9', ';'] = ('reduce', r102)
# actionTable['s9', 'volatile'] = ('reduce', r102)
# actionTable['s9', 'double'] = ('reduce', r102)
# actionTable['s9', ')'] = ('reduce', r102)
# actionTable['s9', 'typedef'] = ('reduce', r102)
# actionTable['s9', 'TYPE_NAME'] = ('reduce', r102)
# actionTable['s9', 'const'] = ('reduce', r102)
# actionTable['s9', 'unsigned'] = ('reduce', r102)
# actionTable['s9', 'int'] = ('reduce', r102)
# actionTable['s9', 'extern'] = ('reduce', r102)
# actionTable['s9', 'struct'] = ('reduce', r102)
# actionTable['s9', 'char'] = ('reduce', r102)
# actionTable['s9', 'signed'] = ('reduce', r102)
# actionTable['s9', '*'] = ('reduce', r102)
# actionTable['s9', 'register'] = ('reduce', r102)
# actionTable['s10', 'sizeof'] = ('shift', 's94')
# actionTable['s10', '('] = ('shift', 's135')
# actionTable['s10', '--'] = ('shift', 's102')
# actionTable['s10', '-'] = ('shift', 's143')
# actionTable['s10', '+'] = ('shift', 's161')
# actionTable['s10', 'IDENTIFIER'] = ('shift', 's123')
# actionTable['s10', 'STRING_LITERAL'] = ('shift', 's182')
# actionTable['s10', '*'] = ('shift', 's47')
# actionTable['s10', '++'] = ('shift', 's212')
# actionTable['s10', 'CONSTANT'] = ('shift', 's5')
# actionTable['s10', '~'] = ('shift', 's41')
# actionTable['s10', ')'] = ('shift', 's27')
# actionTable['s10', '&'] = ('shift', 's175')
# actionTable['s10', '!'] = ('shift', 's129')
# actionTable['s11', '('] = ('reduce', r119)
# actionTable['s11', 'static'] = ('reduce', r119)
# actionTable['s11', 'short'] = ('reduce', r119)
# actionTable['s11', 'float'] = ('reduce', r119)
# actionTable['s11', 'void'] = ('reduce', r119)
# actionTable['s11', 'union'] = ('reduce', r119)
# actionTable['s11', ':'] = ('reduce', r119)
# actionTable['s11', ','] = ('reduce', r119)
# actionTable['s11', 'long'] = ('reduce', r119)
# actionTable['s11', 'auto'] = ('reduce', r119)
# actionTable['s11', 'IDENTIFIER'] = ('reduce', r119)
# actionTable['s11', '['] = ('reduce', r119)
# actionTable['s11', 'enum'] = ('reduce', r119)
# actionTable['s11', ';'] = ('reduce', r119)
# actionTable['s11', 'volatile'] = ('reduce', r119)
# actionTable['s11', 'double'] = ('reduce', r119)
# actionTable['s11', ')'] = ('reduce', r119)
# actionTable['s11', 'typedef'] = ('reduce', r119)
# actionTable['s11', 'TYPE_NAME'] = ('reduce', r119)
# actionTable['s11', 'const'] = ('reduce', r119)
# actionTable['s11', 'unsigned'] = ('reduce', r119)
# actionTable['s11', 'int'] = ('reduce', r119)
# actionTable['s11', 'extern'] = ('reduce', r119)
# actionTable['s11', 'struct'] = ('reduce', r119)
# actionTable['s11', 'char'] = ('reduce', r119)
# actionTable['s11', 'signed'] = ('reduce', r119)
# actionTable['s11', '*'] = ('reduce', r119)
# actionTable['s11', 'register'] = ('reduce', r119)
# actionTable['s12', 'sizeof'] = ('reduce', r63)
# actionTable['s12', '-'] = ('reduce', r63)
# actionTable['s12', 'CONSTANT'] = ('reduce', r63)
# actionTable['s12', '('] = ('reduce', r63)
# actionTable['s12', '!'] = ('reduce', r63)
# actionTable['s12', '++'] = ('reduce', r63)
# actionTable['s12', 'STRING_LITERAL'] = ('reduce', r63)
# actionTable['s12', 'IDENTIFIER'] = ('reduce', r63)
# actionTable['s12', '--'] = ('reduce', r63)
# actionTable['s12', '*'] = ('reduce', r63)
# actionTable['s12', '+'] = ('reduce', r63)
# actionTable['s12', '~'] = ('reduce', r63)
# actionTable['s12', '&'] = ('reduce', r63)
# actionTable['s13', '/'] = ('reduce', r18)
# actionTable['s13', '+='] = ('reduce', r18)
# actionTable['s13', '}'] = ('reduce', r18)
# actionTable['s13', '&&'] = ('reduce', r18)
# actionTable['s13', '>'] = ('reduce', r18)
# actionTable['s13', '>='] = ('reduce', r18)
# actionTable['s13', '||'] = ('reduce', r18)
# actionTable['s13', '-'] = ('reduce', r18)
# actionTable['s13', ':'] = ('reduce', r18)
# actionTable['s13', '<='] = ('reduce', r18)
# actionTable['s13', ','] = ('reduce', r18)
# actionTable['s13', '!='] = ('reduce', r18)
# actionTable['s13', '-='] = ('reduce', r18)
# actionTable['s13', '+'] = ('reduce', r18)
# actionTable['s13', '|='] = ('reduce', r18)
# actionTable['s13', '%'] = ('reduce', r18)
# actionTable['s13', '&'] = ('reduce', r18)
# actionTable['s13', '^'] = ('reduce', r18)
# actionTable['s13', '>>'] = ('reduce', r18)
# actionTable['s13', '?'] = ('reduce', r18)
# actionTable['s13', ';'] = ('reduce', r18)
# actionTable['s13', '>>='] = ('reduce', r18)
# actionTable['s13', '|'] = ('reduce', r18)
# actionTable['s13', ')'] = ('reduce', r18)
# actionTable['s13', '='] = ('reduce', r18)
# actionTable['s13', '<<='] = ('reduce', r18)
# actionTable['s13', '*='] = ('reduce', r18)
# actionTable['s13', '<'] = ('reduce', r18)
# actionTable['s13', ']'] = ('reduce', r18)
# actionTable['s13', '&='] = ('reduce', r18)
# actionTable['s13', '^='] = ('reduce', r18)
# actionTable['s13', '<<'] = ('reduce', r18)
# actionTable['s13', '/='] = ('reduce', r18)
# actionTable['s13', '=='] = ('reduce', r18)
# actionTable['s13', '*'] = ('reduce', r18)
# actionTable['s13', '%='] = ('reduce', r18)
# actionTable['s14', 'sizeof'] = ('shift', 's94')
# actionTable['s14', '('] = ('shift', 's135')
# actionTable['s14', '--'] = ('shift', 's102')
# actionTable['s14', '-'] = ('shift', 's143')
# actionTable['s14', '+'] = ('shift', 's161')
# actionTable['s14', 'IDENTIFIER'] = ('shift', 's123')
# actionTable['s14', 'STRING_LITERAL'] = ('shift', 's182')
# actionTable['s14', '*'] = ('shift', 's47')
# actionTable['s14', '++'] = ('shift', 's212')
# actionTable['s14', 'CONSTANT'] = ('shift', 's5')
# actionTable['s14', '~'] = ('shift', 's41')
# actionTable['s14', '&'] = ('shift', 's175')
# actionTable['s14', '!'] = ('shift', 's129')
# actionTable['s15', 'static'] = ('shift', 's220')
# actionTable['s15', 'void'] = ('shift', 's74')
# actionTable['s15', 'volatile'] = ('shift', 's30')
# actionTable['s15', 'double'] = ('shift', 's81')
# actionTable['s15', 'int'] = ('shift', 's139')
# actionTable['s15', 'char'] = ('shift', 's45')
# actionTable['s15', 'register'] = ('shift', 's24')
# actionTable['s15', 'signed'] = ('shift', 's49')
# actionTable['s15', 'short'] = ('shift', 's162')
# actionTable['s15', 'float'] = ('shift', 's186')
# actionTable['s15', 'union'] = ('shift', 's158')
# actionTable['s15', 'typedef'] = ('shift', 's193')
# actionTable['s15', 'const'] = ('shift', 's112')
# actionTable['s15', 'unsigned'] = ('shift', 's188')
# actionTable['s15', 'long'] = ('shift', 's97')
# actionTable['s15', 'auto'] = ('shift', 's90')
# actionTable['s15', 'enum'] = ('shift', 's177')
# actionTable['s15', 'TYPE_NAME'] = ('shift', 's34')
# actionTable['s15', 'extern'] = ('shift', 's50')
# actionTable['s15', 'struct'] = ('shift', 's172')
# actionTable['s15', ';'] = ('reduce', r74)
# actionTable['s15', ')'] = ('reduce', r74)
# actionTable['s15', ','] = ('reduce', r74)
# actionTable['s15', '('] = ('reduce', r74)
# actionTable['s15', '*'] = ('reduce', r74)
# actionTable['s15', 'IDENTIFIER'] = ('reduce', r74)
# actionTable['s15', '['] = ('reduce', r74)
# actionTable['s16', '/'] = ('reduce', r9)
# actionTable['s16', '('] = ('reduce', r9)
# actionTable['s16', '+='] = ('reduce', r9)
# actionTable['s16', '}'] = ('reduce', r9)
# actionTable['s16', '++'] = ('reduce', r9)
# actionTable['s16', '&&'] = ('reduce', r9)
# actionTable['s16', '--'] = ('reduce', r9)
# actionTable['s16', '>'] = ('reduce', r9)
# actionTable['s16', '>='] = ('reduce', r9)
# actionTable['s16', '||'] = ('reduce', r9)
# actionTable['s16', '-'] = ('reduce', r9)
# actionTable['s16', ':'] = ('reduce', r9)
# actionTable['s16', '<='] = ('reduce', r9)
# actionTable['s16', ','] = ('reduce', r9)
# actionTable['s16', '!='] = ('reduce', r9)
# actionTable['s16', '-='] = ('reduce', r9)
# actionTable['s16', '+'] = ('reduce', r9)
# actionTable['s16', '|='] = ('reduce', r9)
# actionTable['s16', '%'] = ('reduce', r9)
# actionTable['s16', '&'] = ('reduce', r9)
# actionTable['s16', '^'] = ('reduce', r9)
# actionTable['s16', '['] = ('reduce', r9)
# actionTable['s16', '>>'] = ('reduce', r9)
# actionTable['s16', '?'] = ('reduce', r9)
# actionTable['s16', ';'] = ('reduce', r9)
# actionTable['s16', '>>='] = ('reduce', r9)
# actionTable['s16', '|'] = ('reduce', r9)
# actionTable['s16', ')'] = ('reduce', r9)
# actionTable['s16', '='] = ('reduce', r9)
# actionTable['s16', '<<='] = ('reduce', r9)
# actionTable['s16', '*='] = ('reduce', r9)
# actionTable['s16', '<'] = ('reduce', r9)
# actionTable['s16', ']'] = ('reduce', r9)
# actionTable['s16', '&='] = ('reduce', r9)
# actionTable['s16', '^='] = ('reduce', r9)
# actionTable['s16', '<<'] = ('reduce', r9)
# actionTable['s16', '/='] = ('reduce', r9)
# actionTable['s16', '=='] = ('reduce', r9)
# actionTable['s16', '->'] = ('reduce', r9)
# actionTable['s16', '.'] = ('reduce', r9)
# actionTable['s16', '*'] = ('reduce', r9)
# actionTable['s16', '%='] = ('reduce', r9)
# actionTable['s17', '/'] = ('reduce', r19)
# actionTable['s17', '+='] = ('reduce', r19)
# actionTable['s17', '}'] = ('reduce', r19)
# actionTable['s17', '&&'] = ('reduce', r19)
# actionTable['s17', '>'] = ('reduce', r19)
# actionTable['s17', '>='] = ('reduce', r19)
# actionTable['s17', '||'] = ('reduce', r19)
# actionTable['s17', '-'] = ('reduce', r19)
# actionTable['s17', ':'] = ('reduce', r19)
# actionTable['s17', '<='] = ('reduce', r19)
# actionTable['s17', ','] = ('reduce', r19)
# actionTable['s17', '!='] = ('reduce', r19)
# actionTable['s17', '-='] = ('reduce', r19)
# actionTable['s17', '+'] = ('reduce', r19)
# actionTable['s17', '|='] = ('reduce', r19)
# actionTable['s17', '%'] = ('reduce', r19)
# actionTable['s17', '&'] = ('reduce', r19)
# actionTable['s17', '^'] = ('reduce', r19)
# actionTable['s17', '>>'] = ('reduce', r19)
# actionTable['s17', '?'] = ('reduce', r19)
# actionTable['s17', ';'] = ('reduce', r19)
# actionTable['s17', '>>='] = ('reduce', r19)
# actionTable['s17', '|'] = ('reduce', r19)
# actionTable['s17', ')'] = ('reduce', r19)
# actionTable['s17', '='] = ('reduce', r19)
# actionTable['s17', '<<='] = ('reduce', r19)
# actionTable['s17', '*='] = ('reduce', r19)
# actionTable['s17', '<'] = ('reduce', r19)
# actionTable['s17', ']'] = ('reduce', r19)
# actionTable['s17', '&='] = ('reduce', r19)
# actionTable['s17', '^='] = ('reduce', r19)
# actionTable['s17', '<<'] = ('reduce', r19)
# actionTable['s17', '/='] = ('reduce', r19)
# actionTable['s17', '=='] = ('reduce', r19)
# actionTable['s17', '*'] = ('reduce', r19)
# actionTable['s17', '%='] = ('reduce', r19)
# actionTable['s18', '/'] = ('reduce', r11)
# actionTable['s18', '('] = ('reduce', r11)
# actionTable['s18', '+='] = ('reduce', r11)
# actionTable['s18', '}'] = ('reduce', r11)
# actionTable['s18', '++'] = ('reduce', r11)
# actionTable['s18', '&&'] = ('reduce', r11)
# actionTable['s18', '--'] = ('reduce', r11)
# actionTable['s18', '>'] = ('reduce', r11)
# actionTable['s18', '>='] = ('reduce', r11)
# actionTable['s18', '||'] = ('reduce', r11)
# actionTable['s18', '-'] = ('reduce', r11)
# actionTable['s18', ':'] = ('reduce', r11)
# actionTable['s18', '<='] = ('reduce', r11)
# actionTable['s18', ','] = ('reduce', r11)
# actionTable['s18', '!='] = ('reduce', r11)
# actionTable['s18', '-='] = ('reduce', r11)
# actionTable['s18', '+'] = ('reduce', r11)
# actionTable['s18', '|='] = ('reduce', r11)
# actionTable['s18', '%'] = ('reduce', r11)
# actionTable['s18', '&'] = ('reduce', r11)
# actionTable['s18', '^'] = ('reduce', r11)
# actionTable['s18', '['] = ('reduce', r11)
# actionTable['s18', '>>'] = ('reduce', r11)
# actionTable['s18', '?'] = ('reduce', r11)
# actionTable['s18', ';'] = ('reduce', r11)
# actionTable['s18', '>>='] = ('reduce', r11)
# actionTable['s18', '|'] = ('reduce', r11)
# actionTable['s18', ')'] = ('reduce', r11)
# actionTable['s18', '='] = ('reduce', r11)
# actionTable['s18', '<<='] = ('reduce', r11)
# actionTable['s18', '*='] = ('reduce', r11)
# actionTable['s18', '<'] = ('reduce', r11)
# actionTable['s18', ']'] = ('reduce', r11)
# actionTable['s18', '&='] = ('reduce', r11)
# actionTable['s18', '^='] = ('reduce', r11)
# actionTable['s18', '<<'] = ('reduce', r11)
# actionTable['s18', '/='] = ('reduce', r11)
# actionTable['s18', '=='] = ('reduce', r11)
# actionTable['s18', '->'] = ('reduce', r11)
# actionTable['s18', '.'] = ('reduce', r11)
# actionTable['s18', '*'] = ('reduce', r11)
# actionTable['s18', '%='] = ('reduce', r11)
# actionTable['s19', ','] = ('shift', 's160')
# actionTable['s19', ';'] = ('shift', 's150')
# actionTable['s20', ';'] = ('reduce', r55)
# actionTable['s20', ':'] = ('reduce', r55)
# actionTable['s20', '}'] = ('reduce', r55)
# actionTable['s20', ']'] = ('reduce', r55)
# actionTable['s20', ')'] = ('reduce', r55)
# actionTable['s20', ','] = ('reduce', r55)
# actionTable['s21', '/'] = ('reduce', r8)
# actionTable['s21', '('] = ('reduce', r8)
# actionTable['s21', '+='] = ('reduce', r8)
# actionTable['s21', '}'] = ('reduce', r8)
# actionTable['s21', '++'] = ('reduce', r8)
# actionTable['s21', '&&'] = ('reduce', r8)
# actionTable['s21', '--'] = ('reduce', r8)
# actionTable['s21', '>'] = ('reduce', r8)
# actionTable['s21', '>='] = ('reduce', r8)
# actionTable['s21', '||'] = ('reduce', r8)
# actionTable['s21', '-'] = ('reduce', r8)
# actionTable['s21', ':'] = ('reduce', r8)
# actionTable['s21', '<='] = ('reduce', r8)
# actionTable['s21', ','] = ('reduce', r8)
# actionTable['s21', '!='] = ('reduce', r8)
# actionTable['s21', '-='] = ('reduce', r8)
# actionTable['s21', '+'] = ('reduce', r8)
# actionTable['s21', '|='] = ('reduce', r8)
# actionTable['s21', '%'] = ('reduce', r8)
# actionTable['s21', '&'] = ('reduce', r8)
# actionTable['s21', '^'] = ('reduce', r8)
# actionTable['s21', '['] = ('reduce', r8)
# actionTable['s21', '>>'] = ('reduce', r8)
# actionTable['s21', '?'] = ('reduce', r8)
# actionTable['s21', ';'] = ('reduce', r8)
# actionTable['s21', '>>='] = ('reduce', r8)
# actionTable['s21', '|'] = ('reduce', r8)
# actionTable['s21', ')'] = ('reduce', r8)
# actionTable['s21', '='] = ('reduce', r8)
# actionTable['s21', '<<='] = ('reduce', r8)
# actionTable['s21', '*='] = ('reduce', r8)
# actionTable['s21', '<'] = ('reduce', r8)
# actionTable['s21', ']'] = ('reduce', r8)
# actionTable['s21', '&='] = ('reduce', r8)
# actionTable['s21', '^='] = ('reduce', r8)
# actionTable['s21', '<<'] = ('reduce', r8)
# actionTable['s21', '/='] = ('reduce', r8)
# actionTable['s21', '=='] = ('reduce', r8)
# actionTable['s21', '->'] = ('reduce', r8)
# actionTable['s21', '.'] = ('reduce', r8)
# actionTable['s21', '*'] = ('reduce', r8)
# actionTable['s21', '%='] = ('reduce', r8)
# actionTable['s22', '('] = ('shift', 's159')
# actionTable['s22', 'IDENTIFIER'] = ('shift', 's137')
# actionTable['s22', '*'] = ('shift', 's7')
# actionTable['s22', ':'] = ('shift', 's51')
# actionTable['s23', 'sizeof'] = ('shift', 's94')
# actionTable['s23', '('] = ('shift', 's135')
# actionTable['s23', '--'] = ('shift', 's102')
# actionTable['s23', '-'] = ('shift', 's143')
# actionTable['s23', '+'] = ('shift', 's161')
# actionTable['s23', 'IDENTIFIER'] = ('shift', 's123')
# actionTable['s23', 'STRING_LITERAL'] = ('shift', 's182')
# actionTable['s23', '*'] = ('shift', 's47')
# actionTable['s23', '++'] = ('shift', 's212')
# actionTable['s23', 'CONSTANT'] = ('shift', 's5')
# actionTable['s23', '~'] = ('shift', 's41')
# actionTable['s23', '&'] = ('shift', 's175')
# actionTable['s23', '!'] = ('shift', 's129')
# actionTable['s24', 'enum'] = ('reduce', r88)
# actionTable['s24', ';'] = ('reduce', r88)
# actionTable['s24', '('] = ('reduce', r88)
# actionTable['s24', 'static'] = ('reduce', r88)
# actionTable['s24', 'volatile'] = ('reduce', r88)
# actionTable['s24', 'double'] = ('reduce', r88)
# actionTable['s24', 'short'] = ('reduce', r88)
# actionTable['s24', ')'] = ('reduce', r88)
# actionTable['s24', 'typedef'] = ('reduce', r88)
# actionTable['s24', 'float'] = ('reduce', r88)
# actionTable['s24', 'TYPE_NAME'] = ('reduce', r88)
# actionTable['s24', 'const'] = ('reduce', r88)
# actionTable['s24', 'unsigned'] = ('reduce', r88)
# actionTable['s24', 'void'] = ('reduce', r88)
# actionTable['s24', 'union'] = ('reduce', r88)
# actionTable['s24', 'int'] = ('reduce', r88)
# actionTable['s24', 'extern'] = ('reduce', r88)
# actionTable['s24', 'struct'] = ('reduce', r88)
# actionTable['s24', 'char'] = ('reduce', r88)
# actionTable['s24', 'signed'] = ('reduce', r88)
# actionTable['s24', 'long'] = ('reduce', r88)
# actionTable['s24', ','] = ('reduce', r88)
# actionTable['s24', '*'] = ('reduce', r88)
# actionTable['s24', 'register'] = ('reduce', r88)
# actionTable['s24', 'auto'] = ('reduce', r88)
# actionTable['s24', 'IDENTIFIER'] = ('reduce', r88)
# actionTable['s24', '['] = ('reduce', r88)
# actionTable['s25', 'sizeof'] = ('shift', 's94')
# actionTable['s25', '('] = ('shift', 's135')
# actionTable['s25', '--'] = ('shift', 's102')
# actionTable['s25', '-'] = ('shift', 's143')
# actionTable['s25', '+'] = ('shift', 's161')
# actionTable['s25', 'IDENTIFIER'] = ('shift', 's123')
# actionTable['s25', 'STRING_LITERAL'] = ('shift', 's182')
# actionTable['s25', '*'] = ('shift', 's47')
# actionTable['s25', '++'] = ('shift', 's212')
# actionTable['s25', 'CONSTANT'] = ('shift', 's5')
# actionTable['s25', '~'] = ('shift', 's41')
# actionTable['s25', '&'] = ('shift', 's175')
# actionTable['s25', '!'] = ('shift', 's129')
# actionTable['s26', 'void'] = ('shift', 's74')
# actionTable['s26', 'volatile'] = ('shift', 's30')
# actionTable['s26', 'double'] = ('shift', 's81')
# actionTable['s26', 'int'] = ('shift', 's139')
# actionTable['s26', 'char'] = ('shift', 's45')
# actionTable['s26', 'signed'] = ('shift', 's49')
# actionTable['s26', '}'] = ('shift', 's9')
# actionTable['s26', 'short'] = ('shift', 's162')
# actionTable['s26', 'float'] = ('shift', 's186')
# actionTable['s26', 'union'] = ('shift', 's158')
# actionTable['s26', 'const'] = ('shift', 's112')
# actionTable['s26', 'unsigned'] = ('shift', 's188')
# actionTable['s26', 'long'] = ('shift', 's97')
# actionTable['s26', 'enum'] = ('shift', 's177')
# actionTable['s26', 'TYPE_NAME'] = ('shift', 's34')
# actionTable['s26', 'struct'] = ('shift', 's172')
# actionTable['s27', '/'] = ('reduce', r6)
# actionTable['s27', '('] = ('reduce', r6)
# actionTable['s27', '+='] = ('reduce', r6)
# actionTable['s27', '}'] = ('reduce', r6)
# actionTable['s27', '++'] = ('reduce', r6)
# actionTable['s27', '&&'] = ('reduce', r6)
# actionTable['s27', '--'] = ('reduce', r6)
# actionTable['s27', '>'] = ('reduce', r6)
# actionTable['s27', '>='] = ('reduce', r6)
# actionTable['s27', '||'] = ('reduce', r6)
# actionTable['s27', '-'] = ('reduce', r6)
# actionTable['s27', ':'] = ('reduce', r6)
# actionTable['s27', '<='] = ('reduce', r6)
# actionTable['s27', ','] = ('reduce', r6)
# actionTable['s27', '!='] = ('reduce', r6)
# actionTable['s27', '-='] = ('reduce', r6)
# actionTable['s27', '+'] = ('reduce', r6)
# actionTable['s27', '|='] = ('reduce', r6)
# actionTable['s27', '%'] = ('reduce', r6)
# actionTable['s27', '&'] = ('reduce', r6)
# actionTable['s27', '^'] = ('reduce', r6)
# actionTable['s27', '['] = ('reduce', r6)
# actionTable['s27', '>>'] = ('reduce', r6)
# actionTable['s27', '?'] = ('reduce', r6)
# actionTable['s27', ';'] = ('reduce', r6)
# actionTable['s27', '>>='] = ('reduce', r6)
# actionTable['s27', '|'] = ('reduce', r6)
# actionTable['s27', ')'] = ('reduce', r6)
# actionTable['s27', '='] = ('reduce', r6)
# actionTable['s27', '<<='] = ('reduce', r6)
# actionTable['s27', '*='] = ('reduce', r6)
# actionTable['s27', '<'] = ('reduce', r6)
# actionTable['s27', ']'] = ('reduce', r6)
# actionTable['s27', '&='] = ('reduce', r6)
# actionTable['s27', '^='] = ('reduce', r6)
# actionTable['s27', '<<'] = ('reduce', r6)
# actionTable['s27', '/='] = ('reduce', r6)
# actionTable['s27', '=='] = ('reduce', r6)
# actionTable['s27', '->'] = ('reduce', r6)
# actionTable['s27', '.'] = ('reduce', r6)
# actionTable['s27', '*'] = ('reduce', r6)
# actionTable['s27', '%='] = ('reduce', r6)
# actionTable['s28', '>>'] = ('shift', 's33')
# actionTable['s28', '<<'] = ('shift', 's39')
# actionTable['s28', '?'] = ('reduce', r38)
# actionTable['s28', ';'] = ('reduce', r38)
# actionTable['s28', '}'] = ('reduce', r38)
# actionTable['s28', '|'] = ('reduce', r38)
# actionTable['s28', ')'] = ('reduce', r38)
# actionTable['s28', '&&'] = ('reduce', r38)
# actionTable['s28', '>='] = ('reduce', r38)
# actionTable['s28', '>'] = ('reduce', r38)
# actionTable['s28', '||'] = ('reduce', r38)
# actionTable['s28', '<'] = ('reduce', r38)
# actionTable['s28', ':'] = ('reduce', r38)
# actionTable['s28', ']'] = ('reduce', r38)
# actionTable['s28', '<='] = ('reduce', r38)
# actionTable['s28', '=='] = ('reduce', r38)
# actionTable['s28', ','] = ('reduce', r38)
# actionTable['s28', '!='] = ('reduce', r38)
# actionTable['s28', '&'] = ('reduce', r38)
# actionTable['s28', '^'] = ('reduce', r38)
# actionTable['s29', 'sizeof'] = ('shift', 's94')
# actionTable['s29', '('] = ('shift', 's135')
# actionTable['s29', '--'] = ('shift', 's102')
# actionTable['s29', '-'] = ('shift', 's143')
# actionTable['s29', '+'] = ('shift', 's161')
# actionTable['s29', 'IDENTIFIER'] = ('shift', 's123')
# actionTable['s29', 'STRING_LITERAL'] = ('shift', 's182')
# actionTable['s29', '*'] = ('shift', 's47')
# actionTable['s29', '++'] = ('shift', 's212')
# actionTable['s29', 'CONSTANT'] = ('shift', 's5')
# actionTable['s29', '~'] = ('shift', 's41')
# actionTable['s29', '&'] = ('shift', 's175')
# actionTable['s29', '!'] = ('shift', 's129')
# actionTable['s30', 'enum'] = ('reduce', r126)
# actionTable['s30', ';'] = ('reduce', r126)
# actionTable['s30', '('] = ('reduce', r126)
# actionTable['s30', 'static'] = ('reduce', r126)
# actionTable['s30', 'volatile'] = ('reduce', r126)
# actionTable['s30', 'double'] = ('reduce', r126)
# actionTable['s30', 'short'] = ('reduce', r126)
# actionTable['s30', ')'] = ('reduce', r126)
# actionTable['s30', 'typedef'] = ('reduce', r126)
# actionTable['s30', 'float'] = ('reduce', r126)
# actionTable['s30', 'TYPE_NAME'] = ('reduce', r126)
# actionTable['s30', 'const'] = ('reduce', r126)
# actionTable['s30', 'unsigned'] = ('reduce', r126)
# actionTable['s30', 'void'] = ('reduce', r126)
# actionTable['s30', 'union'] = ('reduce', r126)
# actionTable['s30', 'int'] = ('reduce', r126)
# actionTable['s30', 'extern'] = ('reduce', r126)
# actionTable['s30', ':'] = ('reduce', r126)
# actionTable['s30', 'struct'] = ('reduce', r126)
# actionTable['s30', 'char'] = ('reduce', r126)
# actionTable['s30', 'signed'] = ('reduce', r126)
# actionTable['s30', 'long'] = ('reduce', r126)
# actionTable['s30', ','] = ('reduce', r126)
# actionTable['s30', '*'] = ('reduce', r126)
# actionTable['s30', 'register'] = ('reduce', r126)
# actionTable['s30', 'auto'] = ('reduce', r126)
# actionTable['s30', 'IDENTIFIER'] = ('reduce', r126)
# actionTable['s30', '['] = ('reduce', r126)
# actionTable['s31', '('] = ('shift', 's128')
# actionTable['s31', '['] = ('shift', 's40')
# actionTable['s31', ')'] = ('reduce', r153)
# actionTable['s31', ','] = ('reduce', r153)
# actionTable['s32', '('] = ('reduce', r160)
# actionTable['s32', ')'] = ('reduce', r160)
# actionTable['s32', ','] = ('reduce', r160)
# actionTable['s32', '['] = ('reduce', r160)
# actionTable['s33', 'sizeof'] = ('shift', 's94')
# actionTable['s33', '('] = ('shift', 's135')
# actionTable['s33', '--'] = ('shift', 's102')
# actionTable['s33', '-'] = ('shift', 's143')
# actionTable['s33', '+'] = ('shift', 's161')
# actionTable['s33', 'IDENTIFIER'] = ('shift', 's123')
# actionTable['s33', 'STRING_LITERAL'] = ('shift', 's182')
# actionTable['s33', '*'] = ('shift', 's47')
# actionTable['s33', '++'] = ('shift', 's212')
# actionTable['s33', 'CONSTANT'] = ('shift', 's5')
# actionTable['s33', '~'] = ('shift', 's41')
# actionTable['s33', '&'] = ('shift', 's175')
# actionTable['s33', '!'] = ('shift', 's129')
# actionTable['s34', 'enum'] = ('reduce', r100)
# actionTable['s34', ';'] = ('reduce', r100)
# actionTable['s34', '('] = ('reduce', r100)
# actionTable['s34', 'static'] = ('reduce', r100)
# actionTable['s34', 'volatile'] = ('reduce', r100)
# actionTable['s34', 'double'] = ('reduce', r100)
# actionTable['s34', 'short'] = ('reduce', r100)
# actionTable['s34', ')'] = ('reduce', r100)
# actionTable['s34', 'typedef'] = ('reduce', r100)
# actionTable['s34', 'float'] = ('reduce', r100)
# actionTable['s34', 'TYPE_NAME'] = ('reduce', r100)
# actionTable['s34', 'const'] = ('reduce', r100)
# actionTable['s34', 'unsigned'] = ('reduce', r100)
# actionTable['s34', 'void'] = ('reduce', r100)
# actionTable['s34', 'union'] = ('reduce', r100)
# actionTable['s34', 'int'] = ('reduce', r100)
# actionTable['s34', 'extern'] = ('reduce', r100)
# actionTable['s34', ':'] = ('reduce', r100)
# actionTable['s34', 'struct'] = ('reduce', r100)
# actionTable['s34', 'char'] = ('reduce', r100)
# actionTable['s34', 'signed'] = ('reduce', r100)
# actionTable['s34', 'long'] = ('reduce', r100)
# actionTable['s34', ','] = ('reduce', r100)
# actionTable['s34', '*'] = ('reduce', r100)
# actionTable['s34', 'register'] = ('reduce', r100)
# actionTable['s34', 'auto'] = ('reduce', r100)
# actionTable['s34', 'IDENTIFIER'] = ('reduce', r100)
# actionTable['s34', '['] = ('reduce', r100)
# actionTable['s35', 'sizeof'] = ('shift', 's94')
# actionTable['s35', '('] = ('shift', 's135')
# actionTable['s35', '--'] = ('shift', 's102')
# actionTable['s35', '-'] = ('shift', 's143')
# actionTable['s35', '+'] = ('shift', 's161')
# actionTable['s35', 'IDENTIFIER'] = ('shift', 's123')
# actionTable['s35', 'STRING_LITERAL'] = ('shift', 's182')
# actionTable['s35', '*'] = ('shift', 's47')
# actionTable['s35', '++'] = ('shift', 's212')
# actionTable['s35', 'CONSTANT'] = ('shift', 's5')
# actionTable['s35', '~'] = ('shift', 's41')
# actionTable['s35', '&'] = ('shift', 's175')
# actionTable['s35', '!'] = ('shift', 's129')
# actionTable['s36', '|'] = ('shift', 's190')
# actionTable['s36', '?'] = ('reduce', r50)
# actionTable['s36', ';'] = ('reduce', r50)
# actionTable['s36', ':'] = ('reduce', r50)
# actionTable['s36', '}'] = ('reduce', r50)
# actionTable['s36', ']'] = ('reduce', r50)
# actionTable['s36', ')'] = ('reduce', r50)
# actionTable['s36', '&&'] = ('reduce', r50)
# actionTable['s36', ','] = ('reduce', r50)
# actionTable['s36', '||'] = ('reduce', r50)
# actionTable['s37', ')'] = ('reduce', r56)
# actionTable['s37', ';'] = ('reduce', r56)
# actionTable['s37', ','] = ('reduce', r56)
# actionTable['s37', ':'] = ('reduce', r56)
# actionTable['s37', '}'] = ('reduce', r56)
# actionTable['s37', ']'] = ('reduce', r56)
# actionTable['s38', '>>'] = ('shift', 's33')
# actionTable['s38', '<<'] = ('shift', 's39')
# actionTable['s38', '?'] = ('reduce', r37)
# actionTable['s38', ';'] = ('reduce', r37)
# actionTable['s38', '}'] = ('reduce', r37)
# actionTable['s38', '|'] = ('reduce', r37)
# actionTable['s38', ')'] = ('reduce', r37)
# actionTable['s38', '&&'] = ('reduce', r37)
# actionTable['s38', '>='] = ('reduce', r37)
# actionTable['s38', '>'] = ('reduce', r37)
# actionTable['s38', '||'] = ('reduce', r37)
# actionTable['s38', '<'] = ('reduce', r37)
# actionTable['s38', ':'] = ('reduce', r37)
# actionTable['s38', ']'] = ('reduce', r37)
# actionTable['s38', '<='] = ('reduce', r37)
# actionTable['s38', '=='] = ('reduce', r37)
# actionTable['s38', ','] = ('reduce', r37)
# actionTable['s38', '!='] = ('reduce', r37)
# actionTable['s38', '&'] = ('reduce', r37)
# actionTable['s38', '^'] = ('reduce', r37)
# actionTable['s39', 'sizeof'] = ('shift', 's94')
# actionTable['s39', '('] = ('shift', 's135')
# actionTable['s39', '--'] = ('shift', 's102')
# actionTable['s39', '-'] = ('shift', 's143')
# actionTable['s39', '+'] = ('shift', 's161')
# actionTable['s39', 'IDENTIFIER'] = ('shift', 's123')
# actionTable['s39', 'STRING_LITERAL'] = ('shift', 's182')
# actionTable['s39', '*'] = ('shift', 's47')
# actionTable['s39', '++'] = ('shift', 's212')
# actionTable['s39', 'CONSTANT'] = ('shift', 's5')
# actionTable['s39', '~'] = ('shift', 's41')
# actionTable['s39', '&'] = ('shift', 's175')
# actionTable['s39', '!'] = ('shift', 's129')
# actionTable['s40', 'sizeof'] = ('shift', 's94')
# actionTable['s40', '('] = ('shift', 's135')
# actionTable['s40', '--'] = ('shift', 's102')
# actionTable['s40', '-'] = ('shift', 's143')
# actionTable['s40', '+'] = ('shift', 's161')
# actionTable['s40', 'IDENTIFIER'] = ('shift', 's123')
# actionTable['s40', 'STRING_LITERAL'] = ('shift', 's182')
# actionTable['s40', '*'] = ('shift', 's47')
# actionTable['s40', '++'] = ('shift', 's212')
# actionTable['s40', 'CONSTANT'] = ('shift', 's5')
# actionTable['s40', '~'] = ('shift', 's41')
# actionTable['s40', '&'] = ('shift', 's175')
# actionTable['s40', '!'] = ('shift', 's129')
# actionTable['s40', ']'] = ('shift', 's232')
# actionTable['s41', 'sizeof'] = ('reduce', r24)
# actionTable['s41', '~'] = ('reduce', r24)
# actionTable['s41', '-'] = ('reduce', r24)
# actionTable['s41', 'CONSTANT'] = ('reduce', r24)
# actionTable['s41', '('] = ('reduce', r24)
# actionTable['s41', '!'] = ('reduce', r24)
# actionTable['s41', '++'] = ('reduce', r24)
# actionTable['s41', 'STRING_LITERAL'] = ('reduce', r24)
# actionTable['s41', '--'] = ('reduce', r24)
# actionTable['s41', '*'] = ('reduce', r24)
# actionTable['s41', '+'] = ('reduce', r24)
# actionTable['s41', '&'] = ('reduce', r24)
# actionTable['s41', 'IDENTIFIER'] = ('reduce', r24)
# actionTable['s42', ';'] = ('reduce', r114)
# actionTable['s42', ','] = ('reduce', r114)
# actionTable['s43', 'void'] = ('shift', 's74')
# actionTable['s43', 'volatile'] = ('shift', 's30')
# actionTable['s43', 'double'] = ('shift', 's81')
# actionTable['s43', 'int'] = ('shift', 's139')
# actionTable['s43', 'char'] = ('shift', 's45')
# actionTable['s43', 'signed'] = ('shift', 's49')
# actionTable['s43', '}'] = ('shift', 's156')
# actionTable['s43', 'short'] = ('shift', 's162')
# actionTable['s43', 'float'] = ('shift', 's186')
# actionTable['s43', 'union'] = ('shift', 's158')
# actionTable['s43', 'const'] = ('shift', 's112')
# actionTable['s43', 'unsigned'] = ('shift', 's188')
# actionTable['s43', 'long'] = ('shift', 's97')
# actionTable['s43', 'enum'] = ('shift', 's177')
# actionTable['s43', 'TYPE_NAME'] = ('shift', 's34')
# actionTable['s43', 'struct'] = ('shift', 's172')
# actionTable['s44', ')'] = ('reduce', r144)
# actionTable['s44', ','] = ('reduce', r144)
# actionTable['s45', 'enum'] = ('reduce', r90)
# actionTable['s45', ';'] = ('reduce', r90)
# actionTable['s45', '('] = ('reduce', r90)
# actionTable['s45', 'static'] = ('reduce', r90)
# actionTable['s45', 'volatile'] = ('reduce', r90)
# actionTable['s45', 'double'] = ('reduce', r90)
# actionTable['s45', 'short'] = ('reduce', r90)
# actionTable['s45', ')'] = ('reduce', r90)
# actionTable['s45', 'typedef'] = ('reduce', r90)
# actionTable['s45', 'float'] = ('reduce', r90)
# actionTable['s45', 'TYPE_NAME'] = ('reduce', r90)
# actionTable['s45', 'const'] = ('reduce', r90)
# actionTable['s45', 'unsigned'] = ('reduce', r90)
# actionTable['s45', 'void'] = ('reduce', r90)
# actionTable['s45', 'union'] = ('reduce', r90)
# actionTable['s45', 'int'] = ('reduce', r90)
# actionTable['s45', 'extern'] = ('reduce', r90)
# actionTable['s45', ':'] = ('reduce', r90)
# actionTable['s45', 'struct'] = ('reduce', r90)
# actionTable['s45', 'char'] = ('reduce', r90)
# actionTable['s45', 'signed'] = ('reduce', r90)
# actionTable['s45', 'long'] = ('reduce', r90)
# actionTable['s45', ','] = ('reduce', r90)
# actionTable['s45', '*'] = ('reduce', r90)
# actionTable['s45', 'register'] = ('reduce', r90)
# actionTable['s45', 'auto'] = ('reduce', r90)
# ...
# gotoTable['s104', 'additive_expression'] = 's154'
# gotoTable['s104', 'shift_expression'] = 's2'
# gotoTable['s104', 'unary_expression'] = 's119'
# gotoTable['s104', 'unary_operator'] = 's85'
# gotoTable['s104', 'postfix_expression'] = 's206'
# gotoTable['s104', 'multiplicative_expression'] = 's107'
# gotoTable['s118', 'primary_expression'] = 's66'
# gotoTable['s118', 'relational_expression'] = 's178'
# gotoTable['s118', 'additive_expression'] = 's154'
# gotoTable['s118', 'constant_expression'] = 's207'
# gotoTable['s118', 'exclusive_or_expression'] = 's185'
# gotoTable['s118', 'conditional_expression'] = 's98'
# gotoTable['s118', 'inclusive_or_expression'] = 's36'
# gotoTable['s118', 'shift_expression'] = 's2'
# gotoTable['s118', 'unary_expression'] = 's119'
# gotoTable['s118', 'unary_operator'] = 's85'
# gotoTable['s118', 'postfix_expression'] = 's206'
# gotoTable['s118', 'logical_or_expression'] = 's60'
# gotoTable['s118', 'logical_and_expression'] = 's108'
# gotoTable['s118', 'equality_expression'] = 's100'
# gotoTable['s118', 'multiplicative_expression'] = 's107'
# gotoTable['s118', 'and_expression'] = 's121'
# gotoTable['s120', 'primary_expression'] = 's66'
# gotoTable['s120', 'relational_expression'] = 's178'
# gotoTable['s120', 'additive_expression'] = 's154'
# gotoTable['s120', 'exclusive_or_expression'] = 's185'
# gotoTable['s120', 'conditional_expression'] = 's37'
# gotoTable['s120', 'inclusive_or_expression'] = 's36'
# gotoTable['s120', 'shift_expression'] = 's2'
# gotoTable['s120', 'unary_expression'] = 's78'
# gotoTable['s120', 'unary_operator'] = 's85'
# gotoTable['s120', 'postfix_expression'] = 's206'
# gotoTable['s120', 'logical_or_expression'] = 's60'
# gotoTable['s120', 'logical_and_expression'] = 's108'
# gotoTable['s120', 'equality_expression'] = 's100'
# gotoTable['s120', 'multiplicative_expression'] = 's107'
# gotoTable['s120', 'and_expression'] = 's121'
# gotoTable['s120', 'assignment_expression'] = 's67'
# gotoTable['s122', 'primary_expression'] = 's66'
# gotoTable['s122', 'unary_expression'] = 's113'
# gotoTable['s122', 'unary_operator'] = 's85'
# gotoTable['s122', 'postfix_expression'] = 's206'
# gotoTable['s124', 'primary_expression'] = 's66'
# gotoTable['s124', 'unary_expression'] = 's189'
# gotoTable['s124', 'unary_operator'] = 's85'
# gotoTable['s124', 'postfix_expression'] = 's206'
# gotoTable['s127', 'primary_expression'] = 's66'
# gotoTable['s127', 'unary_expression'] = 's167'
# gotoTable['s127', 'unary_operator'] = 's85'
# gotoTable['s127', 'postfix_expression'] = 's206'
# gotoTable['s128', 'type_specifier'] = 's203'
# gotoTable['s128', 'struct_or_union_specifier'] = 's126'
# gotoTable['s128', 'parameter_type_list'] = 's114'
# gotoTable['s128', 'direct_abstract_declarator'] = 's53'
# gotoTable['s128', 'type_qualifier'] = 's101'
# gotoTable['s128', 'parameter_declaration'] = 's44'
# gotoTable['s128', 'pointer'] = 's31'
# gotoTable['s128', 'declaration_specifiers'] = 's171'
# gotoTable['s128', 'enum_specifier'] = 's238'
# gotoTable['s128', 'parameter_list'] = 's88'
# gotoTable['s128', 'struct_or_union'] = 's93'
# gotoTable['s128', 'abstract_declarator'] = 's149'
# gotoTable['s128', 'storage_class_specifier'] = 's15'
# gotoTable['s0', 'primary_expression'] = 's76'
# gotoTable['s135', 'primary_expression'] = 's66'
# gotoTable['s135', 'relational_expression'] = 's178'
# gotoTable['s135', 'additive_expression'] = 's154'
# gotoTable['s135', 'exclusive_or_expression'] = 's185'
# gotoTable['s135', 'conditional_expression'] = 's37'
# gotoTable['s135', 'inclusive_or_expression'] = 's36'
# gotoTable['s135', 'shift_expression'] = 's2'
# gotoTable['s135', 'unary_expression'] = 's78'
# gotoTable['s135', 'unary_operator'] = 's85'
# gotoTable['s135', 'expression'] = 's46'
# gotoTable['s135', 'postfix_expression'] = 's206'
# gotoTable['s135', 'logical_or_expression'] = 's60'
# gotoTable['s135', 'logical_and_expression'] = 's108'
# gotoTable['s135', 'equality_expression'] = 's100'
# gotoTable['s135', 'multiplicative_expression'] = 's107'
# gotoTable['s135', 'and_expression'] = 's121'
# gotoTable['s135', 'assignment_expression'] = 's105'
# gotoTable['s142', 'type_specifier'] = 's203'
# gotoTable['s142', 'struct_or_union_specifier'] = 's126'
# gotoTable['s142', 'parameter_type_list'] = 's235'
# gotoTable['s142', 'type_qualifier'] = 's101'
# gotoTable['s142', 'parameter_declaration'] = 's44'
# gotoTable['s142', 'declaration_specifiers'] = 's171'
# gotoTable['s142', 'enum_specifier'] = 's238'
# gotoTable['s142', 'parameter_list'] = 's88'
# gotoTable['s142', 'struct_or_union'] = 's93'
# gotoTable['s142', 'storage_class_specifier'] = 's15'
# gotoTable['s142', 'identifier_list'] = 's138'
# gotoTable['s146', 'primary_expression'] = 's66'
# gotoTable['s146', 'relational_expression'] = 's178'
# gotoTable['s146', 'additive_expression'] = 's154'
# gotoTable['s146', 'constant_expression'] = 's117'
# gotoTable['s146', 'exclusive_or_expression'] = 's185'
# gotoTable['s146', 'conditional_expression'] = 's98'
# gotoTable['s146', 'inclusive_or_expression'] = 's36'
# gotoTable['s146', 'shift_expression'] = 's2'
# gotoTable['s146', 'unary_expression'] = 's119'
# gotoTable['s146', 'unary_operator'] = 's85'
# gotoTable['s146', 'postfix_expression'] = 's206'
# gotoTable['s146', 'logical_or_expression'] = 's60'
# gotoTable['s146', 'logical_and_expression'] = 's108'
# gotoTable['s146', 'equality_expression'] = 's100'
# gotoTable['s146', 'multiplicative_expression'] = 's107'
# gotoTable['s146', 'and_expression'] = 's121'
# gotoTable['s159', 'direct_declarator'] = 's115'
# gotoTable['s159', 'declarator'] = 's116'
# gotoTable['s159', 'pointer'] = 's75'
# gotoTable['s160', 'direct_declarator'] = 's115'
# gotoTable['s160', 'declarator'] = 's111'
# gotoTable['s160', 'pointer'] = 's75'
# gotoTable['s160', 'struct_declarator'] = 's42'
# gotoTable['s171', 'direct_declarator'] = 's115'
# gotoTable['s171', 'declarator'] = 's208'
# gotoTable['s171', 'direct_abstract_declarator'] = 's53'
# gotoTable['s171', 'pointer'] = 's99'
# gotoTable['s171', 'abstract_declarator'] = 's77'
# gotoTable['s176', 'type_specifier'] = 's203'
# gotoTable['s176', 'struct_or_union_specifier'] = 's126'
# gotoTable['s176', 'type_qualifier'] = 's101'
# gotoTable['s176', 'parameter_declaration'] = 's229'
# gotoTable['s176', 'declaration_specifiers'] = 's171'
# gotoTable['s176', 'enum_specifier'] = 's238'
# gotoTable['s176', 'struct_or_union'] = 's93'
# gotoTable['s176', 'storage_class_specifier'] = 's15'
# gotoTable['s179', 'primary_expression'] = 's66'
# gotoTable['s179', 'relational_expression'] = 's178'
# gotoTable['s179', 'additive_expression'] = 's154'
# gotoTable['s179', 'exclusive_or_expression'] = 's185'
# gotoTable['s179', 'conditional_expression'] = 's37'
# gotoTable['s179', 'inclusive_or_expression'] = 's36'
# gotoTable['s179', 'shift_expression'] = 's2'
# gotoTable['s179', 'unary_expression'] = 's78'
# gotoTable['s179', 'unary_operator'] = 's85'
# gotoTable['s179', 'postfix_expression'] = 's206'
# gotoTable['s179', 'logical_or_expression'] = 's60'
# gotoTable['s179', 'logical_and_expression'] = 's108'
# gotoTable['s179', 'equality_expression'] = 's100'
# gotoTable['s179', 'multiplicative_expression'] = 's107'
# gotoTable['s179', 'and_expression'] = 's121'
# gotoTable['s179', 'assignment_expression'] = 's84'
# gotoTable['s180', 'primary_expression'] = 's66'
# gotoTable['s180', 'unary_expression'] = 's119'
# gotoTable['s180', 'unary_operator'] = 's85'
# gotoTable['s180', 'postfix_expression'] = 's206'
# gotoTable['s180', 'multiplicative_expression'] = 's155'
# gotoTable['s181', 'type_specifier'] = 's203'
# gotoTable['s181', 'struct_or_union_specifier'] = 's126'
# gotoTable['s181', 'parameter_type_list'] = 's163'
# gotoTable['s181', 'type_qualifier'] = 's101'
# gotoTable['s181', 'parameter_declaration'] = 's44'
# gotoTable['s181', 'declaration_specifiers'] = 's171'
# gotoTable['s181', 'enum_specifier'] = 's238'
# gotoTable['s181', 'parameter_list'] = 's88'
# gotoTable['s181', 'struct_or_union'] = 's93'
# gotoTable['s181', 'storage_class_specifier'] = 's15'
# gotoTable['s183', 'primary_expression'] = 's66'
# gotoTable['s183', 'relational_expression'] = 's178'
# gotoTable['s183', 'additive_expression'] = 's154'
# gotoTable['s183', 'exclusive_or_expression'] = 's185'
# gotoTable['s183', 'conditional_expression'] = 's37'
# gotoTable['s183', 'inclusive_or_expression'] = 's36'
# gotoTable['s183', 'shift_expression'] = 's2'
# gotoTable['s183', 'unary_expression'] = 's78'
# gotoTable['s183', 'unary_operator'] = 's85'
# gotoTable['s183', 'expression'] = 's191'
# gotoTable['s183', 'postfix_expression'] = 's206'
# gotoTable['s183', 'logical_or_expression'] = 's60'
# gotoTable['s183', 'logical_and_expression'] = 's108'
# gotoTable['s183', 'equality_expression'] = 's100'
# gotoTable['s183', 'multiplicative_expression'] = 's107'
# gotoTable['s183', 'and_expression'] = 's121'
# gotoTable['s183', 'assignment_expression'] = 's105'
# gotoTable['s187', 'primary_expression'] = 's66'
# gotoTable['s187', 'unary_expression'] = 's119'
# gotoTable['s187', 'unary_operator'] = 's85'
# gotoTable['s187', 'postfix_expression'] = 's206'
# gotoTable['s187', 'multiplicative_expression'] = 's62'
# gotoTable['s190', 'primary_expression'] = 's66'
# gotoTable['s190', 'relational_expression'] = 's178'
# gotoTable['s190', 'additive_expression'] = 's154'
# gotoTable['s190', 'exclusive_or_expression'] = 's234'
# gotoTable['s190', 'shift_expression'] = 's2'
# gotoTable['s190', 'unary_expression'] = 's119'
# gotoTable['s190', 'unary_operator'] = 's85'
# gotoTable['s190', 'postfix_expression'] = 's206'
# gotoTable['s190', 'equality_expression'] = 's100'
# gotoTable['s190', 'multiplicative_expression'] = 's107'
# gotoTable['s190', 'and_expression'] = 's121'
# gotoTable['s192', 'primary_expression'] = 's66'
# gotoTable['s192', 'relational_expression'] = 's178'
# gotoTable['s192', 'additive_expression'] = 's154'
# gotoTable['s192', 'constant_expression'] = 's64'
# gotoTable['s192', 'exclusive_or_expression'] = 's185'
# gotoTable['s192', 'conditional_expression'] = 's98'
# gotoTable['s192', 'inclusive_or_expression'] = 's36'
# gotoTable['s192', 'shift_expression'] = 's2'
# gotoTable['s192', 'unary_expression'] = 's119'
# gotoTable['s192', 'unary_operator'] = 's85'
# gotoTable['s192', 'postfix_expression'] = 's206'
# gotoTable['s192', 'logical_or_expression'] = 's60'
# gotoTable['s192', 'logical_and_expression'] = 's108'
# gotoTable['s192', 'equality_expression'] = 's100'
# gotoTable['s192', 'multiplicative_expression'] = 's107'
# gotoTable['s192', 'and_expression'] = 's121'
# gotoTable['s197', 'primary_expression'] = 's66'
# gotoTable['s197', 'additive_expression'] = 's154'
# gotoTable['s197', 'shift_expression'] = 's28'
# gotoTable['s197', 'unary_expression'] = 's119'
# gotoTable['s197', 'unary_operator'] = 's85'
# gotoTable['s197', 'postfix_expression'] = 's206'
# gotoTable['s197', 'multiplicative_expression'] = 's107'
# gotoTable['s203', 'type_specifier'] = 's203'
# gotoTable['s203', 'struct_or_union_specifier'] = 's126'
# gotoTable['s203', 'type_qualifier'] = 's101'
# gotoTable['s203', 'declaration_specifiers'] = 's1'
# gotoTable['s203', 'enum_specifier'] = 's238'
# gotoTable['s203', 'struct_or_union'] = 's93'
# gotoTable['s203', 'storage_class_specifier'] = 's15'
# gotoTable['s204', 'primary_expression'] = 's66'
# gotoTable['s204', 'relational_expression'] = 's178'
# gotoTable['s204', 'additive_expression'] = 's154'
# gotoTable['s204', 'constant_expression'] = 's96'
# gotoTable['s204', 'exclusive_or_expression'] = 's185'
# gotoTable['s204', 'conditional_expression'] = 's98'
# gotoTable['s204', 'inclusive_or_expression'] = 's36'
# gotoTable['s204', 'shift_expression'] = 's2'
# gotoTable['s204', 'unary_expression'] = 's119'
# gotoTable['s204', 'unary_operator'] = 's85'
# gotoTable['s204', 'postfix_expression'] = 's206'
# gotoTable['s204', 'logical_or_expression'] = 's60'
# gotoTable['s204', 'logical_and_expression'] = 's108'
# gotoTable['s204', 'equality_expression'] = 's100'
# gotoTable['s204', 'multiplicative_expression'] = 's107'
# gotoTable['s204', 'and_expression'] = 's121'
# gotoTable['s205', 'primary_expression'] = 's66'
# gotoTable['s205', 'relational_expression'] = 's178'
# gotoTable['s205', 'additive_expression'] = 's154'
# gotoTable['s205', 'exclusive_or_expression'] = 's185'
# gotoTable['s205', 'conditional_expression'] = 's37'
# gotoTable['s205', 'inclusive_or_expression'] = 's36'
# gotoTable['s205', 'shift_expression'] = 's2'
# gotoTable['s205', 'unary_expression'] = 's78'
# gotoTable['s205', 'unary_operator'] = 's85'
# gotoTable['s205', 'postfix_expression'] = 's206'
# gotoTable['s205', 'logical_or_expression'] = 's60'
# gotoTable['s205', 'logical_and_expression'] = 's108'
# gotoTable['s205', 'equality_expression'] = 's100'
# gotoTable['s205', 'multiplicative_expression'] = 's107'
# gotoTable['s205', 'and_expression'] = 's121'
# gotoTable['s205', 'assignment_expression'] = 's218'
# gotoTable['s209', 'primary_expression'] = 's66'
# gotoTable['s209', 'additive_expression'] = 's154'
# gotoTable['s209', 'shift_expression'] = 's199'
# gotoTable['s209', 'unary_expression'] = 's119'
# gotoTable['s209', 'unary_operator'] = 's85'
# gotoTable['s209', 'postfix_expression'] = 's206'
# gotoTable['s209', 'multiplicative_expression'] = 's107'
# gotoTable['s212', 'primary_expression'] = 's66'
# gotoTable['s212', 'unary_expression'] = 's79'
# gotoTable['s212', 'unary_operator'] = 's85'
# gotoTable['s212', 'postfix_expression'] = 's206'
# gotoTable['s217', 'enumerator'] = 's210'
# gotoTable['s217', 'enumerator_list'] = 's3'
# gotoTable['s219', 'primary_expression'] = 's66'
# gotoTable['s219', 'relational_expression'] = 's178'
# gotoTable['s219', 'additive_expression'] = 's154'
# gotoTable['s219', 'shift_expression'] = 's2'
# gotoTable['s219', 'unary_expression'] = 's119'
# gotoTable['s219', 'unary_operator'] = 's85'
# gotoTable['s219', 'postfix_expression'] = 's206'
# gotoTable['s219', 'equality_expression'] = 's100'
# gotoTable['s219', 'multiplicative_expression'] = 's107'
# gotoTable['s219', 'and_expression'] = 's152'
# gotoTable['s223', 'type_specifier'] = 's91'
# gotoTable['s223', 'primary_expression'] = 's66'
# gotoTable['s223', 'relational_expression'] = 's178'
# gotoTable['s223', 'additive_expression'] = 's154'
# gotoTable['s223', 'exclusive_or_expression'] = 's185'
# gotoTable['s223', 'conditional_expression'] = 's37'
# gotoTable['s223', 'struct_or_union_specifier'] = 's126'
# gotoTable['s223', 'inclusive_or_expression'] = 's36'
# gotoTable['s223', 'shift_expression'] = 's2'
# gotoTable['s223', 'unary_expression'] = 's78'
# gotoTable['s223', 'type_qualifier'] = 's61'
# gotoTable['s223', 'unary_operator'] = 's85'
# gotoTable['s223', 'specifier_qualifier_list'] = 's95'
# gotoTable['s223', 'expression'] = 's46'
# gotoTable['s223', 'postfix_expression'] = 's206'
# gotoTable['s223', 'enum_specifier'] = 's238'
# gotoTable['s223', 'struct_or_union'] = 's93'
# gotoTable['s223', 'logical_or_expression'] = 's60'
# gotoTable['s223', 'logical_and_expression'] = 's108'
# gotoTable['s223', 'equality_expression'] = 's100'
# gotoTable['s223', 'multiplicative_expression'] = 's107'
# gotoTable['s223', 'and_expression'] = 's121'
# gotoTable['s223', 'assignment_expression'] = 's105'
# gotoTable['s223', 'type_name'] = 's89'
# gotoTable['s224', 'type_specifier'] = 's91'
# gotoTable['s224', 'struct_or_union_specifier'] = 's126'
# gotoTable['s224', 'struct_declaration'] = 's92'
# gotoTable['s224', 'type_qualifier'] = 's61'
# gotoTable['s224', 'specifier_qualifier_list'] = 's22'
# gotoTable['s224', 'struct_declaration_list'] = 's43'
# gotoTable['s224', 'enum_specifier'] = 's238'
# gotoTable['s224', 'struct_or_union'] = 's93'
# gotoTable['s228', 'enumerator'] = 's210'
# gotoTable['s228', 'enumerator_list'] = 's82'
# gotoTable['s230', 'enumerator'] = 's174'
# gotoTable['s236', 'type_specifier'] = 's203'
# gotoTable['s236', 'struct_or_union_specifier'] = 's126'
# gotoTable['s236', 'direct_declarator'] = 's115'
# gotoTable['s236', 'parameter_type_list'] = 's114'
# gotoTable['s236', 'declarator'] = 's116'
# gotoTable['s236', 'direct_abstract_declarator'] = 's53'
# gotoTable['s236', 'type_qualifier'] = 's101'
# gotoTable['s236', 'parameter_declaration'] = 's44'
# gotoTable['s236', 'pointer'] = 's99'
# gotoTable['s236', 'declaration_specifiers'] = 's171'
# gotoTable['s236', 'enum_specifier'] = 's238'
# gotoTable['s236', 'parameter_list'] = 's88'
# gotoTable['s236', 'struct_or_union'] = 's93'
# gotoTable['s236', 'abstract_declarator'] = 's149'
# gotoTable['s236', 'storage_class_specifier'] = 's15'

# %%
# !rm GrammarLexer.* GrammarParser.* Grammar.tokens GrammarListener.py Grammar.interp 
# !rm -r __pycache__

# %%
# !ls
# Out:
# Examples                       Shift-Reduce-Parser-Pure.ipynb
# Grammar.g4                     parse-table.py
# Pure.g4                        sum-ast.pdf
# SLR-Table-Generator.ipynb      sum-st.pdf
# Shift-Reduce-Parser-AST.ipynb
