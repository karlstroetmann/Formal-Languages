# %%
from IPython.display import HTML
HTML(open('../style.css').read())
# Out:
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Philosopher:400,700,400italic,700italic' rel='stylesheet' type='text/css'>
# <link href="http://fonts.googleapis.com/css?family=Sacramento" rel="stylesheet" type="text/css">
#
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
# .container { width: 100% }
#
# /* Formatting for header cells */
# .text_cell_render h1 {
#     font-family: 'Philosopher', sans-serif;
#     font-weight: 400;
#     font-size: 2.2em;
#     line-height: 100%;
#     color: rgb(0, 80, 120);
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
# .text_cell_render h2 {
#     font-family: 'Philosopher', serif;
#     font-weight: 400;
#     font-size: 1.9em;
#     line-height: 100%;
#     color: rgb(200,100,0);
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h3 {
#     font-family: 'Philosopher', serif;
#     margin-top:12px;
#     margin-bottom: 3px;
#     font-style: italic;
#     color: rgb(94,127,192);
# }
#
# .text_cell_render h4 {
#     font-family: 'Philosopher', serif;
# }
#
# .text_cell_render h5 {
#     font-family: 'Alegreya Sans', sans-serif;
#     font-weight: 300;
#     font-size: 16pt;
#     color: grey;
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h6 {
#     font-family: 'PT Mono', sans-serif;
#     font-weight: 300;
#     font-size: 10pt;
#     color: grey;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# .text_cell_render em {
#     font-family: 'Philosopher', sans-serif;
#     color:        blue;
#     background-color: rgb(255,220,180);
#     font-size:    110%;
#     margin-left:   2px;
#     margin-right:  2px;
#     font-weight:   100;
# }
#
# .text_cell_render b {
#     color:            rgb(255,195,195);
#     background-color: rgb(0,0,0);
#     font-size:    110%;
#     margin-left:   2px;
#     margin-right:  2px;
#     font-weight:   650;
# }
#
# .text_cell_render u {
#     color:            blue;
#     font-size:    110%;
#     margin-left:   2px;
#     margin-right:  2px;
#     font-weight:   650;
# }
#
# .text_cell_render tt {
#     font-size:    120%;
#     margin-left:   2px;
#     margin-right:  2px;
#     font-weight:   150;
# }
#
# .Codemirror {
#     font-family: "PT Mono";
#     font-size: 100%;
# }
#
# #fancy {
#     font-family:      Georgia;
#     position:         relative;
#     float:            left;
#     border:           2px solid red;
#     width:            600px;
#     padding-left:     20px;
#     padding-right:    20px;
#     padding-top:      10px;
#     font-family:      'Sacramento', cursive;
#     font-size:        26px;
#     background-color: #F4EBF3;
#     border-radius:    15px;
# }
#
# </Style>

# %% [markdown]
# # Implementing an SLR-Table-Generator

# %% [markdown]
# ## A Grammar for Grammars

# %% [markdown]
# We use the following grammar to describe the syntax of a context free grammar.
# ```
# grammar
#     : rule
#     | rule grammar
#     ;
#
# rule
#     : VARIABLE ':' body_list ';'
#     ;
#
# body_list
#     : body
#     | body '|' body_list
#     ;
#
# body
#     :
#     | item body
#     ;
#
# item : VARIABLE
#      | TOKEN
#      | LITERAL
#      ;
# ```

# %% [markdown]
# As the goal is to generate an *SLR-table-generator* we first need to implement a parser for context free grammars.
# The file `arith.g` in the directory `Examples` contains an example grammar that describes arithmetic expressions.

# %%
# !cat Examples/arith.g
# Out:
# expr: expr '+' product
#     | expr '-' product
#     | product
#     ;
#
# product: product '*' factor
#        | product '/' factor
#        | factor
#        ;
#
# factor: '(' expr ')'
#       | NUMBER
#       ;

# %% [markdown]
# We use <span style="font-variant:small-caps;">Ply</span> to develop a parser for context free grammars.

# %%
import ply.lex as lex

# %%
tokens = [ 'VARIABLE',  # r'[a-z][a-z0-9_]*'
           'TOKEN',     # r'[A-Z][A-Z0-9_]*'
           'LITERAL',   # r"'.+?'"
         ]

# %%
t_VARIABLE = r'[a-z][a-z0-9_]*'
t_TOKEN    = r'[A-Z][A-Z0-9_]*'

# %%
def t_comment(t):
    r'//.*'

# %%
def t_LITERAL(t):
    r"'.+?'"
    return t

# %%
literals = [':', '|', ';']

# %%
t_ignore = ' \t\r'

# %%
def t_newline(t):
    r'\n'
    t.lexer.lineno += 1
    return

# %%
def find_column(token):
    program    = token.lexer.lexdata  # the complete string given to the scanner
    line_start = program.rfind('\n', 0, token.lexpos)
    return token.lexpos - line_start

# %%
def t_error(t):
    column = find_column(t)
    print(f"Illegal character '{t.value[0]}' in line {t.lineno}, column {column}.")
    t.lexer.skip(1)

# %%
__file__ = 'main'

# %%
lexer = lex.lex()

# %%
def test_scanner(file_name):
    with open(file_name, 'r') as handle:
        program = handle.read() 
    print(program)
    lexer.input(program)
    lexer.lineno = 1          # reset line number
    for t in lexer:           # start scanning and collect all tokens
        print(t)

# %%
test_scanner('Examples/arith.g')
# Out:
# expr: expr '+' product
#     | expr '-' product
#     | product
#     ;
#
# product: product '*' factor
#        | product '/' factor
#        | factor
#        ;
#
# factor: '(' expr ')'
#       | NUMBER
#       ;
#
# LexToken(VARIABLE,'expr',1,0)
# LexToken(:,':',1,4)
# LexToken(VARIABLE,'expr',1,6)
# LexToken(LITERAL,"'+'",1,11)
# LexToken(VARIABLE,'product',1,15)
# LexToken(|,'|',2,27)
# LexToken(VARIABLE,'expr',2,29)
# LexToken(LITERAL,"'-'",2,34)
# LexToken(VARIABLE,'product',2,38)
# LexToken(|,'|',3,50)
# LexToken(VARIABLE,'product',3,52)
# LexToken(;,';',4,64)
# LexToken(VARIABLE,'product',6,68)
# LexToken(:,':',6,75)
# LexToken(VARIABLE,'product',6,77)
# LexToken(LITERAL,"'*'",6,85)
# LexToken(VARIABLE,'factor',6,89)
# LexToken(|,'|',7,103)
# LexToken(VARIABLE,'product',7,105)
# LexToken(LITERAL,"'/'",7,113)
# LexToken(VARIABLE,'factor',7,117)
# LexToken(|,'|',8,131)
# LexToken(VARIABLE,'factor',8,133)
# LexToken(;,';',9,147)
# LexToken(VARIABLE,'factor',11,157)
# LexToken(:,':',11,163)
# LexToken(LITERAL,"'('",11,165)
# LexToken(VARIABLE,'expr',11,169)
# LexToken(LITERAL,"')'",11,174)
# LexToken(|,'|',12,184)
# LexToken(TOKEN,'NUMBER',12,186)
# LexToken(;,';',13,199)

# %%
import ply.yacc as yacc

# %%
start = 'grammar'

# %%
Variable = str
Token    = str
Symbol   = Variable | Token
Symbols  = tuple[Symbol, ...]

# %% [markdown]
# The types of the variables are as follows:
# ```
# grammar:   [Rule]
# rule:      (Variable,) + Symbols
# body_list: [Symbols]
# body:      Symbols
# item:      Symbol
# ```

# %%
def p_grammar_one(p):
    "grammar : rule"
    p[0] = p[1]

def p_grammar_more(p):
    "grammar : rule grammar"
    p[0] = p[1] + p[2]

# %%
def p_rule(p):
    "rule : VARIABLE ':' body_list ';'"
    p[0] = [ (p[1],) + body for body in p[3] ]

# %%
def p_body_list_one(p):
    "body_list : body"
    p[0] = [p[1]]

def p_body_list_more(p):
    "body_list : body '|' body_list "
    p[0] = [p[1]] + p[3]

# %%
def p_body_empty(p):
    "body : "
    p[0] = ()

def p_body_more(p):
    "body : item body"
    p[0] = (p[1],) + p[2]

# %%
def p_item_variable(p):
    "item : VARIABLE"
    p[0] = p[1]

def p_item_terminal(p):
    "item : TOKEN"
    p[0] = p[1]

def p_item_literal(p):
    "item : LITERAL"
    p[0] = p[1]

# %%
def p_error(t):
    column = find_column(t)
    if t:
        print(f'Syntax error at token "{t.value}" in line {t.lineno}, column {column}.')
    else:
        print('Syntax error at end of input.')

# %%
yacc.yacc(write_tables=False, debug=True);
# Out:
# Generating LALR tables

# %%
def parse(file):
    lexer.lineno = 1
    with open(file, 'r') as handle:
        grammar = handle.read() 
    print(grammar)
    ruleList = yacc.parse(grammar)
    return ruleList

# %%
ruleList = parse('Examples/arith.g')
ruleList
# Out:
# expr: expr '+' product
#     | expr '-' product
#     | product
#     ;
#
# product: product '*' factor
#        | product '/' factor
#        | factor
#        ;
#
# factor: '(' expr ')'
#       | NUMBER
#       ;
# [('expr', 'expr', "'+'", 'product'),
#  ('expr', 'expr', "'-'", 'product'),
#  ('expr', 'product'),
#  ('product', 'product', "'*'", 'factor'),
#  ('product', 'product', "'/'", 'factor'),
#  ('product', 'factor'),
#  ('factor', "'('", 'expr', "')'"),
#  ('factor', 'NUMBER')]

# %% [markdown]
# The parser will return a list of grammar rules, where each rule of the form
# $$ a \rightarrow \beta $$
# is stored as the tuple `(a,) + 𝛽`.

# %%
# %load_ext nb_mypy
# Out:
# Version 1.0.6

# %% [markdown]
# We define a few *type aliases* in order to make the types more readable.

# %%
Variable = str
Token    = str
Symbol   = Variable | Token
Symbols  = tuple[Symbol, ...]

# %% [markdown]
# ### The Class `GrammarRule`

# %% [markdown]
# The class `GrammarRule` is used to store a single grammar rule.  As we have to use objects of type `GrammarRule` as *keys* in a dictionary later, we have to provide the methods `__eq__`, `__ne__`, and `__hash__`.

# %%
class GrammarRule:
    def __init__(self, variable: Variable, body: Symbols) -> None:
        self.mVariable: Variable = variable
        self.mBody    : Symbols  = body
        
    def __eq__(self, other) -> bool:
        return isinstance(other, GrammarRule)    and \
               self.mVariable == other.mVariable and \
               self.mBody     == other.mBody
    
    def __ne__(self, other) -> bool:
        return not self.__eq__(other)
    
    def __hash__(self) -> int:
        return hash(self.__repr__())
    
    def __repr__(self) -> str:
        return f'{self.mVariable} → {" ".join(self.mBody)}'

# %% [markdown]
# The function `transform(rules)` takes a list of tuples representing grammar rules and converts these tuples into objects of class
# `GrammarRule`.

# %%
def transform(rules: list[tuple[Symbol, ...]]) -> list[GrammarRule]:
    return [ GrammarRule(var, tuple(body)) for (var, *body) in rules]

# %%
ruleList: list[tuple[Symbol, ...]]

# %%
ruleList
# Out:
# [('expr', 'expr', "'+'", 'product'),
#  ('expr', 'expr', "'-'", 'product'),
#  ('expr', 'product'),
#  ('product', 'product', "'*'", 'factor'),
#  ('product', 'product', "'/'", 'factor'),
#  ('product', 'factor'),
#  ('factor', "'('", 'expr', "')'"),
#  ('factor', 'NUMBER')]

# %%
grammar = transform(ruleList)

# %%
grammar
# Out:
# [expr → expr '+' product,
#  expr → expr '-' product,
#  expr → product,
#  product → product '*' factor,
#  product → product '/' factor,
#  product → factor,
#  factor → '(' expr ')',
#  factor → NUMBER]

# %% [markdown]
# Given a string `name`, which is either a *variable*, a *token*, or a *literal*, the function `is_var` checks whether `name` is a variable.  The function can distinguish variable names from tokens and literals because variable names consist only of lower case letters, while tokens are all uppercase and literals start with the character "`'`".

# %%
def is_var(name: Symbol) -> bool:
    return name[0].islower()

# %% [markdown]
# Given a list `Rules` of `GrammarRules`, the function `collect_variables(Rules)` returns the set of all *variables* occuring in `Rules`.

# %%
def collect_variables(Rules: list[GrammarRule]) -> set[Variable]:
    Variables: set[Variable] = set()
    for rule in Rules:
        Variables.add(rule.mVariable)
        for item in rule.mBody:
            if is_var(item):
                Variables.add(item)
    return Variables

# %%
collect_variables(grammar)
# Out:
# {'expr', 'factor', 'product'}

# %% [markdown]
# Given a list `Rules` of `GrammarRules`, the function `collect_tokens(Rules)` returns the set of all *tokens* and *literals* occuring in `Rules`.

# %%
def collect_tokens(Rules: list[GrammarRule]) -> set[Token]:
    Tokens: set[Token] = set()
    for rule in Rules:
        for item in rule.mBody:
            if not is_var(item):
                Tokens.add(item)
    return Tokens

# %%
collect_tokens(grammar)
# Out:
# {"'('", "')'", "'*'", "'+'", "'-'", "'/'", 'NUMBER'}

# %% [markdown]
# ## Marked Rules

# %% [markdown]
# The class `MarkedRule` stores a single *marked rule* of the form
# $$ v \rightarrow \alpha \bullet \beta $$
# where the *variable* $v$ is stored in the member variable `mVariable`, while $\alpha$ and $\beta$ are stored in the variables `mAlpha`and `mBeta` respectively.  These variables are assumed to contain tuples of *grammar symbols*.  A *grammar symbol* is either
# - a *variable*,
# - a *token*, or
# - a *literal*, i.e. a string enclosed in single quotes.
#
#
# Later, we need to maintain sets of *marked rules* to represent *states*.  Therefore, we have to define the methods `__eq__`, `__ne__`, and `__hash__`.

# %%
class MarkedRule():
    def __init__(self, variable: Variable, alpha: Symbols, beta: Symbols) -> None:
        self.mVariable: Variable = variable
        self.mAlpha   : Symbols  = alpha
        self.mBeta    : Symbols  = beta
        
    def __eq__(self, other) -> bool:
        return isinstance(other, MarkedRule)     and \
               self.mVariable == other.mVariable and \
               self.mAlpha    == other.mAlpha    and \
               self.mBeta     == other.mBeta
    
    def __ne__(self, other) -> bool:
        return not self.__eq__(other)
    
    def __hash__(self) -> int:
        return hash(self.__repr__())
    
    def __repr__(self) -> str:
        alphaStr = ' '.join(self.mAlpha)
        betaStr  = ' '.join(self.mBeta)
        return f'{self.mVariable} → {alphaStr} • {betaStr}'

# %% [markdown]
# Given a *marked rule* `self`, the function `is_complete` checks, whether the *marked rule* `self` has the form
# $$ c \rightarrow \alpha\; \bullet,$$
# i.e. it checks, whether the $\bullet$ is at the end of the grammar rule.

# %%
def is_complete(self: MarkedRule) -> bool:
    return len(self.mBeta) == 0

MarkedRule.is_complete = is_complete # type: ignore
del is_complete

# %% [markdown]
# Given a *marked rule* `self` of the form
# $$ c \rightarrow \alpha \bullet X\, \delta, $$
# the function `symbol_after_dot` returns the *symbol* $X$. If there is no symbol after the $\bullet$, the method returns `None`.

# %%
def symbol_after_dot(self: MarkedRule) -> Symbol | None:
    if len(self.mBeta) > 0:
        return self.mBeta[0]
    return None

MarkedRule.symbol_after_dot = symbol_after_dot # type: ignore
del symbol_after_dot

# %% [markdown]
# Given a marked rule of the form
# $$ c \rightarrow \alpha \bullet b \delta, $$
# this function returns the variable $b$ following the dot.  If there is no variable following the dot, the function returns `None`.

# %%
def next_var(self: MarkedRule) -> Variable | None:
    if len(self.mBeta) > 0:
        var = self.mBeta[0]
        if is_var(var):
            return var
    return None

MarkedRule.next_var = next_var # type: ignore
del next_var

# %% [markdown]
# The function `move_dot(self)` transforms a *marked rule*  of the form
# $$ c \rightarrow \alpha \bullet X\, \beta $$
# into a *marked rule* of the form
# $$ c \rightarrow \alpha\, X \bullet \beta, $$
# i.e. the $\bullet$ is moved over the next symbol.  Invocation of this method assumes that there is a symbol
# following the $\bullet$.

# %%
def move_dot(self: MarkedRule) -> MarkedRule:
    return MarkedRule(self.mVariable, 
                      self.mAlpha + (self.mBeta[0],), 
                      self.mBeta[1:])

MarkedRule.move_dot = move_dot # type: ignore
del move_dot

# %% [markdown]
# The function `to_rule(self)` turns the *marked rule* `self` into  a `GrammarRule`, i.e. the *marked rule*
# $$ c \rightarrow \alpha \bullet \beta $$
# is turned into the grammar rule
# $$ c \rightarrow \alpha\, \beta. $$

# %%
def to_rule(self: MarkedRule) -> GrammarRule:
    return GrammarRule(self.mVariable, self.mAlpha + self.mBeta)

MarkedRule.to_rule = to_rule # type: ignore
del to_rule

# %% [markdown]
# ## SLR-Table-Generation

# %% [markdown]
# The class `Grammar` represents a context free grammar.  It stores a list of the `GrammarRules` of the given grammar.
# Each grammar rule is of the form
# $$ a \rightarrow \beta $$
# where $\beta$ is a tuple of variables, tokens, and literals.
# The start symbol is assumed to be the variable on the left hand side of the first rule. The grammar is *augmented* with the rule
# $$ \widehat{s} \rightarrow s\, \$. $$
# Here $s$ is the start variable of the given grammar and $\widehat{s}$ is a new variable that is the start variable of the *augmented grammar*. The symbol `$` denotes the end of input.  The non-obvious member variables of the class `Grammar` have the following interpretation
# - `mStates` is the set of all states of the *SLR-parser*.  These states are sets of *marked rules*.
# - `mStateNames`is a dictionary assigning names of the form `s0`, `s1`, $\cdots$, `sn` to the states stored in
#   `mStates`.  The functions `action` and `goto` will be defined for *state names*, not for *states*, because
#   otherwise the table representing these functions would become both huge and unreadable.
#   Therefore, the dictionary `mStateNames` is needed to associate the the states with their names.
# - `mConflicts` is a Boolean variable that will be set to `True` if the table generation discovers
#   a *shift/reduce conflict* or a *reduce/reduce conflict*.

# %%
class Grammar():
    def __init__(self, Rules: list[GrammarRule]):
        self.mRules     : list[GrammarRule] = Rules
        self.mStart     : Variable          = Rules[0].mVariable
        self.mVariables : set[Variable]     = collect_variables(Rules)
        self.mTokens    : set[Token]        = collect_tokens(Rules)
        self.mStates    : set[frozenset[MarkedRule]] = set()
        self.mConflicts : bool              = False
        self.mStateNames: dict[str, set[MarkedRule]] = {}
        self.mVariables.add('ŝ')
        self.mTokens.add('$') # short for EOF
        self.mRules.append(GrammarRule('ŝ', (self.mStart, '$'))) # augment the grammar
        self.mRuleNames: dict[GrammarRule, str] = {} 
        self.compute_tables()                                    

    def compute_tables(self) -> None:
        pass

# %% [markdown]
# Given a set of `Variables`, the function `initialize_dictionary` returns a dictionary that assigns the empty set to all variables.
# This function is needed to initialize the member variable `mFirst` and `mFollow` that are dictionaries storing the *first-set* and
# *follow-sets* of the syntactical variables.

# %%
def initialize_dictionary(Variables: set[Variable]) -> dict[Variable, set[Token]]:
    return { a: set() for a in Variables }

# %% [markdown]
# Given a `Grammar`, the function `compute_tables` computes
# - the sets `First(v)` and `Follow(v)` for every variable `v`,
# - the set of all *states* of the *SLR-Parser*,
# - the *action table*, and
# - the *goto table*.
#
# Given a grammar `g`,
# - the set `g.mFirst` is a dictionary such that `g.mFirst[a] = First(a)` and
# - the set `g.mFollow` is a dictionary such that `g.mFollow[a] = Follow(a)` for all variables `a`.

# %%
def compute_tables(self: Grammar) -> None:
    self.mFirst  = initialize_dictionary(self.mVariables) # type: ignore
    self.mFollow = initialize_dictionary(self.mVariables) # type: ignore
    self.compute_first()         # type: ignore
    self.compute_follow()        # type: ignore
    self.compute_rule_names()    # type: ignore
    self.all_states()            # type: ignore
    self.compute_action_table()  # type: ignore
    self.compute_goto_table()    # type: ignore
    
Grammar.compute_tables = compute_tables # type: ignore
del compute_tables

# %% [markdown]
# The function `compute_rule_names` assigns a unique name to each *rule* of the grammar.  These names are used later
# to represent *reduce actions* in the *action table*.

# %%
def compute_rule_names(self: Grammar) -> None:
    counter = 0
    for rule in self.mRules:
        self.mRuleNames[rule] = 'r' + str(counter)
        counter += 1
        
Grammar.compute_rule_names = compute_rule_names # type: ignore
del compute_rule_names

# %% [markdown]
# The function `compute_first(self)` computes the sets $\texttt{First}(c)$ for all variables $c$ and stores them in the dictionary `mFirst`.  Abstractly, given a variable $c$ the function $\texttt{First}(c)$ is the set of all tokens that can start a string that is derived from $c$:
# $$\texttt{First}(\texttt{c}) :=
#   \Bigl\{ t \in T \Bigm| \exists \gamma \in (V \cup T)^*: \texttt{c} \Rightarrow^* t\,\gamma \Bigr\}.
# $$
# The definition of the function $\texttt{First}()$ is extended to strings from $(V \cup T)^*$ as follows:
# - $\texttt{FirstList}(\lambda) = \{\}$.
# - $\texttt{FirstList}(t \beta) = \{ t \}$  if $t \in T$.
# - $\texttt{FirstList}(\texttt{a} \beta) = \left\{
#        \begin{array}[c]{ll}
#          \texttt{First}(\texttt{a}) \cup \texttt{FirstList}(\beta) & \mbox{if $\texttt{a} \Rightarrow^* \lambda$;} \\
#          \texttt{First}(\texttt{a})                                & \mbox{otherwise.}
#        \end{array}
#        \right.
#       $
#
# If $\texttt{a}$ is a variable of $G$ and the rules defining $\texttt{a}$ are given as
# $$\texttt{a} \rightarrow \alpha_1 \mid \cdots \mid \alpha_n, $$
# then we have
# $$\texttt{First}(\texttt{a}) = \bigcup\limits_{i=1}^n \texttt{FirstList}(\alpha_i). $$
# The dictionary `mFirst` that stores this function is computed via a *fixed point iteration*.

# %%
def compute_first(self: Grammar) -> None:
    change = True
    while change:
        change = False
        for rule in self.mRules:
            a, body = rule.mVariable, rule.mBody
            first_body = self.first_list(body)      # type: ignore
            if not (first_body <= self.mFirst[a]):  # type: ignore
                change = True
                self.mFirst[a] |= first_body        # type: ignore   
    print('First sets:')
    for v in self.mVariables:
        print(f'First({v}) = {self.mFirst[v]}')     # type: ignore
        
Grammar.compute_first = compute_first               # type: ignore
del compute_first

# %% [markdown]
# Given a tuple of variables and tokens `alpha`, the function `first_list(alpha)` computes the function $\texttt{FirstList}(\alpha)$ that has been defined above.  If `alpha` is *nullable*, then the result will contain the empty string $\lambda$.

# %%
def first_list(self: Grammar, alpha: Symbols) -> set[Token]:
    if len(alpha) == 0:
        return { '' }
    elif is_var(alpha[0]): 
        v, *r = alpha
        return eps_union(self.mFirst[v], self.first_list(r)) # type: ignore
    else:
        t = alpha[0]
        return { t }
    
Grammar.first_list = first_list                              # type: ignore
del first_list

# %% [markdown]
# The arguments `S` and `T` of `eps_union` are sets that contain tokens and, additionally, they might contain the empty string
# $\lambda =$ `''`.  The specification of `eps_union` is:
# $$ \mathtt{eps\_union}(S, T) = \left\{ \begin{array}{ll}
#                                        S          & \mbox{if $\lambda \not\in S$} \\
#                                        S \cup T   & \mbox{if $\lambda \in S \wedge \lambda \in T$} \\
#                                        S \cup T - \{\lambda \} & \mbox{if $\lambda \in S \wedge \lambda \not\in T$}
#                                       \end{array}
#                               \right.
# $$

# %%
def eps_union(S: set[Token], T: set[Token]) -> set[Token]:
    if '' in S: 
        if '' in T: 
            return S | T
        return (S - { '' }) | T
    return S

# %% [markdown]
# Given an augmented grammar $G = \langle V,T,R\cup\{\widehat{s} \rightarrow s\,\$\}, \widehat{s}\rangle$
# and a variable $a$, the set of tokens that might follow $a$ is defined as:
# $$\texttt{Follow}(a) :=
#  \bigl\{ t \in \widehat{T} \,\bigm|\, \exists \beta,\gamma \in (V \cup \widehat{T})^*:
#                            \widehat{s} \Rightarrow^* \beta \,a\, t\, \gamma
#   \bigr\}.
# $$
# The function `compute_follow` computes the sets $\texttt{Follow}(a)$ for all variables $a$ via a *fixed-point iteration*.

# %%
def compute_follow(self: Grammar) -> None:
    self.mFollow[self.mStart] = { '$' }                           # type: ignore
    change = True
    while change:
        change = False
        for rule in self.mRules:
            a, body = rule.mVariable, rule.mBody
            for i in range(len(body)):
                if is_var(body[i]):
                    yi        = body[i]
                    Tail      = self.first_list(body[i+1:])       # type: ignore
                    firstTail = eps_union(Tail, self.mFollow[a])  # type: ignore
                    if not (firstTail <= self.mFollow[yi]):       # type: ignore
                        change = True
                        self.mFollow[yi] |= firstTail             # type: ignore
    print('Follow sets (note that "$" denotes the end of file):')
    for v in self.mVariables:
        print(f'Follow({v}) = {self.mFollow[v]}')                 # type: ignore
        
Grammar.compute_follow = compute_follow                           # type: ignore
del compute_follow

# %% [markdown]
# If $\mathcal{M}$ is a set of *marked rules*, then the *closure* of $\mathcal{M}$ is the smallest set $\mathcal{K}$ such that
# we have the following:
# - $\mathcal{M} \subseteq \mathcal{K}$,
# - If $a \rightarrow \beta \bullet c\, \delta$ is a *marked rule* from
#   $\mathcal{K}$, and $c$ is a variable and if, furthermore,
#   $c \rightarrow \gamma$ is a grammar rule,
#   then the marked rule $c \rightarrow \bullet \gamma$
#   is an element of $\mathcal{K}$:
#   $$(a \rightarrow \beta \bullet c\, \delta) \in \mathcal{K}
#          \;\wedge\;
#          (c \rightarrow \gamma) \in R
#          \;\Rightarrow\; (c \rightarrow \bullet \gamma) \in \mathcal{K}
#   $$
#
# We define $\texttt{closure}(\mathcal{M}) := \mathcal{K}$.  The function `cmp_closure` computes this closure for a given set of *marked rules* via a *fixed-point iteration*.

# %%
def cmp_closure(self, Marked_Rules: set[MarkedRule]) -> frozenset[MarkedRule]:
    All_Rules = Marked_Rules
    New_Rules = Marked_Rules
    while True:
        More_Rules = set()
        for rule in New_Rules:
            c = rule.next_var()                                  # type: ignore
            if c == None:
                continue
            for rule in self.mRules:
                head, alpha = rule.mVariable, rule.mBody         # type: ignore
                if c == head:
                    More_Rules |= { MarkedRule(head, (), alpha) }
        if More_Rules <= All_Rules:
            return frozenset(All_Rules)
        New_Rules  = More_Rules - All_Rules
        All_Rules |= New_Rules

Grammar.cmp_closure = cmp_closure                                 # type: ignore
del cmp_closure

# %% [markdown]
# Given a set of *marked rules* $\mathcal{M}$ and a *grammar symbol* $X$, the function $\texttt{goto}(\mathcal{M}, X)$
# is defined as follows:
# $$\texttt{goto}(\mathcal{M}, X) := \texttt{closure}\Bigl( \bigl\{
#    a \rightarrow \beta\, X \bullet \delta \bigm| (a \rightarrow \beta \bullet X\, \delta) \in \mathcal{M}
#    \bigr\} \Bigr).
# $$

# %%
def goto(self, Marked_Rules, x):
    Result = set()
    for mr in Marked_Rules:
        if mr.symbol_after_dot() == x:
            Result.add(mr.move_dot())
    return self.cmp_closure(Result)

Grammar.goto = goto  # type: ignore
del goto

# %% [markdown]
# The function `all_states` computes the set of all states of an *SLR-parser*.  The function starts with the state
# $$ \texttt{closure}\bigl(\{ \widehat{s} \rightarrow \bullet s \, $\}\bigr) $$
# and then tries to compute new states by using the function `goto`.  This computation proceeds via a
# *fixed-point iteration*.  Once all states have been computed, the function assigns names to these states.
# This association is stored in the dictionary *mStateNames*.

# %%
def all_states(self) -> None: 
    start_state  = self.cmp_closure({ MarkedRule('ŝ', (), (self.mStart, '$')) })
    self.mStates = { start_state }
    New_States   = self.mStates
    while True:
        More_States = set()
        for Rule_Set in New_States:
            for mr in Rule_Set: 
                if not mr.is_complete():
                    x = mr.symbol_after_dot()
                    if x != '$':
                        More_States |= { self.goto(Rule_Set, x) }
        if More_States <= self.mStates:
            break
        New_States = More_States - self.mStates;
        self.mStates |= New_States
    print("All SLR-states:")
    counter = 1
    self.mStateNames[start_state] = 's0'
    print(f's0 = {set(start_state)}')
    for state in self.mStates - { start_state }:
        self.mStateNames[state] = f's{counter}'
        print(f's{counter} = {set(state)}')
        counter += 1

Grammar.all_states = all_states # type: ignore
del all_states

# %% [markdown]
# The following function computes the *action table* and is defined as follows:
# - If $\mathcal{M}$ contains a *marked rule* of the form $a \rightarrow \beta \bullet t\, \delta$
#   then we have
#   $$\texttt{action}(\mathcal{M},t) := \langle \texttt{shift}, \texttt{goto}(\mathcal{M},t) \rangle.$$
# - If $\mathcal{M}$ contains a marked rule of the form $a \rightarrow \beta\, \bullet$ and we have
#   $t \in \texttt{Follow}(a)$, then we define
#   $$\texttt{action}(\mathcal{M},t) := \langle \texttt{reduce}, a \rightarrow \beta \rangle$$
# - If $\mathcal{M}$ contains the marked rule $\widehat{s} \rightarrow s \bullet \$ $, then we define
#   $$\texttt{action}(\mathcal{M},\$) := \texttt{accept}. $$
# - Otherwise, we have
#   $$\texttt{action}(\mathcal{M},t) := \texttt{error}. $$

# %%
def compute_action_table(self):
    self.mActionTable = {}
    print('\nAction Table:')
    for state in self.mStates:
        stateName = self.mStateNames[state]
        actionTable = {}
        # compute shift actions
        for token in self.mTokens:
            if token != '$':
                newState  = self.goto(state, token)
                if newState != set():
                    newName = self.mStateNames[newState]
                    actionTable[token] = ('shift', newName)
                    self.mActionTable[stateName, token] = ('shift', newName)
                    print(f'action("{stateName}", {token}) = ("shift", {newName})')
        # compute reduce actions
        for mr in state:
            if mr.is_complete():
                for token in self.mFollow[mr.mVariable]:
                    action1 = actionTable.get(token)
                    action2 = ('reduce', mr.to_rule())
                    if action1 == None:
                        actionTable[token] = action2  
                        r = self.mRuleNames[mr.to_rule()]
                        self.mActionTable[stateName, token] = ('reduce', r)
                        print(f'action("{stateName}", {token}) = {action2}')
                    elif action1 != action2: 
                        self.mConflicts = True
                        print('')
                        print(f'conflict in state {stateName}:')
                        print(f'{stateName} = {state}')
                        print(f'action("{stateName}", {token}) = {action1}')     
                        print(f'action("{stateName}", {token}) = {action2}')
                        print('')
        for mr in state:
            if mr == MarkedRule('ŝ', (self.mStart,), ('$',)):
                actionTable['$'] = 'accept'
                self.mActionTable[stateName, '$'] = 'accept'
                print(f'action("{stateName}", $) = accept')

Grammar.compute_action_table = compute_action_table # type: ignore
del compute_action_table

# %% [markdown]
# The function `compute_goto_table` computes the *goto table*.

# %%
def compute_goto_table(self) -> None:
    self.mGotoTable = {}
    print('\nGoto Table:')
    for state in self.mStates:
        for var in self.mVariables:
            newState = self.goto(state, var)
            if newState != set():
                stateName = self.mStateNames[state]
                newName   = self.mStateNames[newState]
                self.mGotoTable[stateName, var] = newName
                print(f'goto({stateName}, {var}) = {newName}')

Grammar.compute_goto_table = compute_goto_table # type: ignore
del compute_goto_table

# %%
grammar
# Out:
# [expr → expr '+' product,
#  expr → expr '-' product,
#  expr → product,
#  product → product '*' factor,
#  product → product '/' factor,
#  product → factor,
#  factor → '(' expr ')',
#  factor → NUMBER]

# %%
# %%time
g = Grammar(grammar)
# Out:
# First sets:
# First(product) = {"'('", 'NUMBER'}
# First(factor) = {"'('", 'NUMBER'}
# First(ŝ) = {"'('", 'NUMBER'}
# First(expr) = {"'('", 'NUMBER'}
# Follow sets (note that "$" denotes the end of file):
# Follow(product) = {"')'", "'-'", "'*'", "'+'", "'/'", '$'}
# Follow(factor) = {"')'", "'-'", "'*'", "'+'", "'/'", '$'}
# Follow(ŝ) = set()
# Follow(expr) = {"'-'", "')'", '$', "'+'"}
# All SLR-states:
# s0 = {product →  • factor, expr →  • product, expr →  • expr '+' product, factor →  • NUMBER, factor →  • '(' expr ')', product →  • product '/' factor, expr →  • expr '-' product, product →  • product '*' factor, ŝ →  • expr $}
# s1 = {ŝ → expr • $, expr → expr • '+' product, expr → expr • '-' product}
# s2 = {product → factor • }
# s3 = {product → product '/' • factor, factor →  • NUMBER, factor →  • '(' expr ')'}
# s4 = {factor → NUMBER • }
# s5 = {product → product • '*' factor, expr → product • , product → product • '/' factor}
# s6 = {product →  • factor, factor → '(' • expr ')', expr →  • product, expr →  • expr '+' product, factor →  • NUMBER, factor →  • '(' expr ')', product →  • product '/' factor, expr →  • expr '-' product, product →  • product '*' factor}
# s7 = {expr → expr '+' product • , product → product • '*' factor, product → product • '/' factor}
# s8 = {expr → expr • '+' product, factor → '(' expr • ')', expr → expr • '-' product}
# s9 = {product → product '*' • factor, factor →  • NUMBER, factor →  • '(' expr ')'}
# s10 = {factor → '(' expr ')' • }
# s11 = {product → product '/' factor • }
# s12 = {factor →  • NUMBER, factor →  • '(' expr ')', product →  • product '/' factor, product →  • factor, product →  • product '*' factor, expr → expr '-' • product}
# s13 = {product → product '*' factor • }
# s14 = {factor →  • NUMBER, factor →  • '(' expr ')', product →  • product '/' factor, expr → expr '+' • product, product →  • factor, product →  • product '*' factor}
# s15 = {product → product • '*' factor, expr → expr '-' product • , product → product • '/' factor}
#
# Action Table:
# action("s8", ')') = ("shift", s10)
# action("s8", '-') = ("shift", s12)
# action("s8", '+') = ("shift", s14)
# action("s9", NUMBER) = ("shift", s4)
# action("s9", '(') = ("shift", s6)
# action("s1", '-') = ("shift", s12)
# action("s1", '+') = ("shift", s14)
# action("s1", $) = accept
# action("s2", ')') = ('reduce', product → factor)
# action("s2", '-') = ('reduce', product → factor)
# action("s2", '*') = ('reduce', product → factor)
# action("s2", '+') = ('reduce', product → factor)
# action("s2", '/') = ('reduce', product → factor)
# action("s2", $) = ('reduce', product → factor)
# action("s10", ')') = ('reduce', factor → '(' expr ')')
# action("s10", '-') = ('reduce', factor → '(' expr ')')
# action("s10", '*') = ('reduce', factor → '(' expr ')')
# action("s10", '+') = ('reduce', factor → '(' expr ')')
# action("s10", '/') = ('reduce', factor → '(' expr ')')
# action("s10", $) = ('reduce', factor → '(' expr ')')
# action("s3", NUMBER) = ("shift", s4)
# action("s3", '(') = ("shift", s6)
# action("s11", ')') = ('reduce', product → product '/' factor)
# action("s11", '-') = ('reduce', product → product '/' factor)
# action("s11", '*') = ('reduce', product → product '/' factor)
# action("s11", '+') = ('reduce', product → product '/' factor)
# action("s11", '/') = ('reduce', product → product '/' factor)
# action("s11", $) = ('reduce', product → product '/' factor)
# action("s7", '*') = ("shift", s9)
# action("s7", '/') = ("shift", s3)
# action("s7", '-') = ('reduce', expr → expr '+' product)
# action("s7", ')') = ('reduce', expr → expr '+' product)
# action("s7", $) = ('reduce', expr → expr '+' product)
# action("s7", '+') = ('reduce', expr → expr '+' product)
# action("s12", NUMBER) = ("shift", s4)
# action("s12", '(') = ("shift", s6)
# action("s4", ')') = ('reduce', factor → NUMBER)
# action("s4", '-') = ('reduce', factor → NUMBER)
# action("s4", '*') = ('reduce', factor → NUMBER)
# action("s4", '+') = ('reduce', factor → NUMBER)
# action("s4", '/') = ('reduce', factor → NUMBER)
# action("s4", $) = ('reduce', factor → NUMBER)
# action("s5", '*') = ("shift", s9)
# action("s5", '/') = ("shift", s3)
# action("s5", '-') = ('reduce', expr → product)
# action("s5", ')') = ('reduce', expr → product)
# action("s5", $) = ('reduce', expr → product)
# action("s5", '+') = ('reduce', expr → product)
# action("s6", NUMBER) = ("shift", s4)
# action("s6", '(') = ("shift", s6)
# action("s15", '*') = ("shift", s9)
# action("s15", '/') = ("shift", s3)
# action("s15", '-') = ('reduce', expr → expr '-' product)
# action("s15", ')') = ('reduce', expr → expr '-' product)
# action("s15", $) = ('reduce', expr → expr '-' product)
# action("s15", '+') = ('reduce', expr → expr '-' product)
# action("s13", ')') = ('reduce', product → product '*' factor)
# action("s13", '-') = ('reduce', product → product '*' factor)
# action("s13", '*') = ('reduce', product → product '*' factor)
# action("s13", '+') = ('reduce', product → product '*' factor)
# action("s13", '/') = ('reduce', product → product '*' factor)
# action("s13", $) = ('reduce', product → product '*' factor)
# action("s14", NUMBER) = ("shift", s4)
# action("s14", '(') = ("shift", s6)
# action("s0", NUMBER) = ("shift", s4)
# action("s0", '(') = ("shift", s6)
#
# Goto Table:
# goto(s9, factor) = s13
# goto(s3, factor) = s11
# goto(s12, product) = s15
# goto(s12, factor) = s2
# goto(s6, product) = s5
# goto(s6, factor) = s2
# goto(s6, expr) = s8
# goto(s14, product) = s7
# goto(s14, factor) = s2
# goto(s0, product) = s5
# goto(s0, factor) = s2
# goto(s0, expr) = s1
# CPU times: user 5.89 ms, sys: 245 μs, total: 6.13 ms
# Wall time: 6.27 ms

# %%
def strip_quotes(t):
    if t[0] == "'" and t[-1] == "'":
        return t[1:-1]
    return t

# %%
def dump_parse_table(self, file: str) -> None:
    with open(file, 'w', encoding="utf-8") as handle:
        handle.write('# Grammar rules:\n')
        for rule in self.mRules:
            rule_name = self.mRuleNames[rule] 
            handle.write(f'{rule_name} = ("{rule.mVariable}", {rule.mBody})\n')
        handle.write('\n# Action table:\n')
        handle.write('actionTable = {}\n')
        for s, t in self.mActionTable:
            action = self.mActionTable[s, t]
            t = strip_quotes(t)
            if action[0] == 'reduce':
                rule_name = action[1]
                handle.write(f"actionTable['{s}', '{t}'] = ('reduce', {rule_name})\n")
            elif action == 'accept':
                handle.write(f"actionTable['{s}', '{t}'] = 'accept'\n")
            else:
                handle.write(f"actionTable['{s}', '{t}'] = {action}\n")
        handle.write('\n# Goto table:\n')
        handle.write('gotoTable = {}\n')
        for s, v in self.mGotoTable:
            state = self.mGotoTable[s, v]
            handle.write(f"gotoTable['{s}', '{v}'] = '{state}'\n")
        handle.write('\n# States:\n')
        handle.write('stateNames = {}\n')
        for s in self.mStateNames:
            name = self.mStateNames[s]
            handle.write(f"stateNames['{name}'] = {s}\n")        
            
Grammar.dump_parse_table = dump_parse_table # type: ignore
del dump_parse_table

# %%
g.dump_parse_table('parse-table.py') # type: ignore

# %%
# !cat parse-table.py
# Out:
# # Grammar rules:
# r0 = ("expr", ('expr', "'+'", 'product'))
# r1 = ("expr", ('expr', "'-'", 'product'))
# r2 = ("expr", ('product',))
# r3 = ("product", ('product', "'*'", 'factor'))
# r4 = ("product", ('product', "'/'", 'factor'))
# r5 = ("product", ('factor',))
# r6 = ("factor", ("'('", 'expr', "')'"))
# r7 = ("factor", ('NUMBER',))
# r8 = ("ŝ", ('expr', '$'))
#
# # Action table:
# actionTable = {}
# actionTable['s8', ')'] = ('shift', 's10')
# actionTable['s8', '-'] = ('shift', 's12')
# actionTable['s8', '+'] = ('shift', 's14')
# actionTable['s9', 'NUMBER'] = ('shift', 's4')
# actionTable['s9', '('] = ('shift', 's6')
# actionTable['s1', '-'] = ('shift', 's12')
# actionTable['s1', '+'] = ('shift', 's14')
# actionTable['s1', '$'] = 'accept'
# actionTable['s2', ')'] = ('reduce', r5)
# actionTable['s2', '-'] = ('reduce', r5)
# actionTable['s2', '*'] = ('reduce', r5)
# actionTable['s2', '+'] = ('reduce', r5)
# actionTable['s2', '/'] = ('reduce', r5)
# actionTable['s2', '$'] = ('reduce', r5)
# actionTable['s10', ')'] = ('reduce', r6)
# actionTable['s10', '-'] = ('reduce', r6)
# actionTable['s10', '*'] = ('reduce', r6)
# actionTable['s10', '+'] = ('reduce', r6)
# actionTable['s10', '/'] = ('reduce', r6)
# actionTable['s10', '$'] = ('reduce', r6)
# actionTable['s3', 'NUMBER'] = ('shift', 's4')
# actionTable['s3', '('] = ('shift', 's6')
# actionTable['s11', ')'] = ('reduce', r4)
# actionTable['s11', '-'] = ('reduce', r4)
# actionTable['s11', '*'] = ('reduce', r4)
# actionTable['s11', '+'] = ('reduce', r4)
# actionTable['s11', '/'] = ('reduce', r4)
# actionTable['s11', '$'] = ('reduce', r4)
# actionTable['s7', '*'] = ('shift', 's9')
# actionTable['s7', '/'] = ('shift', 's3')
# actionTable['s7', '-'] = ('reduce', r0)
# actionTable['s7', ')'] = ('reduce', r0)
# actionTable['s7', '$'] = ('reduce', r0)
# actionTable['s7', '+'] = ('reduce', r0)
# actionTable['s12', 'NUMBER'] = ('shift', 's4')
# actionTable['s12', '('] = ('shift', 's6')
# actionTable['s4', ')'] = ('reduce', r7)
# actionTable['s4', '-'] = ('reduce', r7)
# actionTable['s4', '*'] = ('reduce', r7)
# actionTable['s4', '+'] = ('reduce', r7)
# actionTable['s4', '/'] = ('reduce', r7)
# actionTable['s4', '$'] = ('reduce', r7)
# actionTable['s5', '*'] = ('shift', 's9')
# actionTable['s5', '/'] = ('shift', 's3')
# actionTable['s5', '-'] = ('reduce', r2)
# actionTable['s5', ')'] = ('reduce', r2)
# actionTable['s5', '$'] = ('reduce', r2)
# actionTable['s5', '+'] = ('reduce', r2)
# actionTable['s6', 'NUMBER'] = ('shift', 's4')
# actionTable['s6', '('] = ('shift', 's6')
# actionTable['s15', '*'] = ('shift', 's9')
# actionTable['s15', '/'] = ('shift', 's3')
# actionTable['s15', '-'] = ('reduce', r1)
# actionTable['s15', ')'] = ('reduce', r1)
# actionTable['s15', '$'] = ('reduce', r1)
# actionTable['s15', '+'] = ('reduce', r1)
# actionTable['s13', ')'] = ('reduce', r3)
# actionTable['s13', '-'] = ('reduce', r3)
# actionTable['s13', '*'] = ('reduce', r3)
# actionTable['s13', '+'] = ('reduce', r3)
# actionTable['s13', '/'] = ('reduce', r3)
# actionTable['s13', '$'] = ('reduce', r3)
# actionTable['s14', 'NUMBER'] = ('shift', 's4')
# actionTable['s14', '('] = ('shift', 's6')
# actionTable['s0', 'NUMBER'] = ('shift', 's4')
# actionTable['s0', '('] = ('shift', 's6')
#
# # Goto table:
# gotoTable = {}
# gotoTable['s9', 'factor'] = 's13'
# gotoTable['s3', 'factor'] = 's11'
# gotoTable['s12', 'product'] = 's15'
# gotoTable['s12', 'factor'] = 's2'
# gotoTable['s6', 'product'] = 's5'
# gotoTable['s6', 'factor'] = 's2'
# gotoTable['s6', 'expr'] = 's8'
# gotoTable['s14', 'product'] = 's7'
# gotoTable['s14', 'factor'] = 's2'
# gotoTable['s0', 'product'] = 's5'
# gotoTable['s0', 'factor'] = 's2'
# gotoTable['s0', 'expr'] = 's1'
#
# # States:
# stateNames = {}
# stateNames['s0'] = frozenset({product →  • factor, expr →  • product, expr →  • expr '+' product, factor →  • NUMBER, factor →  • '(' expr ')', product →  • product '/' factor, expr →  • expr '-' product, product →  • product '*' factor, ŝ →  • expr $})
# stateNames['s1'] = frozenset({ŝ → expr • $, expr → expr • '+' product, expr → expr • '-' product})
# stateNames['s2'] = frozenset({product → factor • })
# stateNames['s3'] = frozenset({product → product '/' • factor, factor →  • NUMBER, factor →  • '(' expr ')'})
# stateNames['s4'] = frozenset({factor → NUMBER • })
# stateNames['s5'] = frozenset({product → product • '*' factor, expr → product • , product → product • '/' factor})
# stateNames['s6'] = frozenset({product →  • factor, factor → '(' • expr ')', expr →  • product, expr →  • expr '+' product, factor →  • NUMBER, factor →  • '(' expr ')', product →  • product '/' factor, expr →  • expr '-' product, product →  • product '*' factor})
# stateNames['s7'] = frozenset({expr → expr '+' product • , product → product • '*' factor, product → product • '/' factor})
# stateNames['s8'] = frozenset({expr → expr • '+' product, factor → '(' expr • ')', expr → expr • '-' product})
# stateNames['s9'] = frozenset({product → product '*' • factor, factor →  • NUMBER, factor →  • '(' expr ')'})
# stateNames['s10'] = frozenset({factor → '(' expr ')' • })
# stateNames['s11'] = frozenset({product → product '/' factor • })
# stateNames['s12'] = frozenset({factor →  • NUMBER, factor →  • '(' expr ')', product →  • product '/' factor, product →  • factor, product →  • product '*' factor, expr → expr '-' • product})
# stateNames['s13'] = frozenset({product → product '*' factor • })
# stateNames['s14'] = frozenset({factor →  • NUMBER, factor →  • '(' expr ')', product →  • product '/' factor, expr → expr '+' • product, product →  • factor, product →  • product '*' factor})
# stateNames['s15'] = frozenset({product → product • '*' factor, expr → expr '-' product • , product → product • '/' factor})

# %%
def analyse(file):
    rules        = parse(file)
    grammarRules = transform(rules) 
    grammar      = Grammar(grammarRules)
    grammar.dump_parse_table('parse-table.py')

# %%
analyse('Examples/postfix.g')

# %%
analyse('Examples/arith-small.g')

# %%
# %%time
analyse('Examples/arith-ambiguous.g')

# %%
# %%time
analyse('Examples/c-grammar-slr.g')
# Out:
# // This is an SLR grammar for the programming language C.
# // I had to make three changes w.r.t. the original grammar:
# // 1. Casts have been removed.
# // 2. Labels have been removed.
# // 3. if-statements without a matching else-clause have been removed.
#
# translation_unit
# 	: external_declaration
# 	| translation_unit external_declaration
# 	;
#
# primary_expression
# 	: IDENTIFIER
# 	| CONSTANT
# 	| STRING_LITERAL
# 	| '(' expression ')'
# 	;
#
# postfix_expression
# 	: primary_expression
# 	| postfix_expression '[' expression ']'
# 	| postfix_expression '(' ')'
# 	| postfix_expression '(' argument_expression_list ')'
# 	| postfix_expression '.' IDENTIFIER
# 	| postfix_expression '->' IDENTIFIER
# 	| postfix_expression '++'
# 	| postfix_expression '--'
# 	;
#
# argument_expression_list
# 	: assignment_expression
# 	| argument_expression_list ',' assignment_expression
# 	;
#
# unary_expression
# 	: postfix_expression
# 	| '++' unary_expression
# 	| '--' unary_expression
# 	| unary_operator unary_expression
# 	| 'sizeof' unary_expression
# 	| 'sizeof' '(' type_name ')'
# 	;
#
# unary_operator
# 	: '&'
# 	| '*'
# 	| '+'
# 	| '-'
# 	| '~'
# 	| '!'
# 	;
#
# multiplicative_expression
# 	: unary_expression
# 	| multiplicative_expression '*' unary_expression
# 	| multiplicative_expression '/' unary_expression
# 	| multiplicative_expression '%' unary_expression
# 	;
#
# additive_expression
# 	: multiplicative_expression
# 	| additive_expression '+' multiplicative_expression
# 	| additive_expression '-' multiplicative_expression
# 	;
#
# shift_expression
# 	: additive_expression
# 	| shift_expression '<<' additive_expression
# 	| shift_expression '>>' additive_expression
# 	;
#
# relational_expression
# 	: shift_expression
# 	| relational_expression '<' shift_expression
# 	| relational_expression '>' shift_expression
# 	| relational_expression '<=' shift_expression
# 	| relational_expression '>=' shift_expression
# 	;
#
# equality_expression
# 	: relational_expression
# 	| equality_expression '==' relational_expression
# 	| equality_expression '!=' relational_expression
# 	;
#
# and_expression
# 	: equality_expression
# 	| and_expression '&' equality_expression
# 	;
#
# exclusive_or_expression
# 	: and_expression
# 	| exclusive_or_expression '^' and_expression
# 	;
#
# inclusive_or_expression
# 	: exclusive_or_expression
# 	| inclusive_or_expression '|' exclusive_or_expression
# 	;
#
# logical_and_expression
# 	: inclusive_or_expression
# 	| logical_and_expression '&&' inclusive_or_expression
# 	;
#
# logical_or_expression
# 	: logical_and_expression
# 	| logical_or_expression '||' logical_and_expression
# 	;
#
# conditional_expression
# 	: logical_or_expression
# 	| logical_or_expression '?' expression ':' conditional_expression
# 	;
#
# assignment_expression
# 	: conditional_expression
# 	| unary_expression assignment_operator assignment_expression
# 	;
#
# assignment_operator
# 	: '='
# 	| '*='
# 	| '/='
# 	| '%='
# 	| '+='
# 	| '-='
# 	| '<<='
# 	| '>>='
# 	| '&='
# 	| '^='
# 	| '|='
# 	;
#
# expression
# 	: assignment_expression
# 	| expression ',' assignment_expression
# 	;
#
# constant_expression
# 	: conditional_expression
# 	;
#
# declaration
# 	: declaration_specifiers ';'
# 	| declaration_specifiers init_declarator_list ';'
# 	;
#
# declaration_specifiers
# 	: storage_class_specifier
# 	| storage_class_specifier declaration_specifiers
# 	| type_specifier
# 	| type_specifier declaration_specifiers
# 	| type_qualifier
# 	| type_qualifier declaration_specifiers
# 	;
#
# init_declarator_list
# 	: init_declarator
# 	| init_declarator_list ',' init_declarator
# 	;
#
# init_declarator
# 	: declarator
# 	| declarator '=' initializer
# 	;
#
# storage_class_specifier
# 	: 'typedef'
# 	| 'extern'
# 	| 'static'
# 	| 'auto'
# 	| 'register'
# 	;
#
# type_specifier
# 	: 'void'
# 	| 'char'
# 	| 'short'
# 	| 'int'
# 	| 'long'
# 	| 'float'
# 	| 'double'
# 	| 'signed'
# 	| 'unsigned'
# 	| struct_or_union_specifier
# 	| enum_specifier
# 	| TYPE_NAME
# 	;
#
# struct_or_union_specifier
# 	: struct_or_union IDENTIFIER '{' struct_declaration_list '}'
# 	| struct_or_union '{' struct_declaration_list '}'
# 	| struct_or_union IDENTIFIER
# 	;
#
# struct_or_union
# 	: 'struct'
# 	| 'union'
# 	;
#
# struct_declaration_list
# 	: struct_declaration
# 	| struct_declaration_list struct_declaration
# 	;
#
# struct_declaration
# 	: specifier_qualifier_list struct_declarator_list ';'
# 	;
#
# specifier_qualifier_list
# 	: type_specifier specifier_qualifier_list
# 	| type_specifier
# 	| type_qualifier specifier_qualifier_list
# 	| type_qualifier
# 	;
#
# struct_declarator_list
# 	: struct_declarator
# 	| struct_declarator_list ',' struct_declarator
# 	;
#
# struct_declarator
# 	: declarator
# 	| ':' constant_expression
# 	| declarator ':' constant_expression
# 	;
#
# enum_specifier
# 	: 'enum' '{' enumerator_list '}'
# 	| 'enum' IDENTIFIER '{' enumerator_list '}'
# 	| 'enum' IDENTIFIER
# 	;
#
# enumerator_list
# 	: enumerator
# 	| enumerator_list ',' enumerator
# 	;
#
# enumerator
# 	: IDENTIFIER
# 	| IDENTIFIER '=' constant_expression
# 	;
#
# type_qualifier
# 	: 'const'
# 	| 'volatile'
# 	;
#
# declarator
# 	: pointer direct_declarator
# 	| direct_declarator
# 	;
#
# direct_declarator
# 	: IDENTIFIER
# 	| '(' declarator ')'
# 	| direct_declarator '[' constant_expression ']'
# 	| direct_declarator '[' ']'
# 	| direct_declarator '(' parameter_type_list ')'
# 	| direct_declarator '(' identifier_list ')'
# 	| direct_declarator '(' ')'
# 	;
#
# pointer
# 	: '*'
# 	| '*' type_qualifier_list
# 	| '*' pointer
# 	| '*' type_qualifier_list pointer
# 	;
#
# type_qualifier_list
# 	: type_qualifier
# 	| type_qualifier_list type_qualifier
# 	;
#
#
# parameter_type_list
# 	: parameter_list
# 	| parameter_list ',' '...'
# 	;
#
# parameter_list
# 	: parameter_declaration
# 	| parameter_list ',' parameter_declaration
# 	;
#
# parameter_declaration
# 	: declaration_specifiers declarator
# 	| declaration_specifiers abstract_declarator
# 	| declaration_specifiers
# 	;
#
# identifier_list
# 	: IDENTIFIER
# 	| identifier_list ',' IDENTIFIER
# 	;
#
# type_name
# 	: specifier_qualifier_list
# 	| specifier_qualifier_list abstract_declarator
# 	;
#
# abstract_declarator
# 	: pointer
# 	| direct_abstract_declarator
# 	| pointer direct_abstract_declarator
# 	;
#
# direct_abstract_declarator
# 	: '(' abstract_declarator ')'
# 	| '[' ']'
# 	| '[' constant_expression ']'
# 	| direct_abstract_declarator '[' ']'
# 	| direct_abstract_declarator '[' constant_expression ']'
# 	| '(' ')'
# 	| '(' parameter_type_list ')'
# 	| direct_abstract_declarator '(' ')'
# 	| direct_abstract_declarator '(' parameter_type_list ')'
# 	;
#
# initializer
# 	: assignment_expression
# 	| '{' initializer_list '}'
# 	| '{' initializer_list ',' '}'
# 	;
#
# initializer_list
# 	: initializer
# 	| initializer_list ',' initializer
# 	;
#
# statement
# 	: labeled_statement
# 	| compound_statement
# 	| expression_statement
# 	| selection_statement
# 	| iteration_statement
# 	| jump_statement
# 	;
#
# labeled_statement
# 	: 'case' constant_expression ':' statement
# 	| 'default' ':' statement
# 	;
#
# compound_statement
# 	: '{' '}'
# 	| '{' statement_list '}'
# 	| '{' declaration_list '}'
# 	| '{' declaration_list statement_list '}'
# 	;
#
# declaration_list
# 	: declaration
# 	| declaration_list declaration
# 	;
#
# statement_list
# 	: statement
# 	| statement_list statement
# 	;
#
# expression_statement
# 	: ';'
# 	| expression ';'
# 	;
#
# selection_statement
# 	: 'if' '(' expression ')' statement 'else' statement
# 	| 'switch' '(' expression ')' statement
# 	;
#
# iteration_statement
# 	: 'while' '(' expression ')' statement
# 	| 'do' statement 'while' '(' expression ')' ';'
# 	| 'for' '(' expression_statement expression_statement ')' statement
# 	| 'for' '(' expression_statement expression_statement expression ')' statement
# 	;
#
# jump_statement
# 	: 'goto' IDENTIFIER ';'
# 	| 'continue' ';'
# 	| 'break' ';'
# 	| 'return' ';'
# 	| 'return' expression ';'
# 	;
#
# external_declaration
# 	: function_definition
# 	| declaration
# 	;
#
# function_definition
# 	: declaration_specifiers declarator declaration_list compound_statement
# 	| declaration_specifiers declarator compound_statement
# 	| declarator declaration_list compound_statement
# 	| declarator compound_statement
# 	;
#
#
# First sets:
# First(struct_declaration) = {"'unsigned'", "'signed'", "'long'", 'TYPE_NAME', "'float'", "'enum'", "'double'", "'void'", "'short'", "'const'", "'int'", "'union'", "'char'", "'struct'", "'volatile'"}
# First(enumerator_list) = {'IDENTIFIER'}
# First(constant_expression) = {'IDENTIFIER', "'~'", "'--'", "'+'", "'sizeof'", 'CONSTANT', "'('", "'-'", "'*'", "'!'", 'STRING_LITERAL', "'++'", "'&'"}
# First(enum_specifier) = {"'enum'"}
# First(unary_operator) = {"'*'", "'!'", "'~'", "'+'", "'-'", "'&'"}
# First(parameter_declaration) = {"'signed'", "'long'", 'TYPE_NAME', "'float'", "'enum'", "'short'", "'int'", "'char'", "'extern'", "'volatile'", "'unsigned'", "'register'", "'double'", "'void'", "'const'", "'auto'", "'static'", "'union'", "'typedef'", "'struct'"}
# First(logical_or_expression) = {'IDENTIFIER', "'~'", "'--'", "'+'", "'sizeof'", 'CONSTANT', "'('", "'-'", "'*'", "'!'", 'STRING_LITERAL', "'++'", "'&'"}
# First(jump_statement) = {"'return'", "'goto'", "'continue'", "'break'"}
# First(equality_expression) = {'IDENTIFIER', "'~'", "'--'", "'+'", "'sizeof'", 'CONSTANT', "'('", "'-'", "'*'", "'!'", 'STRING_LITERAL', "'++'", "'&'"}
# First(conditional_expression) = {'IDENTIFIER', "'~'", "'--'", "'+'", "'sizeof'", 'CONSTANT', "'('", "'-'", "'*'", "'!'", 'STRING_LITERAL', "'++'", "'&'"}
# First(declaration_list) = {"'signed'", "'long'", 'TYPE_NAME', "'float'", "'enum'", "'short'", "'int'", "'char'", "'extern'", "'volatile'", "'unsigned'", "'register'", "'double'", "'void'", "'const'", "'auto'", "'static'", "'union'", "'typedef'", "'struct'"}
# First(iteration_statement) = {"'while'", "'for'", "'do'"}
# First(parameter_list) = {"'signed'", "'long'", 'TYPE_NAME', "'float'", "'enum'", "'short'", "'int'", "'char'", "'extern'", "'volatile'", "'unsigned'", "'register'", "'double'", "'void'", "'const'", "'auto'", "'static'", "'union'", "'typedef'", "'struct'"}
# First(init_declarator) = {"'*'", 'IDENTIFIER', "'('"}
# First(relational_expression) = {'IDENTIFIER', "'~'", "'--'", "'+'", "'sizeof'", 'CONSTANT', "'('", "'-'", "'*'", "'!'", 'STRING_LITERAL', "'++'", "'&'"}
# First(type_specifier) = {"'int'", "'unsigned'", "'signed'", "'union'", "'long'", "'char'", 'TYPE_NAME', "'float'", "'enum'", "'double'", "'void'", "'short'", "'struct'"}
# First(initializer) = {'IDENTIFIER', "'~'", "'--'", "'{'", "'sizeof'", "'+'", 'CONSTANT', "'('", "'-'", "'*'", "'!'", 'STRING_LITERAL', "'++'", "'&'"}
# First(struct_or_union) = {"'union'", "'struct'"}
# First(selection_statement) = {"'if'", "'switch'"}
# First(type_qualifier_list) = {"'volatile'", "'const'"}
# First(unary_expression) = {'IDENTIFIER', 'CONSTANT', "'~'", "'('", "'--'", "'-'", "'*'", "'!'", "'+'", "'sizeof'", 'STRING_LITERAL', "'++'", "'&'"}
# First(inclusive_or_expression) = {'IDENTIFIER', "'~'", "'--'", "'+'", "'sizeof'", 'CONSTANT', "'('", "'-'", "'*'", "'!'", 'STRING_LITERAL', "'++'", "'&'"}
# First(statement) = {'IDENTIFIER', "'switch'", "'~'", "'--'", "'if'", "'continue'", "'{'", "'sizeof'", "'+'", "'case'", "'goto'", 'CONSTANT', "'while'", "'return'", "'break'", "';'", "'('", "'-'", "'*'", "'&'", "'default'", "'!'", "'for'", 'STRING_LITERAL', "'++'", "'do'"}
# First(logical_and_expression) = {'IDENTIFIER', "'~'", "'--'", "'+'", "'sizeof'", 'CONSTANT', "'('", "'-'", "'*'", "'!'", 'STRING_LITERAL', "'++'", "'&'"}
# First(type_name) = {"'unsigned'", "'signed'", "'long'", 'TYPE_NAME', "'float'", "'enum'", "'double'", "'void'", "'short'", "'const'", "'int'", "'union'", "'char'", "'struct'", "'volatile'"}
# First(enumerator) = {'IDENTIFIER'}
# First(init_declarator_list) = {"'*'", 'IDENTIFIER', "'('"}
# First(abstract_declarator) = {"'*'", "'('", "'['"}
# First(parameter_type_list) = {"'signed'", "'long'", 'TYPE_NAME', "'float'", "'enum'", "'short'", "'int'", "'char'", "'extern'", "'volatile'", "'unsigned'", "'register'", "'double'", "'void'", "'const'", "'auto'", "'static'", "'union'", "'typedef'", "'struct'"}
# First(statement_list) = {"'~'", "'--'", "'continue'", "'{'", "'sizeof'", "'return'", "'break'", "';'", "'*'", "'default'", "'!'", "'for'", "'++'", "'&'", 'IDENTIFIER', "'switch'", "'if'", "'+'", "'case'", "'goto'", 'CONSTANT', "'while'", "'('", "'-'", 'STRING_LITERAL', "'do'"}
# First(assignment_operator) = {"'^='", "'+='", "'|='", "'*='", "'<<='", "'&='", "'-='", "'>>='", "'%='", "'='", "'/='"}
# First(direct_abstract_declarator) = {"'('", "'['"}
# First(assignment_expression) = {'IDENTIFIER', "'~'", "'--'", "'+'", "'sizeof'", 'CONSTANT', "'('", "'-'", "'*'", "'!'", 'STRING_LITERAL', "'++'", "'&'"}
# First(multiplicative_expression) = {'IDENTIFIER', "'~'", "'--'", "'+'", "'sizeof'", 'CONSTANT', "'('", "'-'", "'*'", "'!'", 'STRING_LITERAL', "'++'", "'&'"}
# First(argument_expression_list) = {'IDENTIFIER', "'~'", "'--'", "'+'", "'sizeof'", 'CONSTANT', "'('", "'-'", "'*'", "'!'", 'STRING_LITERAL', "'++'", "'&'"}
# First(initializer_list) = {'IDENTIFIER', "'~'", "'--'", "'{'", "'sizeof'", "'+'", 'CONSTANT', "'('", "'-'", "'*'", "'!'", 'STRING_LITERAL', "'++'", "'&'"}
# First(labeled_statement) = {"'default'", "'case'"}
# First(additive_expression) = {'IDENTIFIER', "'~'", "'--'", "'+'", "'sizeof'", 'CONSTANT', "'('", "'-'", "'*'", "'!'", 'STRING_LITERAL', "'++'", "'&'"}
# First(declaration) = {"'signed'", "'long'", 'TYPE_NAME', "'float'", "'enum'", "'short'", "'int'", "'char'", "'extern'", "'volatile'", "'unsigned'", "'register'", "'double'", "'void'", "'const'", "'auto'", "'static'", "'union'", "'typedef'", "'struct'"}
# First(struct_declaration_list) = {"'unsigned'", "'signed'", "'long'", 'TYPE_NAME', "'float'", "'enum'", "'double'", "'void'", "'short'", "'const'", "'int'", "'union'", "'char'", "'struct'", "'volatile'"}
# First(external_declaration) = {"'signed'", "'long'", 'TYPE_NAME', "'float'", "'enum'", "'short'", "'int'", "'char'", "'*'", "'extern'", "'volatile'", 'IDENTIFIER', "'unsigned'", "'register'", "'double'", "'void'", "'const'", "'auto'", "'('", "'static'", "'union'", "'typedef'", "'struct'"}
# First(shift_expression) = {'IDENTIFIER', "'~'", "'--'", "'+'", "'sizeof'", 'CONSTANT', "'('", "'-'", "'*'", "'!'", 'STRING_LITERAL', "'++'", "'&'"}
# First(declaration_specifiers) = {"'unsigned'", "'register'", "'signed'", "'long'", 'TYPE_NAME', "'float'", "'enum'", "'double'", "'void'", "'short'", "'const'", "'int'", "'auto'", "'static'", "'union'", "'char'", "'typedef'", "'struct'", "'extern'", "'volatile'"}
# First(storage_class_specifier) = {"'typedef'", "'auto'", "'static'", "'register'", "'extern'"}
# First(specifier_qualifier_list) = {"'unsigned'", "'signed'", "'long'", 'TYPE_NAME', "'float'", "'enum'", "'double'", "'void'", "'short'", "'const'", "'int'", "'union'", "'char'", "'struct'", "'volatile'"}
# First(expression_statement) = {'IDENTIFIER', "'~'", "'--'", "'+'", "'sizeof'", 'CONSTANT', "';'", "'('", "'-'", "'*'", "'!'", 'STRING_LITERAL', "'++'", "'&'"}
# First(function_definition) = {"'signed'", "'long'", 'TYPE_NAME', "'float'", "'enum'", "'short'", "'int'", "'char'", "'*'", "'extern'", "'volatile'", 'IDENTIFIER', "'unsigned'", "'register'", "'double'", "'void'", "'const'", "'auto'", "'('", "'static'", "'union'", "'typedef'", "'struct'"}
# First(compound_statement) = {"'{'"}
# First(translation_unit) = {"'signed'", "'long'", 'TYPE_NAME', "'float'", "'enum'", "'short'", "'int'", "'char'", "'*'", "'extern'", "'volatile'", 'IDENTIFIER', "'unsigned'", "'register'", "'double'", "'void'", "'const'", "'auto'", "'('", "'static'", "'union'", "'typedef'", "'struct'"}
# First(declarator) = {"'*'", 'IDENTIFIER', "'('"}
# First(ŝ) = {"'signed'", "'long'", 'TYPE_NAME', "'float'", "'enum'", "'short'", "'int'", "'char'", "'*'", "'extern'", "'volatile'", 'IDENTIFIER', "'unsigned'", "'register'", "'double'", "'void'", "'const'", "'auto'", "'('", "'static'", "'union'", "'typedef'", "'struct'"}
# First(expression) = {'IDENTIFIER', "'~'", "'--'", "'+'", "'sizeof'", 'CONSTANT', "'('", "'-'", "'*'", "'!'", 'STRING_LITERAL', "'++'", "'&'"}
# First(primary_expression) = {"'('", 'IDENTIFIER', 'STRING_LITERAL', 'CONSTANT'}
# First(struct_declarator_list) = {"'*'", 'IDENTIFIER', "':'", "'('"}
# First(direct_declarator) = {"'('", 'IDENTIFIER'}
# First(identifier_list) = {'IDENTIFIER'}
# First(and_expression) = {'IDENTIFIER', "'~'", "'--'", "'+'", "'sizeof'", 'CONSTANT', "'('", "'-'", "'*'", "'!'", 'STRING_LITERAL', "'++'", "'&'"}
# First(exclusive_or_expression) = {'IDENTIFIER', "'~'", "'--'", "'+'", "'sizeof'", 'CONSTANT', "'('", "'-'", "'*'", "'!'", 'STRING_LITERAL', "'++'", "'&'"}
# First(postfix_expression) = {"'('", 'IDENTIFIER', 'STRING_LITERAL', 'CONSTANT'}
# First(struct_or_union_specifier) = {"'union'", "'struct'"}
# First(struct_declarator) = {"'*'", 'IDENTIFIER', "'('", "':'"}
# First(type_qualifier) = {"'volatile'", "'const'"}
# First(pointer) = {"'*'"}
# Follow sets (note that "$" denotes the end of file):
# Follow(struct_declaration) = {"'unsigned'", "'signed'", "'long'", 'TYPE_NAME', "'float'", "'enum'", "'double'", "'void'", "'short'", "'const'", "'int'", "'union'", "'char'", "'}'", "'struct'", "'volatile'"}
# Follow(enumerator_list) = {"'}'", "','"}
# Follow(constant_expression) = {"'}'", "']'", "':'", "';'", "','"}
# Follow(enum_specifier) = {"'signed'", "'long'", 'TYPE_NAME', "'float'", "'enum'", "'short'", "')'", "'int'", "';'", "','", "'char'", "'*'", "'extern'", "'volatile'", 'IDENTIFIER', "'unsigned'", "'register'", "'['", "'double'", "'void'", "'const'", "'('", "'auto'", "'static'", "'union'", "'typedef'", "':'", "'struct'"}
# Follow(unary_operator) = {'IDENTIFIER', 'CONSTANT', "'~'", "'('", "'--'", "'-'", "'*'", "'!'", "'+'", "'sizeof'", 'STRING_LITERAL', "'++'", "'&'"}
# Follow(parameter_declaration) = {"')'", "','"}
# Follow(logical_or_expression) = {"')'", "'||'", "']'", "';'", "','", "'?'", "'}'", "':'"}
# Follow(jump_statement) = {'IDENTIFIER', "'switch'", "'~'", "'--'", "'if'", "'continue'", "'{'", "'sizeof'", "'+'", "'else'", "'case'", "'goto'", 'CONSTANT', "'while'", "'return'", "'break'", "';'", "'('", "'-'", "'}'", "'*'", "'default'", "'!'", "'for'", "'&'", 'STRING_LITERAL', "'++'", "'do'"}
# Follow(equality_expression) = {"'||'", "']'", "'!='", "'|'", "'=='", "')'", "';'", "','", "'?'", "'}'", "'^'", "'&&'", "':'", "'&'"}
# Follow(conditional_expression) = {"')'", "']'", "';'", "','", "'}'", "':'"}
# Follow(declaration_list) = {"'~'", "'--'", "'continue'", "'signed'", "'long'", 'TYPE_NAME', "'float'", "'{'", "'sizeof'", "'enum'", "'short'", "'return'", "'break'", "'int'", "';'", "'char'", "'*'", "'default'", "'!'", "'for'", "'++'", "'extern'", "'&'", "'volatile'", 'IDENTIFIER', "'switch'", "'unsigned'", "'if'", "'register'", "'+'", "'double'", "'case'", "'goto'", "'void'", "'const'", 'CONSTANT', "'while'", "'('", "'-'", "'auto'", "'static'", "'union'", "'}'", "'typedef'", 'STRING_LITERAL', "'do'", "'struct'"}
# Follow(iteration_statement) = {'IDENTIFIER', "'switch'", "'~'", "'--'", "'if'", "'continue'", "'{'", "'sizeof'", "'+'", "'else'", "'case'", "'goto'", 'CONSTANT', "'while'", "'return'", "'break'", "';'", "'('", "'-'", "'}'", "'*'", "'default'", "'!'", "'for'", "'&'", 'STRING_LITERAL', "'++'", "'do'"}
# Follow(parameter_list) = {"')'", "','"}
# Follow(init_declarator) = {"','", "';'"}
# Follow(relational_expression) = {"'||'", "']'", "'>'", "'<='", "'!='", "'|'", "'<'", "'=='", "')'", "';'", "','", "'?'", "'}'", "'^'", "'&&'", "':'", "'>='", "'&'"}
# Follow(type_specifier) = {'IDENTIFIER', "'unsigned'", "'volatile'", "'register'", "'signed'", "'long'", 'TYPE_NAME', "'float'", "'enum'", "'['", "'double'", "'void'", "'short'", "'const'", "')'", "'int'", "';'", "'('", "'auto'", "'static'", "'union'", "','", "'char'", "'*'", "'typedef'", "':'", "'extern'", "'struct'"}
# Follow(initializer) = {"'}'", "','", "';'"}
# Follow(struct_or_union) = {'IDENTIFIER', "'{'"}
# Follow(selection_statement) = {'IDENTIFIER', "'switch'", "'~'", "'--'", "'if'", "'continue'", "'{'", "'sizeof'", "'+'", "'else'", "'case'", "'goto'", 'CONSTANT', "'while'", "'return'", "'break'", "';'", "'('", "'-'", "'}'", "'*'", "'default'", "'!'", "'for'", "'&'", 'STRING_LITERAL', "'++'", "'do'"}
# Follow(type_qualifier_list) = {'IDENTIFIER', "')'", "'('", "'volatile'", "','", "'*'", "'['", "'const'"}
# Follow(unary_expression) = {"'||'", "']'", "'>'", "'<<='", "'|'", "'*='", "')'", "'^='", "'%'", "'|='", "';'", "','", "'?'", "'*'", "'<<'", "'&&'", "'-='", "'&'", "'+='", "'<='", "'&='", "'!='", "'<'", "'+'", "'=='", "'='", "'>>'", "'-'", "'}'", "'>>='", "'^'", "'%='", "':'", "'/'", "'>='", "'/='"}
# Follow(inclusive_or_expression) = {"')'", "'||'", "']'", "';'", "','", "'?'", "'}'", "'|'", "'&&'", "':'"}
# Follow(statement) = {'IDENTIFIER', "'switch'", "'~'", "'--'", "'if'", "'continue'", "'{'", "'sizeof'", "'+'", "'else'", "'case'", "'goto'", 'CONSTANT', "'while'", "'return'", "'break'", "';'", "'('", "'-'", "'}'", "'*'", "'default'", "'!'", "'for'", "'&'", 'STRING_LITERAL', "'++'", "'do'"}
# Follow(logical_and_expression) = {"')'", "'||'", "']'", "';'", "','", "'?'", "'}'", "'&&'", "':'"}
# Follow(type_name) = {"')'"}
# Follow(enumerator) = {"'}'", "','"}
# Follow(init_declarator_list) = {"','", "';'"}
# Follow(abstract_declarator) = {"')'", "','"}
# Follow(parameter_type_list) = {"')'"}
# Follow(statement_list) = {'IDENTIFIER', "'switch'", "'~'", "'--'", "'do'", "'if'", "'continue'", "'{'", "'sizeof'", "'+'", "'case'", "'goto'", 'CONSTANT', "'while'", "'return'", "'break'", "';'", "'('", "'-'", "'}'", "'*'", "'default'", "'!'", "'for'", 'STRING_LITERAL', "'++'", "'&'"}
# Follow(assignment_operator) = {'IDENTIFIER', 'CONSTANT', "'~'", "'--'", "'('", "'-'", "'*'", "'!'", "'+'", "'sizeof'", 'STRING_LITERAL', "'++'", "'&'"}
# Follow(direct_abstract_declarator) = {"'('", "')'", "'['", "','"}
# Follow(assignment_expression) = {"'}'", "')'", "']'", "':'", "';'", "','"}
# Follow(multiplicative_expression) = {"'||'", "']'", "'>'", "'|'", "')'", "'%'", "';'", "','", "'?'", "'*'", "'<<'", "'&&'", "'&'", "'<='", "'!='", "'<'", "'+'", "'=='", "'>>'", "'-'", "'}'", "'^'", "':'", "'/'", "'>='"}
# Follow(argument_expression_list) = {"')'", "','"}
# Follow(initializer_list) = {"'}'", "','"}
# Follow(labeled_statement) = {'IDENTIFIER', "'switch'", "'~'", "'--'", "'if'", "'continue'", "'{'", "'sizeof'", "'+'", "'else'", "'case'", "'goto'", 'CONSTANT', "'while'", "'return'", "'break'", "';'", "'('", "'-'", "'}'", "'*'", "'default'", "'!'", "'for'", "'&'", 'STRING_LITERAL', "'++'", "'do'"}
# Follow(additive_expression) = {"'||'", "']'", "'>'", "'|'", "')'", "';'", "','", "'?'", "'<<'", "'&&'", "'&'", "'<='", "'!='", "'<'", "'+'", "'=='", "'>>'", "'-'", "'}'", "'^'", "':'", "'>='"}
# Follow(declaration) = {"'~'", "'signed'", "'long'", 'TYPE_NAME', "'enum'", "'int'", "'default'", "'for'", "'++'", "'&'", 'IDENTIFIER', "'unsigned'", "'register'", "'+'", "'void'", '$', "'const'", "'while'", "'('", "'-'", "'union'", "'do'", "'struct'", "'--'", "'continue'", "'float'", "'{'", "'sizeof'", "'short'", "'return'", "'break'", "';'", "'char'", "'*'", "'!'", "'extern'", "'volatile'", "'switch'", "'if'", "'double'", "'case'", "'goto'", 'CONSTANT', "'auto'", "'static'", "'}'", "'typedef'", 'STRING_LITERAL'}
# Follow(struct_declaration_list) = {"'unsigned'", "'volatile'", "'signed'", "'long'", 'TYPE_NAME', "'float'", "'enum'", "'double'", "'void'", "'short'", "'const'", "'int'", "'union'", "'char'", "'}'", "'struct'"}
# Follow(external_declaration) = {'IDENTIFIER', "'unsigned'", "'volatile'", "'signed'", "'register'", "'long'", 'TYPE_NAME', "'float'", "'enum'", "'double'", "'void'", "'short'", '$', "'const'", "'int'", "'auto'", "'('", "'static'", "'union'", "'char'", "'*'", "'typedef'", "'extern'", "'struct'"}
# Follow(shift_expression) = {"'||'", "']'", "'>'", "'<='", "'!='", "'|'", "'<'", "'=='", "'>>'", "')'", "';'", "','", "'?'", "'}'", "'<<'", "'^'", "'&&'", "':'", "'>='", "'&'"}
# Follow(declaration_specifiers) = {"'*'", 'IDENTIFIER', "')'", "'['", "';'", "'('", "','"}
# Follow(storage_class_specifier) = {'IDENTIFIER', "'unsigned'", "'volatile'", "'register'", "'signed'", "'long'", 'TYPE_NAME', "'float'", "'enum'", "'['", "'double'", "'void'", "'short'", "'const'", "')'", "'int'", "';'", "'('", "'auto'", "'static'", "'union'", "','", "'char'", "'*'", "'typedef'", "'extern'", "'struct'"}
# Follow(specifier_qualifier_list) = {"'*'", 'IDENTIFIER', "')'", "':'", "'['", "'('"}
# Follow(expression_statement) = {"'~'", "'--'", "'continue'", "'{'", "'sizeof'", "'else'", "')'", "'return'", "'break'", "';'", "'*'", "'default'", "'!'", "'for'", "'++'", "'&'", 'IDENTIFIER', "'switch'", "'if'", "'+'", "'case'", "'goto'", 'CONSTANT', "'while'", "'('", "'-'", "'}'", 'STRING_LITERAL', "'do'"}
# Follow(function_definition) = {'IDENTIFIER', "'unsigned'", "'volatile'", "'signed'", "'register'", "'long'", 'TYPE_NAME', "'float'", "'enum'", "'double'", "'void'", "'short'", '$', "'const'", "'int'", "'auto'", "'('", "'static'", "'union'", "'char'", "'*'", "'typedef'", "'extern'", "'struct'"}
# Follow(compound_statement) = {"'~'", "'--'", "'signed'", "'continue'", "'long'", 'TYPE_NAME', "'float'", "'enum'", "'{'", "'sizeof'", "'else'", "'short'", "'return'", "'break'", "'int'", "';'", "'char'", "'*'", "'default'", "'!'", "'for'", "'++'", "'extern'", "'&'", "'volatile'", 'IDENTIFIER', "'switch'", "'unsigned'", "'register'", "'if'", "'+'", "'double'", "'void'", "'case'", '$', "'goto'", "'const'", 'CONSTANT', "'while'", "'auto'", "'('", "'static'", "'union'", "'-'", "'}'", "'typedef'", 'STRING_LITERAL', "'do'", "'struct'"}
# Follow(translation_unit) = {'IDENTIFIER', "'unsigned'", "'signed'", "'register'", "'long'", 'TYPE_NAME', "'float'", "'enum'", "'double'", "'void'", "'short'", '$', "'const'", "'int'", "'auto'", "'('", "'static'", "'union'", "'char'", "'*'", "'typedef'", "'struct'", "'extern'", "'volatile'"}
# Follow(declarator) = {"'unsigned'", "'signed'", "'register'", "'long'", 'TYPE_NAME', "'float'", "'enum'", "'{'", "'double'", "'void'", "'='", "'short'", "'const'", "')'", "'int'", "';'", "'auto'", "','", "'static'", "'union'", "'char'", "'typedef'", "':'", "'struct'", "'extern'", "'volatile'"}
# Follow(ŝ) = set()
# Follow(expression) = {"')'", "']'", "':'", "';'", "','"}
# Follow(primary_expression) = {"'||'", "']'", "'<<='", "','", "'?'", "'<<'", "'&&'", "'-='", "'++'", "'&'", "'+='", "'<='", "'&='", "'!='", "'<'", "'['", "'+'", "'>>'", "'('", "'-'", "'>>='", "'^'", "'%='", "'->'", "'--'", "'>'", "'|'", "'*='", "')'", "'^='", "'%'", "'|='", "';'", "'*'", "'.'", "'=='", "'='", "'}'", "':'", "'/'", "'>='", "'/='"}
# Follow(struct_declarator_list) = {"','", "';'"}
# Follow(direct_declarator) = {"'signed'", "'long'", 'TYPE_NAME', "'float'", "'enum'", "'{'", "'short'", "')'", "'int'", "';'", "','", "'char'", "'extern'", "'volatile'", "'unsigned'", "'register'", "'['", "'double'", "'void'", "'='", "'const'", "'('", "'auto'", "'static'", "'union'", "'typedef'", "':'", "'struct'"}
# Follow(identifier_list) = {"')'", "','"}
# Follow(and_expression) = {"'||'", "']'", "'|'", "')'", "';'", "','", "'?'", "'}'", "'^'", "'&&'", "':'", "'&'"}
# Follow(exclusive_or_expression) = {"')'", "'||'", "']'", "';'", "','", "'?'", "'}'", "'|'", "'&&'", "'^'", "':'"}
# Follow(postfix_expression) = {"'||'", "']'", "'->'", "'--'", "'>'", "'<<='", "'|'", "'*='", "')'", "'^='", "'%'", "'|='", "';'", "','", "'?'", "'*'", "'<<'", "'&&'", "'-='", "'.'", "'++'", "'&'", "'+='", "'<='", "'&='", "'!='", "'<'", "'['", "'+'", "'=='", "'='", "'>>'", "'('", "'-'", "'}'", "'>>='", "'^'", "'%='", "':'", "'/'", "'>='", "'/='"}
# Follow(struct_or_union_specifier) = {"'signed'", "'long'", 'TYPE_NAME', "'float'", "'enum'", "'short'", "')'", "'int'", "';'", "','", "'char'", "'*'", "'extern'", "'volatile'", 'IDENTIFIER', "'unsigned'", "'register'", "'['", "'double'", "'void'", "'const'", "'('", "'auto'", "'static'", "'union'", "'typedef'", "':'", "'struct'"}
# Follow(struct_declarator) = {"','", "';'"}
# Follow(type_qualifier) = {'IDENTIFIER', "'unsigned'", "'volatile'", "'register'", "'signed'", "'long'", 'TYPE_NAME', "'float'", "'enum'", "'['", "'double'", "'void'", "'short'", "'const'", "')'", "'int'", "';'", "'('", "'auto'", "'static'", "'union'", "','", "'char'", "'*'", "'typedef'", "':'", "'extern'", "'struct'"}
# Follow(pointer) = {'IDENTIFIER', "')'", "'['", "'('", "','"}
# All SLR-states:
# s0 = {type_specifier →  • 'float', declarator →  • direct_declarator, declaration_specifiers →  • type_specifier declaration_specifiers, translation_unit →  • external_declaration, storage_class_specifier →  • 'typedef', type_specifier →  • 'int', type_specifier →  • 'char', pointer →  • '*' pointer, struct_or_union →  • 'struct', struct_or_union_specifier →  • struct_or_union IDENTIFIER, pointer →  • '*' type_qualifier_list, storage_class_specifier →  • 'register', type_specifier →  • 'long', direct_declarator →  • direct_declarator '(' identifier_list ')', enum_specifier →  • 'enum' IDENTIFIER '{' enumerator_list '}', struct_or_union_specifier →  • struct_or_union IDENTIFIER '{' struct_declaration_list '}', external_declaration →  • declaration, type_specifier →  • 'short', ŝ →  • translation_unit $, declarator →  • pointer direct_declarator, type_specifier →  • 'void', declaration_specifiers →  • storage_class_specifier declaration_specifiers, struct_or_union_specifier →  • struct_or_union '{' struct_declaration_list '}', storage_class_specifier →  • 'static', function_definition →  • declarator compound_statement, storage_class_specifier →  • 'extern', function_definition →  • declaration_specifiers declarator declaration_list compound_statement, enum_specifier →  • 'enum' IDENTIFIER, type_specifier →  • 'signed', function_definition →  • declaration_specifiers declarator compound_statement, declaration_specifiers →  • type_specifier, storage_class_specifier →  • 'auto', direct_declarator →  • direct_declarator '(' parameter_type_list ')', enum_specifier →  • 'enum' '{' enumerator_list '}', declaration_specifiers →  • type_qualifier, type_specifier →  • TYPE_NAME, pointer →  • '*', direct_declarator →  • direct_declarator '(' ')', struct_or_union →  • 'union', type_qualifier →  • 'const', declaration →  • declaration_specifiers ';', declaration_specifiers →  • type_qualifier declaration_specifiers, function_definition →  • declarator declaration_list compound_statement, declaration →  • declaration_specifiers init_declarator_list ';', translation_unit →  • translation_unit external_declaration, declaration_specifiers →  • storage_class_specifier, direct_declarator →  • IDENTIFIER, type_specifier →  • 'unsigned', type_specifier →  • struct_or_union_specifier, type_specifier →  • enum_specifier, pointer →  • '*' type_qualifier_list pointer, type_specifier →  • 'double', direct_declarator →  • direct_declarator '[' ']', direct_declarator →  • direct_declarator '[' constant_expression ']', direct_declarator →  • '(' declarator ')', type_qualifier →  • 'volatile', external_declaration →  • function_definition}
# s1 = {enumerator_list → enumerator • }
# s2 = {initializer → '{' initializer_list • ',' '}', initializer → '{' initializer_list • '}', initializer_list → initializer_list • ',' initializer}
# s3 = {selection_statement → 'if' '(' expression ')' statement 'else' statement • }
# s4 = {unary_operator →  • '!', inclusive_or_expression →  • exclusive_or_expression, equality_expression →  • equality_expression '==' relational_expression, unary_expression →  • 'sizeof' '(' type_name ')', shift_expression →  • shift_expression '<<' additive_expression, unary_expression →  • '++' unary_expression, primary_expression →  • STRING_LITERAL, relational_expression →  • shift_expression, multiplicative_expression →  • multiplicative_expression '*' unary_expression, primary_expression →  • IDENTIFIER, unary_expression →  • 'sizeof' unary_expression, unary_expression →  • unary_operator unary_expression, multiplicative_expression →  • multiplicative_expression '%' unary_expression, unary_operator →  • '&', postfix_expression →  • postfix_expression '--', postfix_expression →  • postfix_expression '->' IDENTIFIER, shift_expression →  • additive_expression, additive_expression →  • multiplicative_expression, equality_expression →  • equality_expression '!=' relational_expression, and_expression →  • equality_expression, and_expression →  • and_expression '&' equality_expression, unary_operator →  • '*', additive_expression →  • additive_expression '+' multiplicative_expression, unary_operator →  • '+', inclusive_or_expression →  • inclusive_or_expression '|' exclusive_or_expression, postfix_expression →  • postfix_expression '(' argument_expression_list ')', postfix_expression →  • postfix_expression '(' ')', equality_expression →  • relational_expression, postfix_expression →  • postfix_expression '.' IDENTIFIER, primary_expression →  • '(' expression ')', exclusive_or_expression →  • and_expression, postfix_expression →  • primary_expression, logical_and_expression → logical_and_expression '&&' • inclusive_or_expression, postfix_expression →  • postfix_expression '++', unary_operator →  • '-', unary_operator →  • '~', multiplicative_expression →  • multiplicative_expression '/' unary_expression, shift_expression →  • shift_expression '>>' additive_expression, exclusive_or_expression →  • exclusive_or_expression '^' and_expression, additive_expression →  • additive_expression '-' multiplicative_expression, unary_expression →  • postfix_expression, postfix_expression →  • postfix_expression '[' expression ']', primary_expression →  • CONSTANT, relational_expression →  • relational_expression '<' shift_expression, multiplicative_expression →  • unary_expression, unary_expression →  • '--' unary_expression, relational_expression →  • relational_expression '<=' shift_expression, relational_expression →  • relational_expression '>' shift_expression, relational_expression →  • relational_expression '>=' shift_expression}
# s5 = {equality_expression → equality_expression • '==' relational_expression, and_expression → equality_expression • , equality_expression → equality_expression • '!=' relational_expression}
# s6 = {unary_operator →  • '!', inclusive_or_expression →  • exclusive_or_expression, equality_expression →  • equality_expression '==' relational_expression, unary_expression →  • 'sizeof' '(' type_name ')', shift_expression →  • shift_expression '<<' additive_expression, unary_expression →  • '++' unary_expression, primary_expression →  • STRING_LITERAL, relational_expression →  • shift_expression, multiplicative_expression →  • multiplicative_expression '*' unary_expression, primary_expression →  • IDENTIFIER, unary_expression →  • 'sizeof' unary_expression, unary_expression →  • unary_operator unary_expression, logical_and_expression →  • logical_and_expression '&&' inclusive_or_expression, logical_and_expression →  • inclusive_or_expression, multiplicative_expression →  • multiplicative_expression '%' unary_expression, unary_operator →  • '&', logical_or_expression →  • logical_or_expression '||' logical_and_expression, postfix_expression →  • postfix_expression '--', conditional_expression →  • logical_or_expression '?' expression ':' conditional_expression, shift_expression →  • additive_expression, additive_expression →  • multiplicative_expression, postfix_expression →  • postfix_expression '->' IDENTIFIER, equality_expression →  • equality_expression '!=' relational_expression, and_expression →  • equality_expression, and_expression →  • and_expression '&' equality_expression, unary_operator →  • '*', additive_expression →  • additive_expression '+' multiplicative_expression, conditional_expression →  • logical_or_expression, unary_operator →  • '+', inclusive_or_expression →  • inclusive_or_expression '|' exclusive_or_expression, postfix_expression →  • postfix_expression '(' argument_expression_list ')', postfix_expression →  • postfix_expression '(' ')', equality_expression →  • relational_expression, postfix_expression →  • postfix_expression '.' IDENTIFIER, primary_expression →  • '(' expression ')', exclusive_or_expression →  • and_expression, postfix_expression →  • primary_expression, postfix_expression →  • postfix_expression '++', unary_operator →  • '-', unary_operator →  • '~', logical_or_expression →  • logical_and_expression, multiplicative_expression →  • multiplicative_expression '/' unary_expression, shift_expression →  • shift_expression '>>' additive_expression, exclusive_or_expression →  • exclusive_or_expression '^' and_expression, additive_expression →  • additive_expression '-' multiplicative_expression, unary_expression →  • postfix_expression, constant_expression →  • conditional_expression, postfix_expression →  • postfix_expression '[' expression ']', primary_expression →  • CONSTANT, relational_expression →  • relational_expression '<' shift_expression, multiplicative_expression →  • unary_expression, unary_expression →  • '--' unary_expression, relational_expression →  • relational_expression '<=' shift_expression, enumerator → IDENTIFIER '=' • constant_expression, relational_expression →  • relational_expression '>' shift_expression, relational_expression →  • relational_expression '>=' shift_expression}
# s7 = {jump_statement →  • 'break' ';', inclusive_or_expression →  • exclusive_or_expression, unary_expression →  • '++' unary_expression, statement →  • selection_statement, labeled_statement →  • 'default' ':' statement, logical_and_expression →  • inclusive_or_expression, postfix_expression →  • postfix_expression '--', conditional_expression →  • logical_or_expression '?' expression ':' conditional_expression, shift_expression →  • additive_expression, additive_expression →  • multiplicative_expression, expression_statement →  • ';', conditional_expression →  • logical_or_expression, unary_operator →  • '+', inclusive_or_expression →  • inclusive_or_expression '|' exclusive_or_expression, labeled_statement → 'case' constant_expression ':' • statement, statement →  • compound_statement, postfix_expression →  • postfix_expression '.' IDENTIFIER, iteration_statement →  • 'for' '(' expression_statement expression_statement expression ')' statement, selection_statement →  • 'switch' '(' expression ')' statement, equality_expression →  • relational_expression, jump_statement →  • 'return' ';', postfix_expression →  • primary_expression, statement →  • expression_statement, unary_operator →  • '-', expression →  • assignment_expression, logical_or_expression →  • logical_and_expression, jump_statement →  • 'return' expression ';', exclusive_or_expression →  • exclusive_or_expression '^' and_expression, postfix_expression →  • postfix_expression '[' expression ']', compound_statement →  • '{' '}', primary_expression →  • CONSTANT, jump_statement →  • 'continue' ';', relational_expression →  • relational_expression '<' shift_expression, iteration_statement →  • 'do' statement 'while' '(' expression ')' ';', iteration_statement →  • 'while' '(' expression ')' statement, expression_statement →  • expression ';', assignment_expression →  • conditional_expression, unary_operator →  • '!', equality_expression →  • equality_expression '==' relational_expression, unary_expression →  • 'sizeof' '(' type_name ')', shift_expression →  • shift_expression '<<' additive_expression, statement →  • iteration_statement, compound_statement →  • '{' declaration_list '}', primary_expression →  • STRING_LITERAL, relational_expression →  • shift_expression, primary_expression →  • IDENTIFIER, multiplicative_expression →  • multiplicative_expression '*' unary_expression, unary_expression →  • 'sizeof' unary_expression, unary_expression →  • unary_operator unary_expression, logical_and_expression →  • logical_and_expression '&&' inclusive_or_expression, unary_operator →  • '&', multiplicative_expression →  • multiplicative_expression '%' unary_expression, logical_or_expression →  • logical_or_expression '||' logical_and_expression, compound_statement →  • '{' declaration_list statement_list '}', postfix_expression →  • postfix_expression '->' IDENTIFIER, equality_expression →  • equality_expression '!=' relational_expression, unary_operator →  • '*', and_expression →  • equality_expression, and_expression →  • and_expression '&' equality_expression, selection_statement →  • 'if' '(' expression ')' statement 'else' statement, additive_expression →  • additive_expression '+' multiplicative_expression, postfix_expression →  • postfix_expression '(' argument_expression_list ')', compound_statement →  • '{' statement_list '}', statement →  • jump_statement, postfix_expression →  • postfix_expression '(' ')', primary_expression →  • '(' expression ')', exclusive_or_expression →  • and_expression, postfix_expression →  • postfix_expression '++', statement →  • labeled_statement, labeled_statement →  • 'case' constant_expression ':' statement, unary_operator →  • '~', multiplicative_expression →  • multiplicative_expression '/' unary_expression, expression →  • expression ',' assignment_expression, shift_expression →  • shift_expression '>>' additive_expression, jump_statement →  • 'goto' IDENTIFIER ';', assignment_expression →  • unary_expression assignment_oper ...
# s8 = {postfix_expression → postfix_expression '[' expression ']' • }
# s9 = {unary_operator → '&' • }
# s10 = {unary_operator → '!' • }
# s11 = {jump_statement → 'return' expression ';' • }
# s12 = {direct_abstract_declarator →  • '[' constant_expression ']', direct_abstract_declarator →  • '(' abstract_declarator ')', direct_abstract_declarator →  • '[' ']', direct_abstract_declarator →  • '(' parameter_type_list ')', direct_abstract_declarator →  • '(' ')', direct_abstract_declarator →  • direct_abstract_declarator '(' ')', direct_abstract_declarator →  • direct_abstract_declarator '[' ']', direct_abstract_declarator →  • direct_abstract_declarator '(' parameter_type_list ')', abstract_declarator → pointer • direct_abstract_declarator, abstract_declarator → pointer • , direct_abstract_declarator →  • direct_abstract_declarator '[' constant_expression ']'}
# s13 = {type_specifier →  • 'float', jump_statement →  • 'break' ';', inclusive_or_expression →  • exclusive_or_expression, compound_statement → '{' • statement_list '}', type_specifier →  • 'int', unary_expression →  • '++' unary_expression, type_specifier →  • 'char', struct_or_union →  • 'struct', struct_or_union_specifier →  • struct_or_union IDENTIFIER, statement →  • selection_statement, declaration_list →  • declaration_list declaration, type_specifier →  • 'long', labeled_statement →  • 'default' ':' statement, enum_specifier →  • 'enum' IDENTIFIER '{' enumerator_list '}', logical_and_expression →  • inclusive_or_expression, postfix_expression →  • postfix_expression '--', struct_or_union_specifier →  • struct_or_union IDENTIFIER '{' struct_declaration_list '}', type_specifier →  • 'short', conditional_expression →  • logical_or_expression '?' expression ':' conditional_expression, shift_expression →  • additive_expression, additive_expression →  • multiplicative_expression, expression_statement →  • ';', conditional_expression →  • logical_or_expression, unary_operator →  • '+', inclusive_or_expression →  • inclusive_or_expression '|' exclusive_or_expression, statement →  • compound_statement, postfix_expression →  • postfix_expression '.' IDENTIFIER, iteration_statement →  • 'for' '(' expression_statement expression_statement expression ')' statement, selection_statement →  • 'switch' '(' expression ')' statement, equality_expression →  • relational_expression, statement_list →  • statement_list statement, storage_class_specifier →  • 'auto', jump_statement →  • 'return' ';', postfix_expression →  • primary_expression, struct_or_union →  • 'union', statement →  • expression_statement, unary_operator →  • '-', expression →  • assignment_expression, logical_or_expression →  • logical_and_expression, jump_statement →  • 'return' expression ';', compound_statement → '{' • '}', declaration →  • declaration_specifiers init_declarator_list ';', exclusive_or_expression →  • exclusive_or_expression '^' and_expression, declaration_specifiers →  • storage_class_specifier, postfix_expression →  • postfix_expression '[' expression ']', compound_statement →  • '{' '}', primary_expression →  • CONSTANT, jump_statement →  • 'continue' ';', type_specifier →  • 'double', relational_expression →  • relational_expression '<' shift_expression, iteration_statement →  • 'do' statement 'while' '(' expression ')' ';', type_qualifier →  • 'volatile', compound_statement → '{' • declaration_list statement_list '}', iteration_statement →  • 'while' '(' expression ')' statement, assignment_expression →  • conditional_expression, expression_statement →  • expression ';', compound_statement → '{' • declaration_list '}', unary_operator →  • '!', equality_expression →  • equality_expression '==' relational_expression, unary_expression →  • 'sizeof' '(' type_name ')', declaration_specifiers →  • type_specifier declaration_specifiers, storage_class_specifier →  • 'typedef', shift_expression →  • shift_expression '<<' additive_expression, statement →  • iteration_statement, compound_statement →  • '{' declaration_list '}', primary_expression →  • STRING_LITERAL, relational_expression →  • shift_expression, primary_expression →  • IDENTIFIER, storage_class_specifier →  • 'register', unary_expression →  • 'sizeof' unary_expression, multiplicative_expression →  • multiplicative_expression '*' unary_expression, unary_expression →  • unary_operator unary_expression, logical_and_expression →  • logical_and_expression '&&' inclusive_or_expression, unary_operator →  • '&', multiplicative_expression →  • multiplicative_expression '%' unary_expression, logical_or_expression →  • logical_or_expression '||' logical_and_expression, compound_statement →  • '{' declaration_list statement_list '}', postfix_expression →  • postfix_expression '->' IDENTIFIER, equality_expression →  • equality_expression '!=' relational_expression, unary_operator →  • '*', and_expression → ...
# s14 = {postfix_expression → postfix_expression '++' • }
# s15 = {type_specifier → 'double' • }
# s16 = {direct_abstract_declarator → direct_abstract_declarator '(' parameter_type_list ')' • }
# s17 = {declaration → declaration_specifiers init_declarator_list • ';', init_declarator_list → init_declarator_list • ',' init_declarator}
# s18 = {declaration_list → declaration_list declaration • }
# s19 = {init_declarator →  • declarator, declarator →  • direct_declarator, direct_declarator →  • direct_declarator '(' parameter_type_list ')', pointer →  • '*' pointer, pointer →  • '*', direct_declarator →  • direct_declarator '(' ')', pointer →  • '*' type_qualifier_list, direct_declarator →  • direct_declarator '(' identifier_list ')', init_declarator_list → init_declarator_list ',' • init_declarator, declarator →  • pointer direct_declarator, direct_declarator →  • IDENTIFIER, pointer →  • '*' type_qualifier_list pointer, direct_declarator →  • direct_declarator '[' ']', direct_declarator →  • '(' declarator ')', direct_declarator →  • direct_declarator '[' constant_expression ']', init_declarator →  • declarator '=' initializer}
# s20 = {declarator →  • direct_declarator, direct_declarator →  • direct_declarator '(' parameter_type_list ')', pointer →  • '*' pointer, pointer →  • '*', direct_declarator →  • direct_declarator '(' ')', pointer →  • '*' type_qualifier_list, direct_declarator →  • direct_declarator '(' identifier_list ')', struct_declarator →  • ':' constant_expression, declarator →  • pointer direct_declarator, direct_declarator →  • IDENTIFIER, struct_declarator →  • declarator, pointer →  • '*' type_qualifier_list pointer, struct_declarator →  • declarator ':' constant_expression, direct_declarator →  • direct_declarator '[' ']', direct_declarator →  • '(' declarator ')', direct_declarator →  • direct_declarator '[' constant_expression ']', struct_declarator_list → struct_declarator_list ',' • struct_declarator}
# s21 = {type_specifier → 'int' • }
# s22 = {iteration_statement → 'do' statement 'while' '(' expression ')' • ';'}
# ...
# goto(s242, unary_operator) = s298
# goto(s242, unary_expression) = s291
# goto(s242, primary_expression) = s114
# goto(s242, postfix_expression) = s198
# goto(s245, unary_operator) = s298
# goto(s245, equality_expression) = s120
# goto(s245, relational_expression) = s207
# goto(s245, unary_expression) = s241
# goto(s245, multiplicative_expression) = s294
# goto(s245, additive_expression) = s109
# goto(s245, shift_expression) = s150
# goto(s245, primary_expression) = s114
# goto(s245, postfix_expression) = s198
# goto(s247, unary_operator) = s298
# goto(s247, unary_expression) = s152
# goto(s247, primary_expression) = s114
# goto(s247, postfix_expression) = s198
# goto(s249, enumerator) = s295
# goto(s255, unary_operator) = s298
# goto(s255, logical_or_expression) = s147
# goto(s255, jump_statement) = s296
# goto(s255, equality_expression) = s5
# goto(s255, conditional_expression) = s234
# goto(s255, iteration_statement) = s286
# goto(s255, relational_expression) = s207
# goto(s255, selection_statement) = s297
# goto(s255, unary_expression) = s158
# goto(s255, inclusive_or_expression) = s303
# goto(s255, statement) = s190
# goto(s255, logical_and_expression) = s329
# goto(s255, assignment_expression) = s181
# goto(s255, multiplicative_expression) = s294
# goto(s255, labeled_statement) = s169
# goto(s255, additive_expression) = s109
# goto(s255, shift_expression) = s150
# goto(s255, expression_statement) = s149
# goto(s255, compound_statement) = s34
# goto(s255, expression) = s177
# goto(s255, primary_expression) = s114
# goto(s255, and_expression) = s91
# goto(s255, exclusive_or_expression) = s258
# goto(s255, postfix_expression) = s198
# goto(s257, unary_operator) = s298
# goto(s257, unary_expression) = s241
# goto(s257, multiplicative_expression) = s294
# goto(s257, additive_expression) = s109
# goto(s257, shift_expression) = s80
# goto(s257, primary_expression) = s114
# goto(s257, postfix_expression) = s198
# goto(s259, unary_operator) = s298
# goto(s259, logical_or_expression) = s147
# goto(s259, jump_statement) = s296
# goto(s259, equality_expression) = s5
# goto(s259, conditional_expression) = s234
# goto(s259, iteration_statement) = s286
# goto(s259, relational_expression) = s207
# goto(s259, selection_statement) = s297
# goto(s259, unary_expression) = s158
# goto(s259, inclusive_or_expression) = s303
# goto(s259, statement) = s47
# goto(s259, logical_and_expression) = s329
# goto(s259, assignment_expression) = s181
# goto(s259, multiplicative_expression) = s294
# goto(s259, labeled_statement) = s169
# goto(s259, additive_expression) = s109
# goto(s259, shift_expression) = s150
# goto(s259, expression_statement) = s149
# goto(s259, compound_statement) = s34
# goto(s259, expression) = s177
# goto(s259, primary_expression) = s114
# goto(s259, and_expression) = s91
# goto(s259, exclusive_or_expression) = s258
# goto(s259, postfix_expression) = s198
# goto(s261, unary_operator) = s298
# goto(s261, relational_expression) = s339
# goto(s261, unary_expression) = s241
# goto(s261, multiplicative_expression) = s294
# goto(s261, additive_expression) = s109
# goto(s261, shift_expression) = s150
# goto(s261, primary_expression) = s114
# goto(s261, postfix_expression) = s198
# goto(s263, unary_operator) = s298
# goto(s263, logical_or_expression) = s147
# goto(s263, jump_statement) = s296
# goto(s263, equality_expression) = s5
# goto(s263, conditional_expression) = s234
# goto(s263, iteration_statement) = s286
# goto(s263, relational_expression) = s207
# goto(s263, selection_statement) = s297
# goto(s263, unary_expression) = s158
# goto(s263, inclusive_or_expression) = s303
# goto(s263, statement) = s121
# goto(s263, logical_and_expression) = s329
# goto(s263, assignment_expression) = s181
# goto(s263, multiplicative_expression) = s294
# goto(s263, labeled_statement) = s169
# goto(s263, additive_expression) = s109
# goto(s263, shift_expression) = s150
# goto(s263, expression_statement) = s149
# goto(s263, compound_statement) = s34
# goto(s263, expression) = s177
# goto(s263, primary_expression) = s114
# goto(s263, and_expression) = s91
# goto(s263, exclusive_or_expression) = s258
# goto(s263, postfix_expression) = s198
# goto(s264, unary_operator) = s298
# goto(s264, logical_or_expression) = s147
# goto(s264, jump_statement) = s296
# goto(s264, equality_expression) = s5
# goto(s264, conditional_expression) = s234
# goto(s264, iteration_statement) = s286
# goto(s264, relational_expression) = s207
# goto(s264, selection_statement) = s297
# goto(s264, unary_expression) = s158
# goto(s264, inclusive_or_expression) = s303
# goto(s264, statement) = s47
# goto(s264, logical_and_expression) = s329
# goto(s264, assignment_expression) = s181
# goto(s264, multiplicative_expression) = s294
# goto(s264, labeled_statement) = s169
# goto(s264, additive_expression) = s109
# goto(s264, shift_expression) = s150
# goto(s264, expression_statement) = s149
# goto(s264, compound_statement) = s34
# goto(s264, expression) = s177
# goto(s264, primary_expression) = s114
# goto(s264, and_expression) = s91
# goto(s264, exclusive_or_expression) = s258
# goto(s264, postfix_expression) = s198
# goto(s265, direct_declarator) = s260
# goto(s268, unary_operator) = s298
# goto(s268, equality_expression) = s5
# goto(s268, relational_expression) = s207
# goto(s268, unary_expression) = s241
# goto(s268, multiplicative_expression) = s294
# goto(s268, additive_expression) = s109
# goto(s268, shift_expression) = s150
# goto(s268, primary_expression) = s114
# goto(s268, and_expression) = s91
# goto(s268, exclusive_or_expression) = s119
# goto(s268, postfix_expression) = s198
# goto(s269, struct_declaration) = s184
# goto(s269, enum_specifier) = s156
# goto(s269, type_specifier) = s276
# goto(s269, struct_or_union) = s240
# goto(s269, struct_declaration_list) = s189
# goto(s269, specifier_qualifier_list) = s129
# goto(s269, struct_or_union_specifier) = s324
# goto(s269, type_qualifier) = s201
# goto(s273, unary_operator) = s298
# goto(s273, unary_expression) = s241
# goto(s273, multiplicative_expression) = s155
# goto(s273, primary_expression) = s114
# goto(s273, postfix_expression) = s198
# goto(s276, enum_specifier) = s156
# goto(s276, type_specifier) = s276
# goto(s276, struct_or_union) = s240
# goto(s276, specifier_qualifier_list) = s246
# goto(s276, struct_or_union_specifier) = s324
# goto(s276, type_qualifier) = s201
# goto(s279, unary_operator) = s298
# goto(s279, unary_expression) = s241
# goto(s279, multiplicative_expression) = s294
# goto(s279, additive_expression) = s109
# goto(s279, shift_expression) = s335
# goto(s279, primary_expression) = s114
# goto(s279, postfix_expression) = s198
# goto(s280, unary_operator) = s298
# goto(s280, logical_or_expression) = s147
# goto(s280, jump_statement) = s296
# goto(s280, equality_expression) = s5
# goto(s280, conditional_expression) = s234
# goto(s280, iteration_statement) = s286
# goto(s280, relational_expression) = s207
# goto(s280, selection_statement) = s297
# goto(s280, unary_expression) = s158
# goto(s280, inclusive_or_expression) = s303
# goto(s280, statement) = s284
# goto(s280, logical_and_expression) = s329
# goto(s280, assignment_expression) = s181
# goto(s280, multiplicative_expression) = s294
# goto(s280, labeled_statement) = s169
# goto(s280, additive_expression) = s109
# goto(s280, shift_expression) = s150
# goto(s280, expression_statement) = s149
# goto(s280, compound_statement) = s34
# goto(s280, expression) = s177
# goto(s280, primary_expression) = s114
# goto(s280, and_expression) = s91
# goto(s280, exclusive_or_expression) = s258
# goto(s280, postfix_expression) = s198
# goto(s283, enum_specifier) = s156
# goto(s283, type_specifier) = s237
# goto(s283, struct_or_union) = s240
# goto(s283, declaration) = s18
# goto(s283, declaration_specifiers) = s188
# goto(s283, storage_class_specifier) = s321
# goto(s283, compound_statement) = s90
# goto(s283, struct_or_union_specifier) = s324
# goto(s283, type_qualifier) = s145
# goto(s287, unary_operator) = s298
# goto(s287, unary_expression) = s241
# goto(s287, multiplicative_expression) = s294
# goto(s287, additive_expression) = s109
# goto(s287, shift_expression) = s163
# goto(s287, primary_expression) = s114
# goto(s287, postfix_expression) = s198
# goto(s289, unary_operator) = s298
# goto(s289, logical_or_expression) = s147
# goto(s289, equality_expression) = s5
# goto(s289, conditional_expression) = s234
# goto(s289, relational_expression) = s207
# goto(s289, unary_expression) = s158
# goto(s289, inclusive_or_expression) = s303
# goto(s289, logical_and_expression) = s329
# goto(s289, assignment_expression) = s181
# goto(s289, multiplicative_expression) = s294
# goto(s289, additive_expression) = s109
# goto(s289, shift_expression) = s150
# goto(s289, expression) = s178
# goto(s289, primary_expression) = s114
# goto(s289, and_expression) = s91
# goto(s289, exclusive_or_expression) = s258
# goto(s289, postfix_expression) = s198
# goto(s298, unary_operator) = s298
# goto(s298, unary_expression) = s78
# goto(s298, primary_expression) = s114
# goto(s298, postfix_expression) = s198
# goto(s301, constant_expression) = s227
# goto(s301, unary_operator) = s298
# goto(s301, logical_or_expression) = s147
# goto(s301, equality_expression) = s5
# goto(s301, conditional_expression) = s92
# goto(s301, relational_expression) = s207
# goto(s301, unary_expression) = s241
# goto(s301, inclusive_or_expression) = s303
# goto(s301, logical_and_expression) = s329
# goto(s301, multiplicative_expression) = s294
# goto(s301, additive_expression) = s109
# goto(s301, shift_expression) = s150
# goto(s301, primary_expression) = s114
# goto(s301, and_expression) = s91
# goto(s301, exclusive_or_expression) = s258
# goto(s301, postfix_expression) = s198
# goto(s302, enum_specifier) = s156
# goto(s302, type_specifier) = s237
# goto(s302, struct_or_union) = s240
# goto(s302, declaration) = s18
# goto(s302, declaration_specifiers) = s188
# goto(s302, storage_class_specifier) = s321
# goto(s302, compound_statement) = s314
# goto(s302, struct_or_union_specifier) = s324
# goto(s302, type_qualifier) = s145
# goto(s307, constant_expression) = s107
# goto(s307, unary_operator) = s298
# goto(s307, logical_or_expression) = s147
# goto(s307, equality_expression) = s5
# goto(s307, conditional_expression) = s92
# goto(s307, relational_expression) = s207
# goto(s307, unary_expression) = s241
# goto(s307, inclusive_or_expression) = s303
# goto(s307, logical_and_expression) = s329
# goto(s307, multiplicative_expression) = s294
# goto(s307, additive_expression) = s109
# goto(s307, shift_expression) = s150
# goto(s307, primary_expression) = s114
# goto(s307, and_expression) = s91
# goto(s307, exclusive_or_expression) = s258
# goto(s307, postfix_expression) = s198
# goto(s310, enumerator_list) = s334
# goto(s310, enumerator) = s1
# goto(s311, struct_declaration) = s94
# goto(s311, enum_specifier) = s156
# goto(s311, type_specifier) = s276
# goto(s311, struct_or_union) = s240
# goto(s311, specifier_qualifier_list) = s129
# goto(s311, struct_or_union_specifier) = s324
# goto(s311, type_qualifier) = s201
# goto(s312, unary_operator) = s298
# goto(s312, logical_or_expression) = s147
# goto(s312, jump_statement) = s296
# goto(s312, equality_expression) = s5
# goto(s312, conditional_expression) = s234
# goto(s312, iteration_statement) = s286
# goto(s312, relational_expression) = s207
# goto(s312, selection_statement) = s297
# goto(s312, unary_expression) = s158
# goto(s312, inclusive_or_expression) = s303
# goto(s312, statement) = s160
# goto(s312, logical_and_expression) = s329
# goto(s312, assignment_expression) = s181
# goto(s312, multiplicative_expression) = s294
# goto(s312, labeled_statement) = s169
# goto(s312, additive_expression) = s109
# goto(s312, shift_expression) = s150
# goto(s312, expression_statement) = s149
# goto(s312, compound_statement) = s34
# goto(s312, expression) = s177
# goto(s312, primary_expression) = s114
# goto(s312, and_expression) = s91
# goto(s312, exclusive_or_expression) = s258
# goto(s312, postfix_expression) = s198
# goto(s313, unary_operator) = s298
# goto(s313, logical_or_expression) = s147
# goto(s313, equality_expression) = s5
# goto(s313, conditional_expression) = s234
# goto(s313, relational_expression) = s207
# goto(s313, initializer) = s173
# goto(s313, unary_expression) = s158
# goto(s313, inclusive_or_expression) = s303
# goto(s313, logical_and_expression) = s329
# goto(s313, assignment_expression) = s277
# goto(s313, multiplicative_expression) = s294
# goto(s313, additive_expression) = s109
# goto(s313, shift_expression) = s150
# goto(s313, primary_expression) = s114
# goto(s313, and_expression) = s91
# goto(s313, exclusive_or_expression) = s258
# goto(s313, postfix_expression) = s198
# goto(s320, init_declarator) = s328
# goto(s320, init_declarator_list) = s17
# goto(s320, declarator) = s103
# goto(s320, direct_declarator) = s285
# goto(s320, pointer) = s265
# goto(s321, enum_specifier) = s156
# goto(s321, type_specifier) = s237
# goto(s321, struct_or_union) = s240
# goto(s321, declaration_specifiers) = s274
# goto(s321, storage_class_specifier) = s321
# goto(s321, struct_or_union_specifier) = s324
# goto(s321, type_qualifier) = s145
# goto(s322, unary_operator) = s298
# goto(s322, logical_or_expression) = s147
# goto(s322, equality_expression) = s5
# goto(s322, conditional_expression) = s234
# goto(s322, relational_expression) = s207
# goto(s322, unary_expression) = s158
# goto(s322, inclusive_or_expression) = s303
# goto(s322, logical_and_expression) = s329
# goto(s322, assignment_expression) = s63
# goto(s322, multiplicative_expression) = s294
# goto(s322, additive_expression) = s109
# goto(s322, shift_expression) = s150
# goto(s322, primary_expression) = s114
# goto(s322, and_expression) = s91
# goto(s322, exclusive_or_expression) = s258
# goto(s322, postfix_expression) = s198
# goto(s327, unary_operator) = s298
# goto(s327, unary_expression) = s84
# goto(s327, primary_expression) = s114
# goto(s327, postfix_expression) = s198
# goto(s332, unary_operator) = s298
# goto(s332, logical_or_expression) = s147
# goto(s332, equality_expression) = s5
# goto(s332, conditional_expression) = s234
# goto(s332, relational_expression) = s207
# goto(s332, unary_expression) = s158
# goto(s332, inclusive_or_expression) = s303
# goto(s332, logical_and_expression) = s329
# goto(s332, assignment_expression) = s181
# goto(s332, multiplicative_expression) = s294
# goto(s332, additive_expression) = s109
# goto(s332, shift_expression) = s150
# goto(s332, expression_statement) = s125
# goto(s332, expression) = s177
# goto(s332, primary_expression) = s114
# goto(s332, and_expression) = s91
# goto(s332, exclusive_or_expression) = s258
# goto(s332, postfix_expression) = s198
# goto(s333, unary_operator) = s298
# goto(s333, logical_or_expression) = s147
# goto(s333, equality_expression) = s5
# goto(s333, conditional_expression) = s54
# goto(s333, relational_expression) = s207
# goto(s333, unary_expression) = s241
# goto(s333, inclusive_or_expression) = s303
# goto(s333, logical_and_expression) = s329
# goto(s333, multiplicative_expression) = s294
# goto(s333, additive_expression) = s109
# goto(s333, shift_expression) = s150
# goto(s333, primary_expression) = s114
# goto(s333, and_expression) = s91
# goto(s333, exclusive_or_expression) = s258
# goto(s333, postfix_expression) = s198
# goto(s338, unary_operator) = s298
# goto(s338, logical_or_expression) = s147
# goto(s338, equality_expression) = s5
# goto(s338, conditional_expression) = s234
# goto(s338, relational_expression) = s207
# goto(s338, unary_expression) = s158
# goto(s338, inclusive_or_expression) = s303
# goto(s338, logical_and_expression) = s329
# goto(s338, assignment_expression) = s106
# goto(s338, multiplicative_expression) = s294
# goto(s338, additive_expression) = s109
# goto(s338, shift_expression) = s150
# goto(s338, primary_expression) = s114
# goto(s338, and_expression) = s91
# goto(s338, exclusive_or_expression) = s258
# goto(s338, postfix_expression) = s198
# goto(s340, unary_operator) = s298
# goto(s340, logical_or_expression) = s147
# goto(s340, equality_expression) = s5
# goto(s340, conditional_expression) = s234
# goto(s340, relational_expression) = s207
# goto(s340, unary_expression) = s158
# goto(s340, inclusive_or_expression) = s303
# goto(s340, logical_and_expression) = s329
# goto(s340, assignment_expression) = s181
# goto(s340, multiplicative_expression) = s294
# goto(s340, additive_expression) = s109
# goto(s340, shift_expression) = s150
# goto(s340, expression) = s59
# goto(s340, primary_expression) = s114
# goto(s340, and_expression) = s91
# goto(s340, exclusive_or_expression) = s258
# goto(s340, postfix_expression) = s198
# CPU times: user 386 ms, sys: 10.3 ms, total: 397 ms
# Wall time: 396 ms

# %%
# %%time
analyse('Examples/c-grammar.g')

# %%
analyse('Examples/bool-2.g')
